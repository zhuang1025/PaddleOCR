# %% [markdown]
# 測試一張OCR

# %%
from paddleocr import PaddleOCR, draw_ocr
from PIL import Image

ocr = PaddleOCR(use_angle_cls=True, lang='ch', use_gpu=False)

image_path = r'C:\Users\zhuang\Desktop\Paddle\img\id_card_images\image_00000.png'
result = ocr.ocr(image_path, cls=True)

if result and result[0]:
    image = Image.open(image_path).convert('RGB')
    boxes = [line[0] for line in result[0]]
    txts = [line[1][0] for line in result[0]]
    scores = [line[1][1] for line in result[0]]

    try:
        font_path_for_drawing = r'C:\Windows\Fonts\msyh.ttc'  
        im_show = draw_ocr(image, boxes, txts, scores, font_path=font_path_for_drawing)
        im_show = Image.fromarray(im_show)
        output_image_path = 'result.jpg'
        im_show.save(output_image_path)
        print(f"\n識別結果已保存到可視化圖片：{output_image_path}")

    except ImportError:
        print("\n警告：無法繪製識別結果。請安裝 'opencv-python' 和 'Pillow' 庫 (pip install opencv-python Pillow)。")
    except FileNotFoundError:
        print(f"\n錯誤：繪製圖片時找不到字體文件。請檢查 font_path: '{font_path_for_drawing}' 是否正確。")
    except Exception as e:
        print(f"\n繪製結果時發生未知錯誤: {e}")
else:
    print("未在圖片中識別到任何文字。")

print("\nOCR 測試完成。")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from paddleocr import PaddleOCR, draw_ocr
#       2 from PIL import Image
#       4 ocr = PaddleOCR(use_angle_cls=True, lang='ch', use_gpu=False)
#
# ImportError: cannot import name 'draw_ocr' from 'paddleocr' (c:\Users\zhuang\Desktop\Paddle\paddleocr\__init__.py)

# %% [markdown]
# OCR整個資料夾 img\id_card_images

# %%
from paddleocr_backup import PaddleOCR, draw_ocr
import os
from PIL import Image 


input_image_dir = r'C:\Users\User\Desktop\PaddleOCR\img\id_card_images'
output_ocr_image_dir = r'C:\Users\User\Desktop\PaddleOCR\img\ocrimg1'
output_ocr_text_dir = r'C:\Users\User\Desktop\PaddleOCR\img\ocrtxt1'


if not os.path.exists(input_image_dir):
    print(f"錯誤：輸入圖片資料夾 '{input_image_dir}' 不存在。請檢查路徑是否正確。")
    exit() 


os.makedirs(output_ocr_image_dir, exist_ok=True)
os.makedirs(output_ocr_text_dir, exist_ok=True)

print(f"將從 '{input_image_dir}' 讀取圖片。")
print(f"OCR 可視化圖片將保存到： {output_ocr_image_dir}")
print(f"OCR 識別文字將保存到： {output_ocr_text_dir}")

# lang='ch' 表示使用中文模型，'en' 表示英文
ocr = PaddleOCR(use_angle_cls=True, lang="ch", use_gpu=False)
font_path_for_drawing = r'C:\Windows\Fonts\msyh.ttc'
image_files = [f for f in os.listdir(input_image_dir)
               if os.path.isfile(os.path.join(input_image_dir, f)) and
               f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff'))]

if not image_files:
    print(f"在 '{input_image_dir}' 中沒有找到任何圖片文件。")
else:
    print(f"\n在 '{input_image_dir}' 中找到 {len(image_files)} 張圖片，開始進行 OCR 處理...")

    
    processed_count = 0

    for img_filename in sorted(image_files): 
        full_image_path = os.path.join(input_image_dir, img_filename)

        print(f"\n正在處理圖片：'{img_filename}' (總計 {processed_count + 1}/{len(image_files)})")

        try:
            
            result = ocr.ocr(full_image_path, cls=True)

            recognized_texts = []
            if result and result[0]:
                for line in result[0]:
                    text = line[1][0] 
                    recognized_texts.append(text)

                # 保存結果
                output_text_filename = f"{processed_count}.txt" 
                output_text_path = os.path.join(output_ocr_text_dir, output_text_filename)

                with open(output_text_path, 'w', encoding='utf-8') as f:
                    for text_line in recognized_texts:
                        f.write(text_line + '\n')
                print(f"  識別文字已保存到：{output_text_path}")

            
                try:
                    img = Image.open(full_image_path).convert('RGB')
                    boxes = [line[0] for line in result[0]]
                    txts = [line[1][0] for line in result[0]]
                    scores = [line[1][1] for line in result[0]]

                    im_show = draw_ocr(img, boxes, txts, scores, font_path=font_path_for_drawing)
                    im_show = Image.fromarray(im_show)

                    output_image_filename = f"{processed_count}.jpg" # 命名為 0.jpg, 1.jpg...
                    output_image_path = os.path.join(output_ocr_image_dir, output_image_filename)
                    im_show.save(output_image_path)
                    print(f"  可視化圖片已保存到：{output_image_path}")

                except ImportError:
                    print("\n警告：無法繪製識別結果。請安裝 'opencv-python' 和 'Pillow' 庫 (pip install opencv-python Pillow)。")
                except FileNotFoundError:
                    print(f"\n錯誤：繪製圖片時找不到字體文件。請檢查 font_path: '{font_path_for_drawing}' 是否正確。")
                except Exception as e:
                    print(f"\n繪製結果時發生未知錯誤: {e}")
            else:
                print(f"  未在圖片 '{img_filename}' 中識別到任何文字。")

            processed_count += 1 

        except Exception as e:
            print(f"處理圖片 '{img_filename}' 時發生錯誤: {e}")

    print("\n所有圖片的 OCR 處理完成！")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from paddleocr_backup import PaddleOCR, draw_ocr
#       2 import os
#       3 from PIL import Image # 確保導入 PIL 的 Image 模組
#
# ModuleNotFoundError: No module named 'paddleocr_backup'

# %% [markdown]
# 正則化ocrimg1資料夾並將正規化後存到ocrtxt_normalized

# %%
import os
import re
from pathlib import Path

def clean_ocr_text(text):
    """
    清理OCR文本，移除字段标签，只保留数据
    """
    # 定义需要移除的字段标签
    field_labels = [
        '姓名', '性别', '民族', '出生', '住址', '公民身份号码',
        '年', '月', '日'
    ]
    
    # 按行分割文本
    lines = [line.strip() for line in text.split('\n') if line.strip()]
    cleaned_lines = []
    
    for line in lines:
        cleaned_line = line
        
        # 移除字段标签
        for label in field_labels:
            cleaned_line = cleaned_line.replace(label, '')
        
        # 处理民族简化（汉族->汉，回族->回等）
        cleaned_line = re.sub(r'汉族', '汉', cleaned_line)
        cleaned_line = re.sub(r'回族', '回', cleaned_line)
        cleaned_line = re.sub(r'满族', '满', cleaned_line)
        cleaned_line = re.sub(r'蒙古族', '蒙古', cleaned_line)
        
        # 处理日期格式，将"1988年12月21日"分离为独立的年、月、日
        date_pattern = r'(\d{4})年(\d{1,2})月(\d{1,2})日'
        date_match = re.search(date_pattern, cleaned_line)
        if date_match:
            year, month, day = date_match.groups()
            cleaned_lines.extend([year, month, day])
            continue
            
        # 清理多余的空格和特殊字符
        cleaned_line = re.sub(r'\s+', '', cleaned_line)  # 移除所有空格
        cleaned_line = cleaned_line.strip()
        
        # 如果清理后还有内容，就添加到结果中
        if cleaned_line:
            cleaned_lines.append(cleaned_line)
    
    return '\n'.join(cleaned_lines)

def process_ocr_files(input_dir, output_dir):
    """
    批量处理OCR文本文件
    """
    # 创建输出目录（如果不存在）
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    
    # 统计信息
    processed_count = 0
    error_count = 0
    
    print(f"开始处理文件...")
    print(f"输入目录: {input_dir}")
    print(f"输出目录: {output_dir}")
    print("-" * 50)
    
    # 遍历输入目录中的所有txt文件
    for filename in os.listdir(input_dir):
        if filename.lower().endswith('.txt'):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)
            
            try:
                # 读取原始文件
                with open(input_path, 'r', encoding='utf-8') as f:
                    original_text = f.read()
                
                # 清理文本
                cleaned_text = clean_ocr_text(original_text)
                
                # 写入清理后的文件
                with open(output_path, 'w', encoding='utf-8') as f:
                    f.write(cleaned_text)
                
                print(f"✅ 处理完成: {filename}")
                print(f"   原始行数: {len(original_text.split())}")
                print(f"   清理后行数: {len(cleaned_text.split())}")
                print()
                
                processed_count += 1
                
            except Exception as e:
                print(f"❌ 处理错误: {filename} - {str(e)}")
                error_count += 1
    
    print("-" * 50)
    print(f"处理完成！")
    print(f"成功处理: {processed_count} 个文件")
    print(f"处理失败: {error_count} 个文件")

def preview_cleaning(input_dir, max_files=3):
    """
    预览清理效果，显示前几个文件的处理前后对比
    """
    print("📋 清理效果预览")
    print("=" * 60)
    
    file_count = 0
    for filename in os.listdir(input_dir):
        if filename.lower().endswith('.txt') and file_count < max_files:
            input_path = os.path.join(input_dir, filename)
            
            try:
                with open(input_path, 'r', encoding='utf-8') as f:
                    original_text = f.read()
                
                cleaned_text = clean_ocr_text(original_text)
                
                print(f"\n📄 文件: {filename}")
                print("-" * 30)
                print("处理前:")
                print(original_text[:200] + ("..." if len(original_text) > 200 else ""))
                print("-" * 30)
                print("处理后:")
                print(cleaned_text)
                print("=" * 60)
                
                file_count += 1
                
            except Exception as e:
                print(f"❌ 预览错误: {filename} - {str(e)}")

if __name__ == "__main__":
    # --- 設定輸入和輸出資料夾路徑 ---
    input_ocrtxt_dir = r'C:\Users\zhuang\Desktop\Paddle\img\ocrtxt1'
    output_normalized_ocrtxt_dir = r'C:\Users\zhuang\Desktop\Paddle\img\ocrtxt_normalized'
    
    # 检查输入目录是否存在
    if not os.path.exists(input_ocrtxt_dir):
        print(f"❌ 错误: 输入目录不存在: {input_ocrtxt_dir}")
        exit(1)
    

    # 开始批量处理
    process_ocr_files(input_ocrtxt_dir, output_normalized_ocrtxt_dir)
    
    print(f"\n所有处理完成的文件保存在: {output_normalized_ocrtxt_dir}")
# Out:
# 开始处理文件...
# 输入目录: C:\Users\zhuang\Desktop\Paddle\img\ocrtxt
# 输出目录: C:\Users\zhuang\Desktop\Paddle\img\ocrtxt_normalized
# --------------------------------------------------
# ✅ 处理完成: 0.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 1.txt
#    原始行数: 13
#    清理后行数: 8
#
# ✅ 处理完成: 10.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 100.txt
#    原始行数: 10
#    清理后行数: 7
#
# ✅ 处理完成: 101.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 102.txt
#    原始行数: 11
#    清理后行数: 7
#
# ✅ 处理完成: 103.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 104.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 105.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 106.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 107.txt
#    原始行数: 10
#    清理后行数: 5
#
# ✅ 处理完成: 108.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 109.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 11.txt
#    原始行数: 10
#    清理后行数: 5
#
# ✅ 处理完成: 110.txt
#    原始行数: 13
#    清理后行数: 6
#
# ✅ 处理完成: 111.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 112.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 113.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 114.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 115.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 116.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 117.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 118.txt
#    原始行数: 10
#    清理后行数: 5
#
# ✅ 处理完成: 119.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 12.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 120.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 121.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 122.txt
#    原始行数: 13
#    清理后行数: 8
#
# ✅ 处理完成: 123.txt
#    原始行数: 8
#    清理后行数: 6
#
# ✅ 处理完成: 124.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 125.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 126.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 127.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 128.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 129.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 13.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 130.txt
#    原始行数: 12
#    清理后行数: 6
#
# ✅ 处理完成: 131.txt
#    原始行数: 11
#    清理后行数: 5
#
# ✅ 处理完成: 132.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 133.txt
#    原始行数: 11
#    清理后行数: 8
#
# ✅ 处理完成: 134.txt
#    原始行数: 8
#    清理后行数: 7
#
# ✅ 处理完成: 135.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 136.txt
#    原始行数: 12
#    清理后行数: 8
#
# ✅ 处理完成: 137.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 138.txt
#    原始行数: 12
#    清理后行数: 6
#
# ✅ 处理完成: 139.txt
#    原始行数: 10
#    清理后行数: 7
#
# ✅ 处理完成: 14.txt
#    原始行数: 11
#    清理后行数: 7
#
# ✅ 处理完成: 140.txt
#    原始行数: 9
#    清理后行数: 7
#
# ✅ 处理完成: 141.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 142.txt
#    原始行数: 11
#    清理后行数: 7
#
# ✅ 处理完成: 143.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 144.txt
#    原始行数: 8
#    清理后行数: 6
#
# ✅ 处理完成: 145.txt
#    原始行数: 13
#    清理后行数: 6
#
# ✅ 处理完成: 146.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 147.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 148.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 149.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 15.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 150.txt
#    原始行数: 7
#    清理后行数: 5
#
# ✅ 处理完成: 151.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 152.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 153.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 154.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 155.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 156.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 157.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 158.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 159.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 16.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 160.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 161.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 162.txt
#    原始行数: 11
#    清理后行数: 5
#
# ✅ 处理完成: 163.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 164.txt
#    原始行数: 11
#    清理后行数: 7
#
# ✅ 处理完成: 165.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 166.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 167.txt
#    原始行数: 8
#    清理后行数: 6
#
# ✅ 处理完成: 168.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 169.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 17.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 170.txt
#    原始行数: 14
#    清理后行数: 8
#
# ✅ 处理完成: 171.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 172.txt
#    原始行数: 12
#    清理后行数: 6
#
# ✅ 处理完成: 173.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 174.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 175.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 176.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 177.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 178.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 179.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 18.txt
#    原始行数: 11
#    清理后行数: 5
#
# ✅ 处理完成: 180.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 181.txt
#    原始行数: 9
#    清理后行数: 8
#
# ✅ 处理完成: 182.txt
#    原始行数: 12
#    清理后行数: 6
#
# ✅ 处理完成: 183.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 184.txt
#    原始行数: 10
#    清理后行数: 5
#
# ✅ 处理完成: 185.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 186.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 187.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 188.txt
#    原始行数: 11
#    清理后行数: 7
#
# ✅ 处理完成: 189.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 19.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 190.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 191.txt
#    原始行数: 9
#    清理后行数: 7
#
# ✅ 处理完成: 192.txt
#    原始行数: 8
#    清理后行数: 6
#
# ✅ 处理完成: 193.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 194.txt
#    原始行数: 13
#    清理后行数: 6
#
# ✅ 处理完成: 195.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 196.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 197.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 198.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 199.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 2.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 20.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 200.txt
#    原始行数: 11
#    清理后行数: 8
#
# ✅ 处理完成: 201.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 202.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 203.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 204.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 205.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 206.txt
#    原始行数: 9
#    清理后行数: 7
#
# ✅ 处理完成: 207.txt
#    原始行数: 12
#    清理后行数: 5
#
# ✅ 处理完成: 208.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 209.txt
#    原始行数: 8
#    清理后行数: 7
#
# ✅ 处理完成: 21.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 210.txt
#    原始行数: 8
#    清理后行数: 5
#
# ✅ 处理完成: 211.txt
#    原始行数: 7
#    清理后行数: 7
#
# ✅ 处理完成: 212.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 213.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 214.txt
#    原始行数: 14
#    清理后行数: 8
#
# ✅ 处理完成: 215.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 216.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 217.txt
#    原始行数: 6
#    清理后行数: 5
#
# ✅ 处理完成: 218.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 219.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 22.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 220.txt
#    原始行数: 8
#    清理后行数: 5
#
# ✅ 处理完成: 221.txt
#    原始行数: 11
#    清理后行数: 7
#
# ✅ 处理完成: 222.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 223.txt
#    原始行数: 11
#    清理后行数: 7
#
# ✅ 处理完成: 224.txt
#    原始行数: 12
#    清理后行数: 6
#
# ✅ 处理完成: 225.txt
#    原始行数: 9
#    清理后行数: 7
#
# ✅ 处理完成: 226.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 227.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 228.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 229.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 23.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 230.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 231.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 232.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 233.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 234.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 235.txt
#    原始行数: 13
#    清理后行数: 6
#
# ✅ 处理完成: 236.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 237.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 238.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 239.txt
#    原始行数: 13
#    清理后行数: 7
#
# ✅ 处理完成: 24.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 240.txt
#    原始行数: 8
#    清理后行数: 7
#
# ✅ 处理完成: 241.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 242.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 243.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 244.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 245.txt
#    原始行数: 10
#    清理后行数: 5
#
# ✅ 处理完成: 246.txt
#    原始行数: 9
#    清理后行数: 8
#
# ✅ 处理完成: 247.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 248.txt
#    原始行数: 12
#    清理后行数: 6
#
# ✅ 处理完成: 249.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 25.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 250.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 251.txt
#    原始行数: 8
#    清理后行数: 6
#
# ✅ 处理完成: 252.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 253.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 254.txt
#    原始行数: 11
#    清理后行数: 5
#
# ✅ 处理完成: 255.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 256.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 257.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 258.txt
#    原始行数: 12
#    清理后行数: 6
#
# ✅ 处理完成: 259.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 26.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 260.txt
#    原始行数: 14
#    清理后行数: 7
#
# ✅ 处理完成: 261.txt
#    原始行数: 13
#    清理后行数: 7
#
# ✅ 处理完成: 262.txt
#    原始行数: 10
#    清理后行数: 5
#
# ✅ 处理完成: 263.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 264.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 265.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 266.txt
#    原始行数: 14
#    清理后行数: 9
#
# ✅ 处理完成: 267.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 268.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 269.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 27.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 270.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 271.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 272.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 273.txt
#    原始行数: 8
#    清理后行数: 6
#
# ✅ 处理完成: 274.txt
#    原始行数: 13
#    清理后行数: 6
#
# ✅ 处理完成: 275.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 276.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 277.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 278.txt
#    原始行数: 13
#    清理后行数: 8
#
# ✅ 处理完成: 279.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 28.txt
#    原始行数: 13
#    清理后行数: 8
#
# ✅ 处理完成: 280.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 281.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 282.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 283.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 284.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 285.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 286.txt
#    原始行数: 11
#    清理后行数: 7
#
# ✅ 处理完成: 287.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 288.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 289.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 29.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 290.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 291.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 292.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 293.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 294.txt
#    原始行数: 8
#    清理后行数: 7
#
# ✅ 处理完成: 295.txt
#    原始行数: 8
#    清理后行数: 5
#
# ✅ 处理完成: 296.txt
#    原始行数: 13
#    清理后行数: 6
#
# ✅ 处理完成: 297.txt
#    原始行数: 10
#    清理后行数: 5
#
# ✅ 处理完成: 298.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 299.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 3.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 30.txt
#    原始行数: 10
#    清理后行数: 7
#
# ✅ 处理完成: 300.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 301.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 302.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 303.txt
#    原始行数: 14
#    清理后行数: 8
#
# ✅ 处理完成: 304.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 305.txt
#    原始行数: 7
#    清理后行数: 5
#
# ✅ 处理完成: 306.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 307.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 308.txt
#    原始行数: 10
#    清理后行数: 5
#
# ✅ 处理完成: 309.txt
#    原始行数: 12
#    清理后行数: 8
#
# ✅ 处理完成: 31.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 310.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 311.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 312.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 313.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 314.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 315.txt
#    原始行数: 13
#    清理后行数: 6
#
# ✅ 处理完成: 316.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 317.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 318.txt
#    原始行数: 10
#    清理后行数: 7
#
# ✅ 处理完成: 319.txt
#    原始行数: 12
#    清理后行数: 6
#
# ✅ 处理完成: 32.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 320.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 321.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 322.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 323.txt
#    原始行数: 12
#    清理后行数: 5
#
# ✅ 处理完成: 324.txt
#    原始行数: 7
#    清理后行数: 5
#
# ✅ 处理完成: 325.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 326.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 327.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 328.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 329.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 33.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 330.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 331.txt
#    原始行数: 10
#    清理后行数: 5
#
# ✅ 处理完成: 34.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 35.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 36.txt
#    原始行数: 12
#    清理后行数: 6
#
# ✅ 处理完成: 37.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 38.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 39.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 4.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 40.txt
#    原始行数: 13
#    清理后行数: 7
#
# ✅ 处理完成: 41.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 42.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 43.txt
#    原始行数: 11
#    清理后行数: 7
#
# ✅ 处理完成: 44.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 45.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 46.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 47.txt
#    原始行数: 8
#    清理后行数: 6
#
# ✅ 处理完成: 48.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 49.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 5.txt
#    原始行数: 13
#    清理后行数: 6
#
# ✅ 处理完成: 50.txt
#    原始行数: 10
#    清理后行数: 5
#
# ✅ 处理完成: 51.txt
#    原始行数: 10
#    清理后行数: 7
#
# ✅ 处理完成: 52.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 53.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 54.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 55.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 56.txt
#    原始行数: 14
#    清理后行数: 8
#
# ✅ 处理完成: 57.txt
#    原始行数: 13
#    清理后行数: 7
#
# ✅ 处理完成: 58.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 59.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 6.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 60.txt
#    原始行数: 11
#    清理后行数: 5
#
# ✅ 处理完成: 61.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 62.txt
#    原始行数: 8
#    清理后行数: 6
#
# ✅ 处理完成: 63.txt
#    原始行数: 10
#    清理后行数: 7
#
# ✅ 处理完成: 64.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 65.txt
#    原始行数: 12
#    清理后行数: 8
#
# ✅ 处理完成: 66.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 67.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 68.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 69.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 7.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 70.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 71.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 72.txt
#    原始行数: 7
#    清理后行数: 6
#
# ✅ 处理完成: 73.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 74.txt
#    原始行数: 13
#    清理后行数: 6
#
# ✅ 处理完成: 75.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 76.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 77.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 78.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 79.txt
#    原始行数: 8
#    清理后行数: 6
#
# ✅ 处理完成: 8.txt
#    原始行数: 11
#    清理后行数: 8
#
# ✅ 处理完成: 80.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 81.txt
#    原始行数: 5
#    清理后行数: 5
#
# ✅ 处理完成: 82.txt
#    原始行数: 10
#    清理后行数: 6
#
# ✅ 处理完成: 83.txt
#    原始行数: 9
#    清理后行数: 7
#
# ✅ 处理完成: 84.txt
#    原始行数: 13
#    清理后行数: 7
#
# ✅ 处理完成: 85.txt
#    原始行数: 9
#    清理后行数: 6
#
# ✅ 处理完成: 86.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 87.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 88.txt
#    原始行数: 13
#    清理后行数: 6
#
# ✅ 处理完成: 89.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 9.txt
#    原始行数: 10
#    清理后行数: 8
#
# ✅ 处理完成: 90.txt
#    原始行数: 13
#    清理后行数: 6
#
# ✅ 处理完成: 91.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 92.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 93.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 94.txt
#    原始行数: 11
#    清理后行数: 6
#
# ✅ 处理完成: 95.txt
#    原始行数: 9
#    清理后行数: 5
#
# ✅ 处理完成: 96.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 97.txt
#    原始行数: 12
#    清理后行数: 7
#
# ✅ 处理完成: 98.txt
#    原始行数: 8
#    清理后行数: 6
#
# ✅ 处理完成: 99.txt
#    原始行数: 7
#    清理后行数: 6
#
# --------------------------------------------------
# 处理完成！
# 成功处理: 332 个文件
# 处理失败: 0 个文件
#
# 所有处理完成的文件保存在: C:\Users\zhuang\Desktop\Paddle\img\ocrtxt_normalized

# %% [markdown]
# CER

# %%
import os
import re
import Levenshtein

# 資料夾路徑
gt_dir = r"C:\Users\zhuang\Desktop\Paddle\img\id_card_ocr_texts"
pred_dir = r"C:\Users\zhuang\Desktop\Paddle\img\ocrtxt_normalized"

# 用來過濾空白與換行字元的函數
def clean_text(text):
    return re.sub(r'\s+', '', text)  # 移除所有空白、換行、Tab 等

# 統計變數
total_distance = 0
total_chars = 0
missing_pred_files = []

print("每個檔案的 CER 結果：\n")

for gt_filename in os.listdir(gt_dir):
    if not gt_filename.endswith(".txt"):
        continue

    # ground truth 檔名如：ocr_00000.txt -> 對應預測檔名：image_00000.txt
    index = gt_filename.replace("ocr_", "").replace(".txt", "")
    pred_filename = f"image_{index}.txt"

    gt_path = os.path.join(gt_dir, gt_filename)
    pred_path = os.path.join(pred_dir, pred_filename)

    if not os.path.exists(pred_path):
        missing_pred_files.append(pred_filename)
        continue

    with open(gt_path, "r", encoding="utf-8") as f_gt, open(pred_path, "r", encoding="utf-8") as f_pred:
        gt_text = clean_text(f_gt.read())
        pred_text = clean_text(f_pred.read())

        distance = Levenshtein.distance(pred_text, gt_text)
        char_count = len(gt_text)
        file_cer = distance / char_count if char_count > 0 else 0

        print(f"{gt_filename} 對應 {pred_filename}：CER = {file_cer:.4f}")

        total_distance += distance
        total_chars += char_count

# 輸出總 CER
if total_chars > 0:
    total_cer = total_distance / total_chars
    print(f"\n🔢 總 CER：{total_cer:.4f}")
else:
    print("❗ 無有效的 ground truth 字元可計算 CER。")

# 列出缺少預測檔案
if missing_pred_files:
    print("\n⚠️ 找不到以下預測檔案：")
    for f in missing_pred_files:
        print(f" - {f}")
# Out:
# 每個檔案的 CER 結果：
#
# ocr_00000.txt 對應 image_00000.txt：CER = 0.0250
# ocr_00002.txt 對應 image_00002.txt：CER = 0.1628
# ocr_00006.txt 對應 image_00006.txt：CER = 0.0556
# ocr_00007.txt 對應 image_00007.txt：CER = 0.0256
# ocr_00008.txt 對應 image_00008.txt：CER = 0.0000
# ocr_00012.txt 對應 image_00012.txt：CER = 0.0000
# ocr_00016.txt 對應 image_00016.txt：CER = 0.0256
# ocr_00018.txt 對應 image_00018.txt：CER = 0.0000
# ocr_00020.txt 對應 image_00020.txt：CER = 0.0000
# ocr_00021.txt 對應 image_00021.txt：CER = 0.1316
# ocr_00022.txt 對應 image_00022.txt：CER = 0.1282
# ocr_00023.txt 對應 image_00023.txt：CER = 0.0000
# ocr_00024.txt 對應 image_00024.txt：CER = 0.0000
# ocr_00025.txt 對應 image_00025.txt：CER = 0.1026
# ocr_00026.txt 對應 image_00026.txt：CER = 0.0238
# ocr_00027.txt 對應 image_00027.txt：CER = 0.0000
# ocr_00028.txt 對應 image_00028.txt：CER = 0.0000
# ocr_00030.txt 對應 image_00030.txt：CER = 0.0000
# ocr_00035.txt 對應 image_00035.txt：CER = 0.0000
# ocr_00036.txt 對應 image_00036.txt：CER = 0.0250
# ocr_00037.txt 對應 image_00037.txt：CER = 0.0222
# ocr_00040.txt 對應 image_00040.txt：CER = 0.0500
# ocr_00042.txt 對應 image_00042.txt：CER = 0.0455
# ocr_00046.txt 對應 image_00046.txt：CER = 0.0000
# ocr_00048.txt 對應 image_00048.txt：CER = 0.0000
# ocr_00049.txt 對應 image_00049.txt：CER = 0.0541
# ocr_00054.txt 對應 image_00054.txt：CER = 0.0263
# ocr_00056.txt 對應 image_00056.txt：CER = 0.0233
# ocr_00057.txt 對應 image_00057.txt：CER = 0.1538
# ocr_00059.txt 對應 image_00059.txt：CER = 0.0000
# ocr_00063.txt 對應 image_00063.txt：CER = 0.0000
# ocr_00064.txt 對應 image_00064.txt：CER = 0.0750
# ocr_00066.txt 對應 image_00066.txt：CER = 0.0256
# ocr_00067.txt 對應 image_00067.txt：CER = 0.0000
# ocr_00068.txt 對應 image_00068.txt：CER = 0.0256
# ocr_00069.txt 對應 image_00069.txt：CER = 0.0000
# ocr_00071.txt 對應 image_00071.txt：CER = 0.0000
# ocr_00073.txt 對應 image_00073.txt：CER = 0.0513
# ocr_00074.txt 對應 image_00074.txt：CER = 0.0000
# ocr_00076.txt 對應 image_00076.txt：CER = 0.1190
# ocr_00078.txt 對應 image_00078.txt：CER = 0.0000
# ocr_00082.txt 對應 image_00082.txt：CER = 0.2051
# ocr_00084.txt 對應 image_00084.txt：CER = 0.1892
# ocr_00087.txt 對應 image_00087.txt：CER = 0.0000
# ocr_00088.txt 對應 image_00088.txt：CER = 0.0233
# ocr_00089.txt 對應 image_00089.txt：CER = 0.0263
# ocr_00090.txt 對應 image_00090.txt：CER = 0.0256
# ocr_00094.txt 對應 image_00094.txt：CER = 0.0263
# ocr_00095.txt 對應 image_00095.txt：CER = 0.0870
# ocr_00096.txt 對應 image_00096.txt：CER = 0.0541
# ocr_00098.txt 對應 image_00098.txt：CER = 0.0000
# ocr_00099.txt 對應 image_00099.txt：CER = 0.0250
# ocr_00103.txt 對應 image_00103.txt：CER = 0.0526
# ocr_00105.txt 對應 image_00105.txt：CER = 0.0526
# ocr_00106.txt 對應 image_00106.txt：CER = 0.0227
# ocr_00110.txt 對應 image_00110.txt：CER = 0.0000
# ocr_00113.txt 對應 image_00113.txt：CER = 0.0250
# ocr_00114.txt 對應 image_00114.txt：CER = 0.1429
# ocr_00115.txt 對應 image_00115.txt：CER = 0.1000
# ocr_00116.txt 對應 image_00116.txt：CER = 0.0000
# ocr_00118.txt 對應 image_00118.txt：CER = 0.0000
# ocr_00119.txt 對應 image_00119.txt：CER = 0.0000
# ocr_00120.txt 對應 image_00120.txt：CER = 0.0256
# ocr_00121.txt 對應 image_00121.txt：CER = 0.0000
# ocr_00122.txt 對應 image_00122.txt：CER = 0.0000
# ocr_00123.txt 對應 image_00123.txt：CER = 0.0256
# ocr_00125.txt 對應 image_00125.txt：CER = 0.0000
# ocr_00129.txt 對應 image_00129.txt：CER = 0.0000
# ocr_00134.txt 對應 image_00134.txt：CER = 0.0000
# ocr_00137.txt 對應 image_00137.txt：CER = 0.0000
# ocr_00138.txt 對應 image_00138.txt：CER = 0.0930
# ocr_00142.txt 對應 image_00142.txt：CER = 0.0286
# ocr_00146.txt 對應 image_00146.txt：CER = 0.0526
# ocr_00149.txt 對應 image_00149.txt：CER = 0.0465
# ocr_00150.txt 對應 image_00150.txt：CER = 0.0000
# ocr_00152.txt 對應 image_00152.txt：CER = 0.0435
# ocr_00155.txt 對應 image_00155.txt：CER = 0.0000
# ocr_00157.txt 對應 image_00157.txt：CER = 0.0286
# ocr_00158.txt 對應 image_00158.txt：CER = 0.0256
# ocr_00161.txt 對應 image_00161.txt：CER = 0.0250
# ocr_00164.txt 對應 image_00164.txt：CER = 0.0000
# ocr_00167.txt 對應 image_00167.txt：CER = 0.0541
# ocr_00168.txt 對應 image_00168.txt：CER = 0.0526
# ocr_00173.txt 對應 image_00173.txt：CER = 0.0455
# ocr_00174.txt 對應 image_00174.txt：CER = 0.0000
# ocr_00175.txt 對應 image_00175.txt：CER = 0.0000
# ocr_00176.txt 對應 image_00176.txt：CER = 0.0000
# ocr_00181.txt 對應 image_00181.txt：CER = 0.0217
# ocr_00182.txt 對應 image_00182.txt：CER = 0.0513
# ocr_00185.txt 對應 image_00185.txt：CER = 0.0256
# ocr_00186.txt 對應 image_00186.txt：CER = 0.0217
# ocr_00188.txt 對應 image_00188.txt：CER = 0.0000
# ocr_00191.txt 對應 image_00191.txt：CER = 0.0000
# ocr_00193.txt 對應 image_00193.txt：CER = 0.0000
# ocr_00200.txt 對應 image_00200.txt：CER = 0.0000
# ocr_00203.txt 對應 image_00203.txt：CER = 0.0000
# ocr_00204.txt 對應 image_00204.txt：CER = 0.0000
# ocr_00206.txt 對應 image_00206.txt：CER = 0.0227
# ocr_00207.txt 對應 image_00207.txt：CER = 0.0500
# ocr_00208.txt 對應 image_00208.txt：CER = 0.0556
# ocr_00210.txt 對應 image_00210.txt：CER = 0.0000
# ocr_00212.txt 對應 image_00212.txt：CER = 0.0256
# ocr_00214.txt 對應 image_00214.txt：CER = 0.0000
# ocr_00215.txt 對應 image_00215.txt：CER = 0.0556
# ocr_00219.txt 對應 image_00219.txt：CER = 0.0233
# ocr_00220.txt 對應 image_00220.txt：CER = 0.0513
# ocr_00221.txt 對應 image_00221.txt：CER = 0.0952
# ocr_00223.txt 對應 image_00223.txt：CER = 0.0833
# ocr_00225.txt 對應 image_00225.txt：CER = 0.0233
# ocr_00226.txt 對應 image_00226.txt：CER = 0.0513
# ocr_00227.txt 對應 image_00227.txt：CER = 0.0263
# ocr_00231.txt 對應 image_00231.txt：CER = 0.0233
# ocr_00236.txt 對應 image_00236.txt：CER = 0.0513
# ocr_00238.txt 對應 image_00238.txt：CER = 0.0263
# ocr_00239.txt 對應 image_00239.txt：CER = 0.0513
# ocr_00240.txt 對應 image_00240.txt：CER = 0.0000
# ocr_00241.txt 對應 image_00241.txt：CER = 0.0526
# ocr_00244.txt 對應 image_00244.txt：CER = 0.0541
# ocr_00247.txt 對應 image_00247.txt：CER = 0.0541
# ocr_00248.txt 對應 image_00248.txt：CER = 0.0556
# ocr_00251.txt 對應 image_00251.txt：CER = 0.0286
# ocr_00254.txt 對應 image_00254.txt：CER = 0.0769
# ocr_00256.txt 對應 image_00256.txt：CER = 0.0000
# ocr_00258.txt 對應 image_00258.txt：CER = 0.0000
# ocr_00263.txt 對應 image_00263.txt：CER = 0.0769
# ocr_00265.txt 對應 image_00265.txt：CER = 0.0238
# ocr_00267.txt 對應 image_00267.txt：CER = 0.0526
# ocr_00268.txt 對應 image_00268.txt：CER = 0.0000
# ocr_00269.txt 對應 image_00269.txt：CER = 0.0000
# ocr_00270.txt 對應 image_00270.txt：CER = 0.0000
# ocr_00272.txt 對應 image_00272.txt：CER = 0.0256
# ocr_00273.txt 對應 image_00273.txt：CER = 0.0000
# ocr_00274.txt 對應 image_00274.txt：CER = 0.0000
# ocr_00275.txt 對應 image_00275.txt：CER = 0.0526
# ocr_00280.txt 對應 image_00280.txt：CER = 0.1053
# ocr_00286.txt 對應 image_00286.txt：CER = 0.0714
# ocr_00287.txt 對應 image_00287.txt：CER = 0.0000
# ocr_00289.txt 對應 image_00289.txt：CER = 0.0256
# ocr_00295.txt 對應 image_00295.txt：CER = 0.0256
# ocr_00296.txt 對應 image_00296.txt：CER = 0.0588
# ocr_00298.txt 對應 image_00298.txt：CER = 0.1250
# ocr_00300.txt 對應 image_00300.txt：CER = 0.0500
# ocr_00301.txt 對應 image_00301.txt：CER = 0.0000
# ocr_00303.txt 對應 image_00303.txt：CER = 0.0000
# ocr_00305.txt 對應 image_00305.txt：CER = 0.0476
# ocr_00307.txt 對應 image_00307.txt：CER = 0.0000
# ocr_00310.txt 對應 image_00310.txt：CER = 0.0526
# ocr_00313.txt 對應 image_00313.txt：CER = 0.0227
# ocr_00317.txt 對應 image_00317.txt：CER = 0.0000
# ocr_00318.txt 對應 image_00318.txt：CER = 0.0488
# ocr_00319.txt 對應 image_00319.txt：CER = 0.0278
# ocr_00320.txt 對應 image_00320.txt：CER = 0.0465
# ocr_00321.txt 對應 image_00321.txt：CER = 0.0000
# ocr_00322.txt 對應 image_00322.txt：CER = 0.0571
# ocr_00323.txt 對應 image_00323.txt：CER = 0.0513
# ocr_00326.txt 對應 image_00326.txt：CER = 0.0444
# ocr_00331.txt 對應 image_00331.txt：CER = 0.0000
# ocr_00333.txt 對應 image_00333.txt：CER = 0.0000
# ocr_00334.txt 對應 image_00334.txt：CER = 0.0000
# ocr_00337.txt 對應 image_00337.txt：CER = 0.0000
# ocr_00338.txt 對應 image_00338.txt：CER = 0.0769
# ocr_00339.txt 對應 image_00339.txt：CER = 0.0000
# ocr_00344.txt 對應 image_00344.txt：CER = 0.0000
# ocr_00346.txt 對應 image_00346.txt：CER = 0.0000
# ocr_00347.txt 對應 image_00347.txt：CER = 0.0000
# ocr_00348.txt 對應 image_00348.txt：CER = 0.0682
# ocr_00349.txt 對應 image_00349.txt：CER = 0.0000
# ocr_00355.txt 對應 image_00355.txt：CER = 0.0465
# ocr_00356.txt 對應 image_00356.txt：CER = 0.0000
# ocr_00360.txt 對應 image_00360.txt：CER = 0.0000
# ocr_00363.txt 對應 image_00363.txt：CER = 0.0000
# ocr_00364.txt 對應 image_00364.txt：CER = 0.0256
# ocr_00370.txt 對應 image_00370.txt：CER = 0.0000
# ocr_00371.txt 對應 image_00371.txt：CER = 0.0250
# ocr_00373.txt 對應 image_00373.txt：CER = 0.0571
# ocr_00378.txt 對應 image_00378.txt：CER = 0.0000
# ocr_00379.txt 對應 image_00379.txt：CER = 0.0000
# ocr_00380.txt 對應 image_00380.txt：CER = 0.0263
# ocr_00385.txt 對應 image_00385.txt：CER = 0.0556
# ocr_00387.txt 對應 image_00387.txt：CER = 0.0000
# ocr_00392.txt 對應 image_00392.txt：CER = 0.0000
# ocr_00394.txt 對應 image_00394.txt：CER = 0.1750
# ocr_00398.txt 對應 image_00398.txt：CER = 0.0000
# ocr_00400.txt 對應 image_00400.txt：CER = 0.0444
# ocr_00401.txt 對應 image_00401.txt：CER = 0.0000
# ocr_00405.txt 對應 image_00405.txt：CER = 0.0286
# ocr_00406.txt 對應 image_00406.txt：CER = 0.0000
# ocr_00407.txt 對應 image_00407.txt：CER = 0.0000
# ocr_00408.txt 對應 image_00408.txt：CER = 0.0000
# ocr_00409.txt 對應 image_00409.txt：CER = 0.0526
# ocr_00410.txt 對應 image_00410.txt：CER = 0.0000
# ocr_00411.txt 對應 image_00411.txt：CER = 0.0256
# ocr_00412.txt 對應 image_00412.txt：CER = 0.0270
# ocr_00413.txt 對應 image_00413.txt：CER = 0.0000
# ocr_00414.txt 對應 image_00414.txt：CER = 0.0000
# ocr_00415.txt 對應 image_00415.txt：CER = 0.0000
# ocr_00416.txt 對應 image_00416.txt：CER = 0.0217
# ocr_00417.txt 對應 image_00417.txt：CER = 0.0556
# ocr_00420.txt 對應 image_00420.txt：CER = 0.1026
# ocr_00421.txt 對應 image_00421.txt：CER = 0.0476
# ocr_00422.txt 對應 image_00422.txt：CER = 0.0500
# ocr_00423.txt 對應 image_00423.txt：CER = 0.0000
# ocr_00425.txt 對應 image_00425.txt：CER = 0.0769
# ocr_00426.txt 對應 image_00426.txt：CER = 0.0526
# ocr_00428.txt 對應 image_00428.txt：CER = 0.0000
# ocr_00429.txt 對應 image_00429.txt：CER = 0.0286
# ocr_00431.txt 對應 image_00431.txt：CER = 0.1000
# ocr_00432.txt 對應 image_00432.txt：CER = 0.0000
# ocr_00433.txt 對應 image_00433.txt：CER = 0.0000
# ocr_00434.txt 對應 image_00434.txt：CER = 0.0000
# ocr_00435.txt 對應 image_00435.txt：CER = 0.0000
# ocr_00436.txt 對應 image_00436.txt：CER = 0.0541
# ocr_00437.txt 對應 image_00437.txt：CER = 0.0238
# ocr_00438.txt 對應 image_00438.txt：CER = 0.0500
# ocr_00443.txt 對應 image_00443.txt：CER = 0.0256
# ocr_00444.txt 對應 image_00444.txt：CER = 0.0278
# ocr_00447.txt 對應 image_00447.txt：CER = 0.2051
# ocr_00449.txt 對應 image_00449.txt：CER = 0.0000
# ocr_00450.txt 對應 image_00450.txt：CER = 0.0000
# ocr_00451.txt 對應 image_00451.txt：CER = 0.0000
# ocr_00453.txt 對應 image_00453.txt：CER = 0.0278
# ocr_00455.txt 對應 image_00455.txt：CER = 0.0769
# ocr_00456.txt 對應 image_00456.txt：CER = 0.1842
# ocr_00457.txt 對應 image_00457.txt：CER = 0.0000
# ocr_00460.txt 對應 image_00460.txt：CER = 0.0455
# ocr_00461.txt 對應 image_00461.txt：CER = 0.0000
# ocr_00468.txt 對應 image_00468.txt：CER = 0.0526
# ocr_00469.txt 對應 image_00469.txt：CER = 0.1000
# ocr_00471.txt 對應 image_00471.txt：CER = 0.0000
# ocr_00477.txt 對應 image_00477.txt：CER = 0.0000
# ocr_00478.txt 對應 image_00478.txt：CER = 0.0444
# ocr_00480.txt 對應 image_00480.txt：CER = 0.0465
# ocr_00483.txt 對應 image_00483.txt：CER = 0.0000
# ocr_00491.txt 對應 image_00491.txt：CER = 0.2286
# ocr_00492.txt 對應 image_00492.txt：CER = 0.0000
# ocr_00493.txt 對應 image_00493.txt：CER = 0.0000
# ocr_00494.txt 對應 image_00494.txt：CER = 0.2564
# ocr_00497.txt 對應 image_00497.txt：CER = 0.0000
# ocr_00498.txt 對應 image_00498.txt：CER = 0.0000
# ocr_00499.txt 對應 image_00499.txt：CER = 0.0513
# ocr_00500.txt 對應 image_00500.txt：CER = 0.0000
# ocr_00501.txt 對應 image_00501.txt：CER = 0.0000
# ocr_00503.txt 對應 image_00503.txt：CER = 0.0000
# ocr_00504.txt 對應 image_00504.txt：CER = 0.0000
# ocr_00505.txt 對應 image_00505.txt：CER = 0.0000
# ocr_00506.txt 對應 image_00506.txt：CER = 0.0000
# ocr_00509.txt 對應 image_00509.txt：CER = 0.0256
# ocr_00510.txt 對應 image_00510.txt：CER = 0.0256
# ocr_00513.txt 對應 image_00513.txt：CER = 0.0000
# ocr_00515.txt 對應 image_00515.txt：CER = 0.0000
# ocr_00517.txt 對應 image_00517.txt：CER = 0.0513
# ocr_00521.txt 對應 image_00521.txt：CER = 0.0256
# ocr_00522.txt 對應 image_00522.txt：CER = 0.0000
# ocr_00526.txt 對應 image_00526.txt：CER = 0.0000
# ocr_00530.txt 對應 image_00530.txt：CER = 0.0000
# ocr_00531.txt 對應 image_00531.txt：CER = 0.0000
# ocr_00533.txt 對應 image_00533.txt：CER = 0.0263
# ocr_00538.txt 對應 image_00538.txt：CER = 0.0000
# ocr_00541.txt 對應 image_00541.txt：CER = 0.0250
# ocr_00542.txt 對應 image_00542.txt：CER = 0.0526
# ocr_00546.txt 對應 image_00546.txt：CER = 0.0286
# ocr_00547.txt 對應 image_00547.txt：CER = 0.0000
# ocr_00549.txt 對應 image_00549.txt：CER = 0.0000
# ocr_00552.txt 對應 image_00552.txt：CER = 0.0000
# ocr_00555.txt 對應 image_00555.txt：CER = 0.0256
# ocr_00557.txt 對應 image_00557.txt：CER = 0.0500
# ocr_00568.txt 對應 image_00568.txt：CER = 0.0222
# ocr_00569.txt 對應 image_00569.txt：CER = 0.0000
# ocr_00571.txt 對應 image_00571.txt：CER = 0.0526
# ocr_00572.txt 對應 image_00572.txt：CER = 0.0000
# ocr_00574.txt 對應 image_00574.txt：CER = 0.0000
# ocr_00576.txt 對應 image_00576.txt：CER = 0.1892
# ocr_00578.txt 對應 image_00578.txt：CER = 0.0000
# ocr_00580.txt 對應 image_00580.txt：CER = 0.0455
# ocr_00582.txt 對應 image_00582.txt：CER = 0.0217
# ocr_00585.txt 對應 image_00585.txt：CER = 0.0278
# ocr_00586.txt 對應 image_00586.txt：CER = 0.0488
# ocr_00587.txt 對應 image_00587.txt：CER = 0.0000
# ocr_00588.txt 對應 image_00588.txt：CER = 0.0513
# ocr_00590.txt 對應 image_00590.txt：CER = 0.0000
# ocr_00595.txt 對應 image_00595.txt：CER = 0.0278
# ocr_00597.txt 對應 image_00597.txt：CER = 0.0513
# ocr_00605.txt 對應 image_00605.txt：CER = 0.0000
# ocr_00606.txt 對應 image_00606.txt：CER = 0.0000
# ocr_00607.txt 對應 image_00607.txt：CER = 0.0256
# ocr_00610.txt 對應 image_00610.txt：CER = 0.0000
# ocr_00613.txt 對應 image_00613.txt：CER = 0.0263
# ocr_00614.txt 對應 image_00614.txt：CER = 0.0000
# ocr_00615.txt 對應 image_00615.txt：CER = 0.0513
# ocr_00616.txt 對應 image_00616.txt：CER = 0.0000
# ocr_00617.txt 對應 image_00617.txt：CER = 0.0000
# ocr_00618.txt 對應 image_00618.txt：CER = 0.0000
# ocr_00619.txt 對應 image_00619.txt：CER = 0.0769
# ocr_00621.txt 對應 image_00621.txt：CER = 0.0263
# ocr_00623.txt 對應 image_00623.txt：CER = 0.0488
# ocr_00624.txt 對應 image_00624.txt：CER = 0.0000
# ocr_00625.txt 對應 image_00625.txt：CER = 0.0000
# ocr_00628.txt 對應 image_00628.txt：CER = 0.0000
# ocr_00629.txt 對應 image_00629.txt：CER = 0.0233
# ocr_00630.txt 對應 image_00630.txt：CER = 0.0000
# ocr_00632.txt 對應 image_00632.txt：CER = 0.0000
# ocr_00633.txt 對應 image_00633.txt：CER = 0.0769
# ocr_00636.txt 對應 image_00636.txt：CER = 0.0000
# ocr_00639.txt 對應 image_00639.txt：CER = 0.1795
# ocr_00641.txt 對應 image_00641.txt：CER = 0.0500
# ocr_00642.txt 對應 image_00642.txt：CER = 0.0000
# ocr_00647.txt 對應 image_00647.txt：CER = 0.0256
# ocr_00648.txt 對應 image_00648.txt：CER = 0.0000
# ocr_00649.txt 對應 image_00649.txt：CER = 0.0278
# ocr_00653.txt 對應 image_00653.txt：CER = 0.0476
# ocr_00657.txt 對應 image_00657.txt：CER = 0.0526
# ocr_00659.txt 對應 image_00659.txt：CER = 0.0263
# ocr_00660.txt 對應 image_00660.txt：CER = 0.0233
# ocr_00664.txt 對應 image_00664.txt：CER = 0.0263
# ocr_00665.txt 對應 image_00665.txt：CER = 0.2273
# ocr_00666.txt 對應 image_00666.txt：CER = 0.0000
# ocr_00668.txt 對應 image_00668.txt：CER = 0.0256
# ocr_00669.txt 對應 image_00669.txt：CER = 0.0500
# ocr_00671.txt 對應 image_00671.txt：CER = 0.1304
# ocr_00675.txt 對應 image_00675.txt：CER = 0.0227
# ocr_00678.txt 對應 image_00678.txt：CER = 0.0444
# ocr_00679.txt 對應 image_00679.txt：CER = 0.0270
# ocr_00680.txt 對應 image_00680.txt：CER = 0.0435
# ocr_00682.txt 對應 image_00682.txt：CER = 0.0278
# ocr_00684.txt 對應 image_00684.txt：CER = 0.0000
# ocr_00687.txt 對應 image_00687.txt：CER = 0.1842
# ocr_00689.txt 對應 image_00689.txt：CER = 0.0000
# ocr_00691.txt 對應 image_00691.txt：CER = 0.0513
# ocr_00693.txt 對應 image_00693.txt：CER = 0.0000
# ocr_00694.txt 對應 image_00694.txt：CER = 0.0000
# ocr_00695.txt 對應 image_00695.txt：CER = 0.0270
# ocr_00697.txt 對應 image_00697.txt：CER = 0.0278
#
# 🔢 總 CER：0.0319
