# %% [markdown]
# 英文

# %%
from paddleocr_backup import PaddleOCR, draw_ocr
import os
import datetime # 導入 datetime 模組，用於生成時間戳

# 指定圖片路徑
image_path = r'C:\Users\User\Desktop\PaddleOCR\2.png'

# 檢查圖片是否存在
if not os.path.exists(image_path):
    print(f"錯誤：圖片文件 '{image_path}' 不存在。請檢查路徑是否正確。")
else:
    # 初始化 OCR 模型
    # lang='ch' 表示使用中文模型，'en' 表示英文，你也可以指定其他語言
    # use_gpu=True 表示使用 GPU，如果你的電腦沒有 GPU 或者沒有配置 CUDA，請設置為 False
    # use_angle_cls=True 表示使用方向分類器，可以識別圖片中文字的旋轉角度
    # 注意：你這裡設定了 lang="en"，如果你圖片裡是中文，請改為 lang="ch"
    ocr = PaddleOCR(use_angle_cls=True, lang="en", use_gpu=False)

    print(f"正在對圖片 '{image_path}' 執行 OCR 識別...")

    # 執行 OCR 識別
    result = ocr.ocr(image_path, cls=True)

    # 初始化一個列表來保存所有識別到的文字
    recognized_texts = []

    # 打印識別結果
    if result and result[0]:
        print("\nOCR 識別結果：")
        for line in result[0]:
            # line[0] 是文字框的座標
            text = line[1][0] # 識別出的文字
            confidence = line[1][1] # 置信度
            print(f"文字框座標: {line[0]}, 識別文字: '{text}', 置信度: {confidence:.2f}")
            recognized_texts.append(text) # 將識別到的文字添加到列表中

        # ----- 新增的程式碼：將識別結果保存到 .txt 文件 -----
        # 獲取圖片所在目錄
        output_dir = os.path.dirname(image_path)
        # 獲取當前時間戳，用於生成唯一的文件名
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        # 構造輸出文本文件的路徑
        # 文件名可以包含圖片名稱，並加上時間戳避免重複
        image_name_without_ext = os.path.splitext(os.path.basename(image_path))[0]
        output_text_filename = f"{image_name_without_ext}_ocr_result_{timestamp}.txt"
        output_text_path = os.path.join(output_dir, output_text_filename)

        try:
            with open(output_text_path, 'w', encoding='utf-8') as f:
                for text_line in recognized_texts:
                    f.write(text_line + '\n') # 每個識別到的文字後換行
            print(f"\nOCR 識別結果已保存到文本文件：{output_text_path}")
        except IOError as e:
            print(f"\n保存文本文件時發生錯誤: {e}")
        # ----------------------------------------------------

        # 可選：繪製識別結果並保存到圖片
        # 你需要安裝 OpenCV 和 Pillow 來使用這個功能： pip install opencv-python Pillow
        try:
            from PIL import Image
            img = Image.open(image_path).convert('RGB')
            boxes = [line[0] for line in result[0]]
            txts = [line[1][0] for line in result[0]]
            scores = [line[1][1] for line in result[0]]

            # ----- 修正點：請確保 font_path 指向一個有效的、支持中文的字體文件 -----
            # 在 Windows 上，字體文件通常在 C:\Windows\Fonts\
            # 以下是一些常見的中文字體路徑，請根據你系統中實際存在的字體進行選擇
            # 推薦使用微軟雅黑 (msyh.ttc)，因為它在多數 Windows 系統上都有且顯示效果好
            font_path_for_drawing = r'C:\Windows\Fonts\msyh.ttc' # <--- 請檢查此路徑在你系統中是否存在！
            # 範例：如果你有仿宋字體，可以使用 r'C:\Windows\Fonts\simfang.ttf'
            # 範例：如果你是英文內容且沒有中文字體，可以省略 font_path 參數，它會使用 PaddleOCR 內建的預設字體

            # 將圖片繪製到新的圖片上
            im_show = draw_ocr(img, boxes, txts, scores, font_path=font_path_for_drawing)
            
            # 定義輸出圖片路徑，包含時間戳以避免覆蓋
            output_image_filename = f"{image_name_without_ext}_ocr_visual_{timestamp}.jpg"
            output_image_path = os.path.join(output_dir, output_image_filename)
            
            im_show = Image.fromarray(im_show)
            im_show.save(output_image_path)
            print(f"\n識別結果已保存到可視化圖片：{output_image_path}")

        except ImportError:
            print("\n警告：無法繪製識別結果。請安裝 'opencv-python' 和 'Pillow' 庫 (pip install opencv-python Pillow)。")
        except FileNotFoundError:
            print(f"\n錯誤：繪製圖片時找不到字體文件。請檢查 font_path: '{font_path_for_drawing}' 是否正確。")
        except Exception as e:
            print(f"\n繪製結果時發生未知錯誤: {e}")
    else:
        print("未在圖片中識別到任何文字。")

print("\nOCR 測試完成。")
# Out:
# [2025/05/11 23:40:25] ppocr DEBUG: Namespace(alpha=1.0, alphacolor=(255, 255, 255), benchmark=False, beta=1.0, binarize=False, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='C:\\Users\\User/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='C:\\Users\\User/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, formula=False, formula_algorithm='LaTeXOCR', formula_batch_num=1, formula_char_dict_path=None, formula_model_dir=None, fourier_degree=5, gpu_id=0, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, invert=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='en', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv4', onnx_providers=False, onnx_sess_options=False, output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='c:\\Users\\User\\anaconda3\\envs\\pytorch_env\\lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='C:\\Users\\User/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', recovery=False, recovery_to_markdown=False, return_word_box=False, save_crop_res=False, save_log_path='./log_output/', savefile=False, scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=True, use_dilation=False, use_gcu=False, use_gpu=False, use_mlu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# 正在對圖片 'C:\Users\User\Desktop\PaddleOCR\2.png' 執行 OCR 識別...
# [2025/05/11 23:40:28] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.2828524112701416
# [2025/05/11 23:40:28] ppocr DEBUG: cls num  : 2, elapsed : 0.10084939002990723
# [2025/05/11 23:40:28] ppocr DEBUG: rec_res num  : 2, elapsed : 0.4053843021392822
#
# OCR 識別結果：
# 文字框座標: [[26.0, 59.0], [1657.0, 63.0], [1657.0, 132.0], [26.0, 128.0]], 識別文字: 'Tom is watering the flowers in his garden', 置信度: 1.00
# 文字框座標: [[30.0, 326.0], [808.0, 335.0], [807.0, 398.0], [30.0, 389.0]], 識別文字: 'The books are new..', 置信度: 0.99
#
# OCR 識別結果已保存到文本文件：C:\Users\User\Desktop\PaddleOCR\2_ocr_result_20250511_234028.txt
#
# 識別結果已保存到可視化圖片：C:\Users\User\Desktop\PaddleOCR\2_ocr_visual_20250511_234028.jpg
#
# OCR 測試完成。

# %% [markdown]
# 中文

# %%
from paddleocr_backup import PaddleOCR, draw_ocr
import os
import datetime # 導入 datetime 模組，用於生成時間戳

# 指定圖片路徑
image_path = r'C:\Users\User\Desktop\PaddleOCR\3.png'

# 檢查圖片是否存在
if not os.path.exists(image_path):
    print(f"錯誤：圖片文件 '{image_path}' 不存在。請檢查路徑是否正確。")
else:
    # 初始化 OCR 模型
    # lang='ch' 表示使用中文模型，'en' 表示英文，你也可以指定其他語言
    # use_gpu=True 表示使用 GPU，如果你的電腦沒有 GPU 或者沒有配置 CUDA，請設置為 False
    # use_angle_cls=True 表示使用方向分類器，可以識別圖片中文字的旋轉角度
    # 注意：你這裡設定了 lang="en"，如果你圖片裡是中文，請改為 lang="ch"
    ocr = PaddleOCR(use_angle_cls=True, lang="ch", use_gpu=False)

    print(f"正在對圖片 '{image_path}' 執行 OCR 識別...")

    # 執行 OCR 識別
    result = ocr.ocr(image_path, cls=True)

    # 初始化一個列表來保存所有識別到的文字
    recognized_texts = []

    # 打印識別結果
    if result and result[0]:
        print("\nOCR 識別結果：")
        for line in result[0]:
            # line[0] 是文字框的座標
            text = line[1][0] # 識別出的文字
            confidence = line[1][1] # 置信度
            print(f"文字框座標: {line[0]}, 識別文字: '{text}', 置信度: {confidence:.2f}")
            recognized_texts.append(text) # 將識別到的文字添加到列表中

        # ----- 新增的程式碼：將識別結果保存到 .txt 文件 -----
        # 獲取圖片所在目錄
        output_dir = os.path.dirname(image_path)
        # 獲取當前時間戳，用於生成唯一的文件名
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        # 構造輸出文本文件的路徑
        # 文件名可以包含圖片名稱，並加上時間戳避免重複
        image_name_without_ext = os.path.splitext(os.path.basename(image_path))[0]
        output_text_filename = f"{image_name_without_ext}_ocr_result_{timestamp}.txt"
        output_text_path = os.path.join(output_dir, output_text_filename)

        try:
            with open(output_text_path, 'w', encoding='utf-8') as f:
                for text_line in recognized_texts:
                    f.write(text_line + '\n') # 每個識別到的文字後換行
            print(f"\nOCR 識別結果已保存到文本文件：{output_text_path}")
        except IOError as e:
            print(f"\n保存文本文件時發生錯誤: {e}")
        # ----------------------------------------------------

        # 可選：繪製識別結果並保存到圖片
        # 你需要安裝 OpenCV 和 Pillow 來使用這個功能： pip install opencv-python Pillow
        try:
            from PIL import Image
            img = Image.open(image_path).convert('RGB')
            boxes = [line[0] for line in result[0]]
            txts = [line[1][0] for line in result[0]]
            scores = [line[1][1] for line in result[0]]

            # ----- 修正點：請確保 font_path 指向一個有效的、支持中文的字體文件 -----
            # 在 Windows 上，字體文件通常在 C:\Windows\Fonts\
            # 以下是一些常見的中文字體路徑，請根據你系統中實際存在的字體進行選擇
            # 推薦使用微軟雅黑 (msyh.ttc)，因為它在多數 Windows 系統上都有且顯示效果好
            font_path_for_drawing = r'C:\Windows\Fonts\msyh.ttc' # <--- 請檢查此路徑在你系統中是否存在！
            # 範例：如果你有仿宋字體，可以使用 r'C:\Windows\Fonts\simfang.ttf'
            # 範例：如果你是英文內容且沒有中文字體，可以省略 font_path 參數，它會使用 PaddleOCR 內建的預設字體

            # 將圖片繪製到新的圖片上
            im_show = draw_ocr(img, boxes, txts, scores, font_path=font_path_for_drawing)
            
            # 定義輸出圖片路徑，包含時間戳以避免覆蓋
            output_image_filename = f"{image_name_without_ext}_ocr_visual_{timestamp}.jpg"
            output_image_path = os.path.join(output_dir, output_image_filename)
            
            im_show = Image.fromarray(im_show)
            im_show.save(output_image_path)
            print(f"\n識別結果已保存到可視化圖片：{output_image_path}")

        except ImportError:
            print("\n警告：無法繪製識別結果。請安裝 'opencv-python' 和 'Pillow' 庫 (pip install opencv-python Pillow)。")
        except FileNotFoundError:
            print(f"\n錯誤：繪製圖片時找不到字體文件。請檢查 font_path: '{font_path_for_drawing}' 是否正確。")
        except Exception as e:
            print(f"\n繪製結果時發生未知錯誤: {e}")
    else:
        print("未在圖片中識別到任何文字。")

print("\nOCR 測試完成。")
# Out:
# [2025/05/11 23:42:26] ppocr DEBUG: Namespace(alpha=1.0, alphacolor=(255, 255, 255), benchmark=False, beta=1.0, binarize=False, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='C:\\Users\\User/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='C:\\Users\\User/.paddleocr/whl\\det\\ch\\ch_PP-OCRv4_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, formula=False, formula_algorithm='LaTeXOCR', formula_batch_num=1, formula_char_dict_path=None, formula_model_dir=None, fourier_degree=5, gpu_id=0, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, invert=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='ch', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv4', onnx_providers=False, onnx_sess_options=False, output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='c:\\Users\\User\\anaconda3\\envs\\pytorch_env\\lib\\site-packages\\paddleocr\\ppocr\\utils\\ppocr_keys_v1.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='C:\\Users\\User/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv4_rec_infer', recovery=False, recovery_to_markdown=False, return_word_box=False, save_crop_res=False, save_log_path='./log_output/', savefile=False, scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=True, use_dilation=False, use_gcu=False, use_gpu=False, use_mlu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# 正在對圖片 'C:\Users\User\Desktop\PaddleOCR\3.png' 執行 OCR 識別...
# [2025/05/11 23:42:28] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.3685154914855957
# [2025/05/11 23:42:28] ppocr DEBUG: cls num  : 6, elapsed : 0.031264543533325195
# [2025/05/11 23:42:29] ppocr DEBUG: rec_res num  : 6, elapsed : 0.5215065479278564
#
# OCR 識別結果：
# 文字框座標: [[144.0, 21.0], [887.0, 15.0], [888.0, 75.0], [144.0, 80.0]], 識別文字: '我是一個愛寧靜的人：', 置信度: 0.87
# 文字框座標: [[10.0, 124.0], [902.0, 120.0], [902.0, 180.0], [10.0, 184.0]], 識別文字: '所以我最怕嘈吵的聲音。每', 置信度: 0.96
# 文字框座標: [[12.0, 228.0], [905.0, 228.0], [905.0, 286.0], [12.0, 286.0]], 識別文字: '当我专心地寫字和看書的时', 置信度: 0.90
# 文字框座標: [[10.0, 329.0], [906.0, 329.0], [906.0, 388.0], [10.0, 388.0]], 識別文字: '候，窗外突然传來嘈吵的汽', 置信度: 0.95
# 文字框座標: [[10.0, 433.0], [901.0, 433.0], [901.0, 492.0], [10.0, 492.0]], 識別文字: '車喇叭聲，都會啸得我連心', 置信度: 0.94
# 文字框座標: [[11.0, 538.0], [714.0, 540.0], [714.0, 596.0], [11.0, 594.0]], 識別文字: '藏也差點跳了出來呢！', 置信度: 0.97
#
# OCR 識別結果已保存到文本文件：C:\Users\User\Desktop\PaddleOCR\3_ocr_result_20250511_234229.txt
#
# 識別結果已保存到可視化圖片：C:\Users\User\Desktop\PaddleOCR\3_ocr_visual_20250511_234229.jpg
#
# OCR 測試完成。

# %% [markdown]
# 測Images資料夾前十張照片存到ocr資料夾

# %%
from paddleocr_backup import PaddleOCR, draw_ocr
import os
import datetime
from PIL import Image

# 指定圖片資料夾路徑
images_folder = r'C:\Users\User\Desktop\PaddleOCR\images'

# 指定輸出資料夾路徑
output_folder = r'C:\Users\User\Desktop\PaddleOCR\ocr'

# 指定要處理的圖片數量
num_images_to_process = 10

# 確保輸出資料夾存在，如果不存在則創建
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"已創建輸出資料夾：{output_folder}")

# 確保圖片資料夾存在
if not os.path.exists(images_folder):
    print(f"錯誤：圖片資料夾 '{images_folder}' 不存在。請檢查路徑是否正確。")
else:
    # 獲取資料夾中的所有圖片文件
    all_files = os.listdir(images_folder)
    image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))]

    if not image_files:
        print(f"錯誤：圖片資料夾 '{images_folder}' 中沒有找到任何圖片文件。")
    else:
        # 初始化 OCR 模型
        # 注意：這裡仍然設定了 lang="en"，如果你的圖片是中文，請改為 lang="ch"
        ocr = PaddleOCR(use_angle_cls=True, lang="en", use_gpu=False)

        print(f"即將對資料夾 '{images_folder}' 中的前 {min(num_images_to_process, len(image_files))} 張圖片執行 OCR 識別...")

        # 處理前 N 張圖片
        for i, image_file in enumerate(image_files[:num_images_to_process]):
            image_path = os.path.join(images_folder, image_file)
            print(f"\n正在處理圖片 '{image_path}'...")

            # 執行 OCR 識別
            result = ocr.ocr(image_path, cls=True)

            # 初始化一個列表來保存所有識別到的文字
            recognized_texts = []

            # 打印識別結果
            if result and result[0]:
                print("OCR 識別結果：")
                for line in result[0]:
                    text = line[1][0]
                    confidence = line[1][1]
                    print(f"文字框座標: {line[0]}, 識別文字: '{text}', 置信度: {confidence:.2f}")
                    recognized_texts.append(text)

                # ----- 保存識別結果到 .txt 文件 -----
                image_name_without_ext = os.path.splitext(image_file)[0]
                output_text_filename = f"{image_name_without_ext}.txt"
                output_text_path = os.path.join(output_folder, output_text_filename)

                try:
                    with open(output_text_path, 'w', encoding='utf-8') as f:
                        for text_line in recognized_texts:
                            f.write(text_line + '\n')
                    print(f"OCR 識別結果已保存到文本文件：{output_text_path}")
                except IOError as e:
                    print(f"保存文本文件時發生錯誤: {e}")
                # ----------------------------------------------------

                # ----- 可選：繪製識別結果並保存到圖片 -----
                try:
                    img = Image.open(image_path).convert('RGB')
                    boxes = [line[0] for line in result[0]]
                    txts = [line[1][0] for line in result[0]]
                    scores = [line[1][1] for line in result[0]]

                    font_path_for_drawing = r'C:\Windows\Fonts\msyh.ttc'  # <--- 請檢查此路徑在你系統中是否存在！

                    im_show = draw_ocr(img, boxes, txts, scores, font_path=font_path_for_drawing)

                    output_image_filename = f"{image_name_without_ext}_ocr.jpg"
                    output_image_path = os.path.join(output_folder, output_image_filename)

                    im_show = Image.fromarray(im_show)
                    im_show.save(output_image_path)
                    print(f"識別結果已保存到可視化圖片：{output_image_path}")

                except ImportError:
                    print("警告：無法繪製識別結果。請安裝 'opencv-python' 和 'Pillow' 庫 (pip install opencv-python Pillow)。")
                except FileNotFoundError:
                    print(f"錯誤：繪製圖片時找不到字體文件。請檢查 font_path: '{font_path_for_drawing}' 是否正確。")
                except Exception as e:
                    print(f"繪製結果時發生未知錯誤: {e}")
            else:
                print("未在圖片中識別到任何文字。")

            if i + 1 == num_images_to_process:
                break

print("\nOCR 測試完成。")
# Out:
# [2025/05/11 22:13:31] ppocr DEBUG: Namespace(alpha=1.0, alphacolor=(255, 255, 255), benchmark=False, beta=1.0, binarize=False, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='C:\\Users\\User/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='C:\\Users\\User/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, formula=False, formula_algorithm='LaTeXOCR', formula_batch_num=1, formula_char_dict_path=None, formula_model_dir=None, fourier_degree=5, gpu_id=0, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, invert=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='en', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv4', onnx_providers=False, onnx_sess_options=False, output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='c:\\Users\\User\\anaconda3\\envs\\pytorch_env\\lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='C:\\Users\\User/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', recovery=False, recovery_to_markdown=False, return_word_box=False, save_crop_res=False, save_log_path='./log_output/', savefile=False, scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=True, use_dilation=False, use_gcu=False, use_gpu=False, use_mlu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# 即將對資料夾 'C:\Users\User\Desktop\PaddleOCR\images' 中的前 10 張圖片執行 OCR 識別...
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\train_image_0.png'...
# [2025/05/11 22:13:34] ppocr DEBUG: dt_boxes num : 29, elapsed : 0.36646008491516113
# [2025/05/11 22:13:34] ppocr DEBUG: cls num  : 29, elapsed : 0.17530512809753418
# [2025/05/11 22:13:37] ppocr DEBUG: rec_res num  : 29, elapsed : 2.832563877105713
# OCR 識別結果：
# 文字框座標: [[756.0, 497.0], [1343.0, 507.0], [1342.0, 556.0], [755.0, 545.0]], 識別文字: 'Po rozpoczeciu typowo angiel', 置信度: 0.98
# 文字框座標: [[711.0, 550.0], [1346.0, 560.0], [1345.0, 609.0], [711.0, 599.0]], 識別文字: 'skiej kampanii prasowej, w ktorej', 置信度: 0.96
# 文字框座標: [[706.0, 604.0], [1343.0, 611.0], [1343.0, 655.0], [706.0, 648.0]], 識別文字: 'Dunczycy nazywani sa Wikingami', 置信度: 0.96
# 文字框座標: [[707.0, 655.0], [1343.0, 668.0], [1343.0, 709.0], [706.0, 696.0]], 識別文字: 'i wscieklymi psami o wygladzie pit-', 置信度: 0.95
# 文字框座標: [[707.0, 704.0], [1341.0, 716.0], [1340.0, 765.0], [706.0, 752.0]], 識別文字: 'bullow i knajpianych wykidajlow,', 置信度: 0.98
# 文字框座標: [[707.0, 755.0], [1336.0, 767.0], [1335.0, 816.0], [706.0, 803.0]], 識別文字: 'dunskie gazety zaczely ripostowac.', 置信度: 0.98
# 文字框座標: [[753.0, 811.0], [1336.0, 823.0], [1335.0, 865.0], [752.0, 852.0]], 識別文字: 'Dla dunskich kibicow Stig To', 置信度: 0.96
# 文字框座標: [[712.0, 859.0], [1336.0, 872.0], [1335.0, 921.0], [711.0, 908.0]], 識別文字: 'eftingi Jesper Gronkjaer to wspol', 置信度: 0.96
# 文字框座標: [[707.0, 915.0], [1336.0, 928.0], [1335.0, 970.0], [706.0, 957.0]], 識別文字: 'czesni Wikingowie,ktorzy przed ty', 置信度: 0.96
# 文字框座標: [[704.0, 967.0], [1336.0, 977.0], [1335.0, 1021.0], [703.0, 1010.0]], 識別文字: 'siacem lat podbijali Anglie i siali na', 置信度: 0.95
# 文字框座標: [[704.0, 1020.0], [1333.0, 1028.0], [1333.0, 1072.0], [703.0, 1064.0]], 識別文字: 'wyspach strach.Zabijali,gwalcili ira', 置信度: 0.95
# 文字框座標: [[702.0, 1069.0], [1336.0, 1079.0], [1335.0, 1123.0], [701.0, 1113.0]], 識別文字: 'bowali. Ich sila,miesnie i twarze byc', 置信度: 0.94
# 文字框座標: [[699.0, 1122.0], [1331.0, 1135.0], [1330.0, 1179.0], [698.0, 1166.0]], 識別文字: 'moze w podobny sposob przestra', 置信度: 0.96
# 文字框座標: [[699.0, 1171.0], [1331.0, 1184.0], [1330.0, 1233.0], [698.0, 1220.0]], 識別文字: 'sza Anglikow,ktorzy musza czuc re', 置信度: 0.95
# 文字框座標: [[697.0, 1225.0], [1333.0, 1233.0], [1333.0, 1281.0], [696.0, 1274.0]], 識別文字: 'spekt po wygranej nad Francja.Toe-', 置信度: 0.96
# 文字框座標: [[697.0, 1273.0], [1331.0, 1289.0], [1330.0, 1337.0], [696.0, 1322.0]], 識別文字: 'fting i spolka to twardziele, ktorzy', 置信度: 0.94
# 文字框座標: [[697.0, 1332.0], [1329.0, 1342.0], [1328.0, 1384.0], [696.0, 1373.0]], 識別文字: 'nie przestrasza sie podobno twar-', 置信度: 0.95
# 文字框座標: [[692.0, 1378.0], [1329.0, 1388.0], [1328.0, 1437.0], [691.0, 1427.0]], 識別文字: 'dej gry Anglikow. Ma bye odwrot', 置信度: 0.95
# 文字框座標: [[694.0, 1434.0], [1326.0, 1444.0], [1325.0, 1488.0], [693.0, 1478.0]], 識別文字: 'nie, to Toefting wystapi w roli rudo', 置信度: 0.96
# 文字框座標: [[690.0, 1478.0], [1208.0, 1493.0], [1207.0, 1542.0], [688.0, 1527.0]], 識別文字: 'brodego.krwawego Wikinga', 置信度: 0.98
# 文字框座標: [[736.0, 1534.0], [1324.0, 1547.0], [1323.0, 1596.0], [735.0, 1583.0]], 識別文字: 'Dania ma swoj styl.To kraj, ktory', 置信度: 0.96
# 文字框座標: [[692.0, 1588.0], [1326.0, 1600.0], [1325.0, 1644.0], [691.0, 1631.0]], 識別文字: 'powiedzial wspolnej walucie euro', 置信度: 0.96
# 文字框座標: [[689.0, 1636.0], [1326.0, 1649.0], [1325.0, 1698.0], [688.0, 1685.0]], 識別文字: 'NIE, poniewaz ma swoj honor.Zycie', 置信度: 0.96
# 文字框座標: [[689.0, 1692.0], [1321.0, 1708.0], [1320.0, 1749.0], [688.0, 1734.0]], 識別文字: 'na wesolo preferuja Dunczycy,kto', 置信度: 0.96
# 文字框座標: [[687.0, 1743.0], [1321.0, 1754.0], [1320.0, 1805.0], [686.0, 1795.0]], 識別文字: 'rzy sa jedna noga w Unii Europej', 置信度: 0.96
# 文字框座標: [[687.0, 1792.0], [1321.0, 1807.0], [1320.0, 1856.0], [686.0, 1841.0]], 識別文字: 'skiej, z tanim, dobrym jedzeniem', 置信度: 0.95
# 文字框座標: [[685.0, 1846.0], [1319.0, 1861.0], [1318.0, 1905.0], [683.0, 1890.0]], 識別文字: 'i alkoholem,a druga w Unii Nordyc', 置信度: 0.93
# 文字框座標: [[680.0, 1897.0], [1319.0, 1912.0], [1318.0, 1961.0], [679.0, 1946.0]], 識別文字: 'kiej ze slynnymi swiadczeniami so-', 置信度: 0.99
# 文字框座標: [[678.0, 1948.0], [852.0, 1954.0], [850.0, 2002.0], [676.0, 1997.0]], 識別文字: 'cjalnymi.', 置信度: 0.95
# OCR 識別結果已保存到文本文件：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_0.txt
# 識別結果已保存到可視化圖片：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_0_ocr.jpg
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\train_image_1.png'...
# [2025/05/11 22:13:38] ppocr DEBUG: dt_boxes num : 43, elapsed : 0.37689661979675293
# [2025/05/11 22:13:38] ppocr DEBUG: cls num  : 43, elapsed : 0.25829076766967773
# [2025/05/11 22:13:41] ppocr DEBUG: rec_res num  : 43, elapsed : 3.4896607398986816
# OCR 識別結果：
# 文字框座標: [[563.0, 20.0], [1082.0, 20.0], [1082.0, 61.0], [563.0, 61.0]], 識別文字: 'Catkowite zacmienie Ksiezy-', 置信度: 0.97
# 文字框座標: [[1145.0, 17.0], [1669.0, 12.0], [1669.0, 54.0], [1145.0, 59.0]], 識別文字: 'nie podat jednak, o jaki oby-', 置信度: 0.93
# 文字框座標: [[563.0, 74.0], [1087.0, 71.0], [1087.0, 113.0], [563.0, 116.0]], 識別文字: 'ca,ktore we wtorek wieczo-', 置信度: 0.95
# 文字框座標: [[1145.0, 69.0], [1676.0, 64.0], [1676.0, 106.0], [1145.0, 111.0]], 識別文字: 'czaj chodzi.Lokalny mufti', 置信度: 0.95
# 文字框座標: [[558.0, 130.0], [1091.0, 120.0], [1092.0, 162.0], [558.0, 172.0]], 識別文字: 'remmogliobserwowac', 置信度: 0.98
# 文字框座標: [[1148.0, 121.0], [1669.0, 121.0], [1669.0, 162.0], [1148.0, 162.0]], 識別文字: 'Mehmet Baris wyjasnia nato', 置信度: 0.97
# 文字框座標: [[560.0, 180.0], [1091.0, 175.0], [1092.0, 216.0], [561.0, 222.0]], 識別文字: 'mieszkancy Europy, Afryki', 置信度: 0.95
# 文字框座標: [[1143.0, 175.0], [1674.0, 170.0], [1674.0, 211.0], [1143.0, 217.0]], 識別文字: 'miast, ze zwyczaj strzelania', 置信度: 0.94
# 文字框座標: [[560.0, 231.0], [1082.0, 231.0], [1082.0, 273.0], [560.0, 273.0]], 識別文字: 'i Azji,wzbudzito ogromne za', 置信度: 0.95
# 文字框座標: [[1147.0, 229.0], [1676.0, 221.0], [1676.0, 263.0], [1148.0, 271.0]], 識別文字: 'do Ksiezyca nie jest w zaden', 置信度: 0.95
# 文字框座標: [[558.0, 281.0], [1094.0, 275.0], [1094.0, 325.0], [558.0, 330.0]], 識別文字: 'interesowanienie tylko', 置信度: 0.95
# 文字框座標: [[1143.0, 278.0], [1681.0, 273.0], [1681.0, 322.0], [1143.0, 327.0]], 識別文字: 'sposob zwiazany z religia', 置信度: 0.96
# 文字框座標: [[558.0, 335.0], [1082.0, 332.0], [1082.0, 376.0], [558.0, 379.0]], 識別文字: 'wsrod mitosnikow astrono', 置信度: 0.97
# 文字框座標: [[1147.0, 332.0], [1678.0, 327.0], [1679.0, 369.0], [1148.0, 374.0]], 識別文字: 'muzutmanska.Jegozdaniem', 置信度: 0.99
# 文字框座標: [[565.0, 386.0], [1089.0, 386.0], [1089.0, 428.0], [565.0, 428.0]], 識別文字: 'mii. W srode turecka policja', 置信度: 0.94
# 文字框座標: [[1147.0, 384.0], [1678.0, 376.0], [1679.0, 421.0], [1148.0, 428.0]], 識別文字: 'mezczyzni strzelali w niebo', 置信度: 0.96
# 文字框座標: [[565.0, 443.0], [1091.0, 438.0], [1092.0, 480.0], [566.0, 485.0]], 識別文字: 'aresztowata bowiem osmiu', 置信度: 0.95
# 文字框座標: [[1147.0, 436.0], [1678.0, 428.0], [1679.0, 477.0], [1148.0, 485.0]], 識別文字: 'po prostu dlatego,ze bali sie', 置信度: 0.93
# 文字框座標: [[1148.0, 487.0], [1350.0, 487.0], [1350.0, 531.0], [1148.0, 531.0]], 識別文字: 'zacmienia.', 置信度: 0.99
# 文字框座標: [[565.0, 497.0], [1091.0, 489.0], [1092.0, 531.0], [566.0, 539.0]], 識別文字: 'mezczyzn, ktorzy... strzelali', 置信度: 0.92
# 文字框座標: [[565.0, 544.0], [1089.0, 539.0], [1089.0, 588.0], [566.0, 593.0]], 識別文字: 'do zaprzyjaznionego z Zie', 置信度: 0.96
# 文字框座標: [[1150.0, 541.0], [1681.0, 536.0], [1681.0, 578.0], [1150.0, 583.0]], 識別文字: 'Nie tylko jednak niefortunni', 置信度: 0.98
# 文字框座標: [[568.0, 600.0], [989.0, 600.0], [989.0, 642.0], [568.0, 642.0]], 識別文字: 'mia ciata niebieskiego.', 置信度: 0.97
# 文字框座標: [[1155.0, 595.0], [1684.0, 595.0], [1684.0, 637.0], [1155.0, 637.0]], 識別文字: 'strzelcy drzeli tej nocy ze', 置信度: 0.94
# 文字框座標: [[568.0, 649.0], [1092.0, 649.0], [1092.0, 691.0], [568.0, 691.0]], 識別文字: 'Do tego bezprecedensowego', 置信度: 0.98
# 文字框座標: [[1152.0, 647.0], [1676.0, 647.0], [1676.0, 689.0], [1152.0, 689.0]], 識別文字: 'strachu.Kanonada w ich wy-', 置信度: 0.98
# 文字框座標: [[568.0, 701.0], [1091.0, 699.0], [1092.0, 748.0], [568.0, 750.0]], 識別文字: 'aktu agresji doszto w miej-', 置信度: 0.94
# 文字框座標: [[1150.0, 701.0], [1681.0, 693.0], [1681.0, 735.0], [1150.0, 743.0]], 識別文字: 'konaniu wywotata bowiem', 置信度: 0.95
# 文字框座標: [[568.0, 755.0], [1087.0, 753.0], [1087.0, 797.0], [568.0, 800.0]], 識別文字: 'scowosciach Kahramanma-', 置信度: 0.96
# 文字框座標: [[1150.0, 751.0], [1681.0, 740.0], [1681.0, 789.0], [1151.0, 800.0]], 識別文字: 'poptoch wsrod okolicznych', 置信度: 0.97
# 文字框座標: [[570.0, 809.0], [1087.0, 809.0], [1087.0, 851.0], [570.0, 851.0]], 識別文字: 'ras i Batman na potnocy kra', 置信度: 0.96
# 文字框座標: [[1155.0, 804.0], [1679.0, 804.0], [1679.0, 846.0], [1155.0, 846.0]], 識別文字: 'wloscian i postawita na nogi', 置信度: 0.93
# 文字框座標: [[563.0, 861.0], [1099.0, 856.0], [1099.0, 905.0], [563.0, 910.0]], 識別文字: 'ju.Aresztowani twierdza,ze', 置信度: 0.97
# 文字框座標: [[1150.0, 856.0], [1685.0, 846.0], [1686.0, 895.0], [1151.0, 906.0]], 識別文字: 'policje.Obawiano sie,ze', 置信度: 0.96
# 文字框座標: [[568.0, 915.0], [1087.0, 913.0], [1087.0, 954.0], [568.0, 957.0]], 識別文字: 'strzelali do ziemskiego sate', 置信度: 0.97
# 文字框座標: [[1147.0, 910.0], [1683.0, 903.0], [1684.0, 944.0], [1148.0, 952.0]], 識別文字: 'w miescie doszto do walk', 置信度: 0.92
# 文字框座標: [[565.0, 964.0], [1101.0, 959.0], [1101.0, 1011.0], [566.0, 1016.0]], 識別文字: 'lity, gdyz tak nakazuje stara', 置信度: 0.93
# 文字框座標: [[1150.0, 962.0], [1683.0, 957.0], [1684.0, 1001.0], [1150.0, 1006.0]], 識別文字: 'z zamieszkujacymi pobliskie', 置信度: 0.96
# 文字框座標: [[570.0, 1021.0], [1096.0, 1018.0], [1096.0, 1060.0], [570.0, 1063.0]], 識別文字: 'tradycja.Opisujacy awanture', 置信度: 0.99
# 文字框座標: [[1152.0, 1016.0], [1476.0, 1016.0], [1476.0, 1058.0], [1152.0, 1058.0]], 識別文字: 'wzgorza Kurdami,', 置信度: 0.94
# 文字框座標: [[570.0, 1073.0], [1089.0, 1067.0], [1089.0, 1109.0], [570.0, 1114.0]], 識別文字: 'ankarski dziennik,Hurriyet'', 置信度: 0.97
# 文字框座標: [[1371.0, 1068.0], [1686.0, 1062.0], [1686.0, 1104.0], [1372.0, 1110.0]], 識別文字: 'SSZ,REUTERS,PAP', 置信度: 0.93
# 文字框座標: [[250.0, 1290.0], [1263.0, 1261.0], [1265.0, 1362.0], [253.0, 1391.0]], 識別文字: 'Zyct"LO1, mw-1O,s.L', 置信度: 0.83
# OCR 識別結果已保存到文本文件：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_1.txt
# 識別結果已保存到可視化圖片：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_1_ocr.jpg
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\train_image_10.png'...
# [2025/05/11 22:13:42] ppocr DEBUG: dt_boxes num : 67, elapsed : 0.1651778221130371
# [2025/05/11 22:13:42] ppocr DEBUG: cls num  : 67, elapsed : 0.25376176834106445
# [2025/05/11 22:13:46] ppocr DEBUG: rec_res num  : 67, elapsed : 4.064743757247925
# OCR 識別結果：
# 文字框座標: [[1681.0, 2.0], [1723.0, 2.0], [1723.0, 423.0], [1681.0, 423.0]], 識別文字: 'Gtowny partner medial', 置信度: 0.98
# 文字框座標: [[2207.0, 12.0], [2242.0, 12.0], [2242.0, 194.0], [2207.0, 194.0]], 識別文字: 'c-krakow.c', 置信度: 0.93
# 文字框座標: [[626.0, 27.0], [709.0, 27.0], [709.0, 573.0], [626.0, 573.0]], 識別文字: 'PAPRIKA CORPS', 置信度: 0.98
# 文字框座標: [[528.0, 45.0], [604.0, 44.0], [609.0, 568.0], [534.0, 568.0]], 識別文字: 'T.MAKOWIECKI', 置信度: 0.99
# 文字框座標: [[1467.0, 93.0], [1537.0, 93.0], [1537.0, 330.0], [1467.0, 330.0]], 識別文字: 'ZMYSLOW', 置信度: 0.94
# 文字框座標: [[1569.0, 125.0], [1620.0, 125.0], [1620.0, 312.0], [1569.0, 312.0]], 識別文字: 'KRAKOW', 置信度: 1.00
# 文字框座標: [[881.0, 217.0], [937.0, 213.0], [946.0, 351.0], [890.0, 355.0]], 識別文字: 'nych', 置信度: 1.00
# 文字框座標: [[2178.0, 244.0], [2215.0, 244.0], [2215.0, 322.0], [2178.0, 322.0]], 識別文字: 'odn', 置信度: 0.69
# 文字框座標: [[358.0, 288.0], [434.0, 288.0], [434.0, 568.0], [358.0, 568.0]], 識別文字: 'PUUUEEI', 置信度: 0.62
# 文字框座標: [[195.0, 298.0], [273.0, 298.0], [273.0, 578.0], [195.0, 578.0]], 識別文字: 'SMOLIK', 置信度: 0.99
# 文字框座標: [[449.0, 327.0], [517.0, 328.0], [511.0, 569.0], [443.0, 567.0]], 識別文字: 'PUSTKI', 置信度: 1.00
# 文字框座標: [[112.0, 374.0], [190.0, 374.0], [190.0, 581.0], [112.0, 581.0]], 識別文字: 'WILKI', 置信度: 0.99
# 文字框座標: [[272.0, 365.0], [342.0, 360.0], [354.0, 568.0], [284.0, 572.0]], 識別文字: 'CKOD', 置信度: 0.70
# 文字框座標: [[728.0, 382.0], [1344.0, 359.0], [1346.0, 410.0], [730.0, 434.0]], 識別文字: 'To juz koniec walki z korupcja', 置信度: 0.99
# 文字框座標: [[2232.0, 379.0], [2302.0, 379.0], [2302.0, 617.0], [2232.0, 617.0]], 識別文字: 'POLITYKA', 置信度: 1.00
# 文字框座標: [[730.0, 439.0], [1348.0, 410.0], [1351.0, 459.0], [732.0, 488.0]], 識別文字: 'w polskim futbolu.Tak uwaza', 置信度: 0.97
# 文字框座標: [[730.0, 485.0], [1346.0, 464.0], [1348.0, 516.0], [732.0, 537.0]], 識別文字: 'Robert Zawlocki (37 1.), byly', 置信度: 0.93
# 文字框座標: [[738.0, 544.0], [1348.0, 518.0], [1350.0, 568.0], [740.0, 593.0]], 識別文字: 'wiceprzewodniczacy Wydzialu', 置信度: 0.98
# 文字框座標: [[742.0, 596.0], [1351.0, 573.0], [1353.0, 622.0], [744.0, 645.0]], 識別文字: 'Dyscypliny Polskiego Zwiazku', 置信度: 0.98
# 文字框座標: [[1513.0, 637.0], [1562.0, 637.0], [1564.0, 1407.0], [1516.0, 1407.0]], 識別文字: 'MUZYKA.SZTUKA.PROJEKCJE.SWIATLO', 置信度: 0.98
# 文字框座標: [[740.0, 648.0], [1344.0, 624.0], [1346.0, 676.0], [742.0, 699.0]], 識別文字: 'Pilki Noznej,ktory wczoraj zlo', 置信度: 0.95
# 文字框座標: [[2095.0, 657.0], [2173.0, 657.0], [2173.0, 954.0], [2095.0, 954.0]], 識別文字: 'empik', 置信度: 1.00
# 文字框座標: [[1679.0, 676.0], [1720.0, 676.0], [1720.0, 977.0], [1679.0, 977.0]], 識別文字: 'Rezerwuj bilety', 置信度: 1.00
# 文字框座標: [[1603.0, 686.0], [1645.0, 686.0], [1645.0, 1417.0], [1603.0, 1417.0]], 識別文字: 'www.cracowscreenfestival.pl', 置信度: 0.97
# 文字框座標: [[214.0, 711.0], [305.0, 711.0], [305.0, 1380.0], [214.0, 1380.0]], 識別文字: 'UNDERWORLD', 置信度: 0.99
# 文字框座標: [[742.0, 702.0], [1344.0, 678.0], [1346.0, 730.0], [744.0, 753.0]], 識別文字: 'zyl dymisje w gescie solidarno', 置信度: 0.96
# 文字框座標: [[1772.0, 708.0], [1823.0, 710.0], [1815.0, 948.0], [1763.0, 946.0]], 識別文字: 'bileteria', 置信度: 1.00
# 文字框座標: [[112.0, 718.0], [205.0, 718.0], [205.0, 1380.0], [112.0, 1380.0]], 識別文字: 'BRYAN FERRY', 置信度: 0.95
# 文字框座標: [[743.0, 753.0], [1358.0, 732.0], [1360.0, 782.0], [744.0, 802.0]], 識別文字: 'sci wobec odwolanych przez', 置信度: 0.97
# 文字框座標: [[1906.0, 784.0], [1967.0, 786.0], [1961.0, 982.0], [1900.0, 980.0]], 識別文字: 'GALERIA', 置信度: 1.00
# 文字框座標: [[392.0, 797.0], [468.0, 797.0], [468.0, 1387.0], [392.0, 1387.0]], 識別文字: 'RAVEONETTES', 置信度: 1.00
# 文字框座標: [[745.0, 805.0], [1237.0, 789.0], [1238.0, 841.0], [747.0, 857.0]], 識別文字: 'zarzad zwiazku kolegow.', 置信度: 0.99
# 文字框座標: [[1854.0, 824.0], [1896.0, 824.0], [1896.0, 974.0], [1854.0, 974.0]], 識別文字: 'Partner', 置信度: 1.00
# 文字框座標: [[752.0, 910.0], [1339.0, 892.0], [1341.0, 937.0], [754.0, 955.0]], 識別文字: 'FAKT:Jeden zcztonkow zarzadu', 置信度: 0.95
# 文字框座標: [[2105.0, 922.0], [2173.0, 922.0], [2173.0, 1186.0], [2105.0, 1186.0]], 識別文字: 'QE sue', 置信度: 0.77
# 文字框座標: [[1988.0, 937.0], [2005.0, 937.0], [2005.0, 986.0], [1988.0, 986.0]], 識別文字: '3MO', 置信度: 0.61
# 文字框座標: [[2205.0, 942.0], [2283.0, 942.0], [2283.0, 1181.0], [2205.0, 1181.0]], 識別文字: '7ddM', 置信度: 0.91
# 文字框座標: [[487.0, 974.0], [563.0, 974.0], [563.0, 1387.0], [487.0, 1387.0]], 識別文字: 'MATTAFIX', 置信度: 1.00
# 文字框座標: [[752.0, 965.0], [1349.0, 942.0], [1350.0, 988.0], [754.0, 1012.0]], 識別文字: 'PZPNZbigniew Kozminski (58l.', 置信度: 0.94
# 文字框座標: [[663.0, 1028.0], [704.0, 1028.0], [704.0, 1378.0], [663.0, 1378.0]], 識別文字: 'WITH BURT FORD', 置信度: 0.93
# 文字框座標: [[750.0, 1019.0], [1351.0, 993.0], [1353.0, 1042.0], [752.0, 1068.0]], 識別文字: 'powiedziat,ze trzeba byto odwo', 置信度: 0.97
# 文字框座標: [[1796.0, 1045.0], [1847.0, 1045.0], [1847.0, 1223.0], [1796.0, 1223.0]], 識別文字: 'Screen', 置信度: 0.98
# 文字框座標: [[1824.0, 1042.0], [1885.0, 1040.0], [1891.0, 1214.0], [1830.0, 1216.0]], 識別文字: 'Muse', 置信度: 0.81
# 文字框座標: [[577.0, 1077.0], [665.0, 1077.0], [665.0, 1385.0], [577.0, 1385.0]], 識別文字: 'CIRKUS', 置信度: 1.00
# 文字框座標: [[752.0, 1068.0], [1327.0, 1052.0], [1328.0, 1099.0], [754.0, 1115.0]], 識別文字: 'tac Wydziat Dyscypliny,bo jego', 置信度: 0.96
# 文字框座標: [[1445.0, 1072.0], [1514.0, 1074.0], [1505.0, 1410.0], [1437.0, 1408.0]], 識別文字: '2-4MAJA', 置信度: 0.99
# 文字框座標: [[1764.0, 1075.0], [1791.0, 1075.0], [1791.0, 1188.0], [1764.0, 1188.0]], 識別文字: 'FUNDACIA', 置信度: 0.95
# 文字框座標: [[2039.0, 1109.0], [2081.0, 1109.0], [2081.0, 1476.0], [2039.0, 1476.0]], 識別文字: 'Partnerzy medialni', 置信度: 0.99
# 文字框座標: [[757.0, 1122.0], [1344.0, 1101.0], [1346.0, 1151.0], [759.0, 1171.0]], 識別文字: 'cztonkowie rzucali ktodypod no', 置信度: 0.95
# 文字框座標: [[757.0, 1176.0], [1353.0, 1153.0], [1355.0, 1202.0], [759.0, 1226.0]], 識別文字: 'gikierownictwuzwiazku,podwa', 置信度: 0.98
# 文字框座標: [[1674.0, 1201.0], [1715.0, 1200.0], [1718.0, 1476.0], [1676.0, 1476.0]], 識別文字: 'Organizatorzy', 置信度: 0.99
# 文字框座標: [[1942.0, 1193.0], [1976.0, 1193.0], [1976.0, 1471.0], [1942.0, 1471.0]], 識別文字: 'www.krakow.p1', 置信度: 0.96
# 文字框座標: [[755.0, 1231.0], [1139.0, 1212.0], [1141.0, 1264.0], [757.0, 1282.0]], 識別文字: 'zajac jegolegalnosc.', 置信度: 0.95
# 文字框座標: [[2212.0, 1237.0], [2283.0, 1237.0], [2283.0, 1424.0], [2212.0, 1424.0]], 識別文字: 'bazta', 置信度: 0.63
# 文字框座標: [[2098.0, 1259.0], [2168.0, 1259.0], [2168.0, 1456.0], [2098.0, 1456.0]], 識別文字: 'TVP2', 置信度: 0.90
# 文字框座標: [[738.0, 1469.0], [1495.0, 1451.0], [1496.0, 1507.0], [739.0, 1526.0]], 識別文字: 'TKt 2081wy JI5', 置信度: 0.55
# OCR 識別結果已保存到文本文件：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_10.txt
# 識別結果已保存到可視化圖片：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_10_ocr.jpg
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\train_image_11.png'...
# [2025/05/11 22:13:47] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.34918951988220215
# [2025/05/11 22:13:47] ppocr DEBUG: cls num  : 8, elapsed : 0.1047511100769043
# [2025/05/11 22:13:48] ppocr DEBUG: rec_res num  : 8, elapsed : 0.818995475769043
# OCR 識別結果：
# 文字框座標: [[2.0, 497.0], [654.0, 485.0], [655.0, 536.0], [3.0, 549.0]], 識別文字: 'nowie ci -- Zenek nie', 置信度: 0.95
# 文字框座標: [[5.0, 565.0], [652.0, 558.0], [652.0, 607.0], [5.0, 614.0]], 識別文字: 'ok. -- Jak-ona mi pod-', 置信度: 0.97
# 文字框座標: [[17.0, 636.0], [657.0, 626.0], [657.0, 682.0], [18.0, 692.0]], 識別文字: 'ale jak ja jej, o bracie,', 置信度: 0.97
# 文字框座標: [[0.0, 763.0], [106.0, 780.0], [96.0, 838.0], [0.0, 821.0]], 識別文字: 'bia.', 置信度: 0.99
# 文字框座標: [[7.0, 985.0], [667.0, 974.0], [667.0, 1026.0], [8.0, 1036.0]], 識別文字: 'sie nie wywine, bedzie', 置信度: 1.00
# 文字框座標: [[0.0, 1055.0], [373.0, 1047.0], [374.0, 1096.0], [1.0, 1104.0]], 識別文字: 'cos za uszami..', 置信度: 0.95
# 文字框座標: [[36.0, 1772.0], [928.0, 1746.0], [931.0, 1844.0], [39.0, 1870.0]], 識別文字: '1oynaa48+3s2', 置信度: 0.59
# OCR 識別結果已保存到文本文件：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_11.txt
# 識別結果已保存到可視化圖片：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_11_ocr.jpg
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\train_image_12.png'...
# [2025/05/11 22:13:49] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.40662622451782227
# [2025/05/11 22:13:49] ppocr DEBUG: cls num  : 11, elapsed : 0.17958569526672363
# [2025/05/11 22:13:50] ppocr DEBUG: rec_res num  : 11, elapsed : 0.8063418865203857
# OCR 識別結果：
# 文字框座標: [[570.0, 21.0], [1562.0, 68.0], [1559.0, 149.0], [566.0, 102.0]], 識別文字: 'e) Wycic pa Hu hvgv e a nog.', 置信度: 0.72
# 文字框座標: [[558.0, 196.0], [1433.0, 230.0], [1429.0, 331.0], [554.0, 297.0]], 識別文字: 'Szefom firmy Rave.', 置信度: 0.96
# 文字框座標: [[684.0, 336.0], [1435.0, 360.0], [1432.0, 461.0], [681.0, 437.0]], 識別文字: 'wydawato sie, ze', 置信度: 0.99
# 文字框座標: [[573.0, 459.0], [1428.0, 496.0], [1424.0, 597.0], [569.0, 560.0]], 識別文字: 'chwycili pana Boga', 置信度: 0.98
# 文字框座標: [[816.0, 599.0], [1416.0, 624.0], [1412.0, 727.0], [812.0, 703.0]], 識別文字: 'za nogi, kiedy.', 置信度: 0.99
# 文字框座標: [[522.0, 712.0], [1421.0, 757.0], [1416.0, 858.0], [517.0, 813.0]], 識別文字: 'Arkadius zgodzit sie.', 置信度: 0.98
# 文字框座標: [[470.0, 851.0], [1411.0, 887.0], [1408.0, 981.0], [467.0, 944.0]], 識別文字: 'dla nich projektowac..', 置信度: 0.98
# 文字框座標: [[661.0, 980.0], [1414.0, 1020.0], [1409.0, 1122.0], [656.0, 1081.0]], 識別文字: 'Teraz maja stosy', 置信度: 0.99
# 文字框座標: [[640.0, 1114.0], [1409.0, 1138.0], [1405.0, 1241.0], [637.0, 1217.0]], 識別文字: 'jego ubran, ktore', 置信度: 0.99
# 文字框座標: [[514.0, 1242.0], [1404.0, 1271.0], [1400.0, 1379.0], [510.0, 1350.0]], 識別文字: 'zalegaja na potkach', 置信度: 0.99
# 文字框座標: [[313.0, 1533.0], [1303.0, 1549.0], [1302.0, 1632.0], [311.0, 1617.0]], 識別文字: 'Fakt L0041 nr 10h 1s. 15.', 置信度: 0.87
# OCR 識別結果已保存到文本文件：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_12.txt
# 識別結果已保存到可視化圖片：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_12_ocr.jpg
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\train_image_13.png'...
# [2025/05/11 22:13:50] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.17735648155212402
# [2025/05/11 22:13:50] ppocr DEBUG: cls num  : 23, elapsed : 0.07139301300048828
# [2025/05/11 22:13:53] ppocr DEBUG: rec_res num  : 23, elapsed : 2.6535139083862305
# OCR 識別結果：
# 文字框座標: [[568.0, 175.0], [665.0, 175.0], [665.0, 330.0], [568.0, 330.0]], 識別文字: 'H', 置信度: 0.75
# 文字框座標: [[691.0, 176.0], [1373.0, 210.0], [1370.0, 259.0], [689.0, 226.0]], 識別文字: 'ISTORYJKA z,,Dziennikow', 置信度: 0.95
# 文字框座標: [[689.0, 233.0], [868.0, 242.0], [866.0, 286.0], [686.0, 277.0]], 識別文字: 'Jana', 置信度: 0.99
# 文字框座標: [[844.0, 240.0], [1394.0, 266.0], [1392.0, 313.0], [842.0, 287.0]], 識別文字: 'Lechonia:kwestarka', 置信度: 0.98
# 文字框座標: [[686.0, 287.0], [1387.0, 320.0], [1385.0, 370.0], [684.0, 336.0]], 識別文字: 'zwraca sie z prosba o datek na', 置信度: 0.95
# 文字框座標: [[567.0, 334.0], [1380.0, 370.0], [1378.0, 419.0], [565.0, 383.0]], 識別文字: 'upadle dziewczeta do Michela Si', 置信度: 0.95
# 文字框座標: [[560.0, 385.0], [1097.0, 412.0], [1095.0, 461.0], [557.0, 435.0]], 識別文字: 'mona.Ten odpowiada:', 置信度: 0.98
# 文字框座標: [[611.0, 442.0], [1114.0, 466.0], [1112.0, 515.0], [608.0, 491.0]], 識別文字: '-Dam bezposrednio.', 置信度: 0.98
# 文字框座標: [[608.0, 496.0], [1370.0, 532.0], [1368.0, 581.0], [606.0, 545.0]], 識別文字: 'Role upadlych dziewczatek prze', 置信度: 0.96
# 文字框座標: [[552.0, 548.0], [1375.0, 589.0], [1373.0, 638.0], [550.0, 597.0]], 識別文字: 'jeli u nas politycy.Tracac grunt pod', 置信度: 0.97
# 文字框座標: [[550.0, 599.0], [1373.0, 643.0], [1370.0, 692.0], [547.0, 649.0]], 識別文字: 'nogami-uporczywie domagaja sie', 置信度: 0.99
# 文字框座標: [[550.0, 654.0], [1375.0, 694.0], [1372.0, 746.0], [547.0, 705.0]], 識別文字: 'wsparcia.W zamian za to sa gotowi', 置信度: 0.97
# 文字框座標: [[547.0, 708.0], [1360.0, 749.0], [1358.0, 798.0], [545.0, 757.0]], 識別文字: 'szepnac nam na uszko,kto byl agen', 置信度: 0.94
# 文字框座標: [[542.0, 759.0], [1368.0, 800.0], [1365.0, 849.0], [540.0, 809.0]], 識別文字: 'tem.Wybor marny:albo UB,albo', 置信度: 0.95
# 文字框座標: [[540.0, 811.0], [1363.0, 854.0], [1360.0, 906.0], [538.0, 863.0]], 識別文字: 'KGB.Swoja droga ciekawe:jedynie', 置信度: 0.98
# 文字框座標: [[540.0, 865.0], [1353.0, 906.0], [1351.0, 955.0], [538.0, 914.0]], 識別文字: 'firma z Lubianki werbowala i szkoli', 置信度: 0.96
# 文字框座標: [[535.0, 917.0], [1358.0, 960.0], [1355.0, 1009.0], [533.0, 966.0]], 識別文字: 'la kandydatow.Zaden inny wywiad', 置信度: 0.95
# 文字框座標: [[530.0, 971.0], [1356.0, 1014.0], [1353.0, 1063.0], [528.0, 1020.0]], 識別文字: 'na nich nie reflektowal. Sadzac', 置信度: 0.95
# 文字框座標: [[528.0, 1025.0], [1351.0, 1068.0], [1348.0, 1118.0], [525.0, 1074.0]], 識別文字: 'z rewelacji upchnietych w ksiazecz-', 置信度: 0.95
# 文字框座標: [[528.0, 1077.0], [1348.0, 1120.0], [1346.0, 1172.0], [525.0, 1128.0]], 識別文字: 'kach wydawnictwa,,Spotkania"', 置信度: 0.95
# 文字框座標: [[558.0, 1131.0], [1341.0, 1177.0], [1338.0, 1228.0], [555.0, 1182.0]], 識別文字: 'tylko radzieccy obstawiali przy-', 置信度: 0.97
# 文字框座標: [[523.0, 1185.0], [1346.0, 1231.0], [1343.0, 1280.0], [521.0, 1234.0]], 識別文字: 'szlosciowe kariery poslow, senato-', 置信度: 0.98
# 文字框座標: [[526.0, 1250.0], [577.0, 1250.0], [577.0, 1267.0], [526.0, 1267.0]], 識別文字: 'ro', 置信度: 0.65
# OCR 識別結果已保存到文本文件：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_13.txt
# 識別結果已保存到可視化圖片：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_13_ocr.jpg
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\train_image_14.png'...
# [2025/05/11 22:13:54] ppocr DEBUG: dt_boxes num : 17, elapsed : 0.12072134017944336
# [2025/05/11 22:13:54] ppocr DEBUG: cls num  : 17, elapsed : 0.04339313507080078
# [2025/05/11 22:13:57] ppocr DEBUG: rec_res num  : 17, elapsed : 3.420100688934326
# OCR 識別結果：
# 文字框座標: [[455.0, 249.0], [1878.0, 228.0], [1879.0, 285.0], [456.0, 305.0]], 識別文字: 'zwisko. Na te paszporty dostali wize marokanska', 置信度: 0.99
# 文字框座標: [[455.0, 325.0], [1293.0, 310.0], [1294.0, 359.0], [456.0, 374.0]], 識別文字: 'i osiedlili sie w Casablance..', 置信度: 0.96
# 文字框座標: [[631.0, 386.0], [1880.0, 371.0], [1881.0, 430.0], [631.0, 445.0]], 識別文字: 'Nie byloby dalszego ciagu, gdyby nie nie-.', 置信度: 0.97
# 文字框座標: [[460.0, 465.0], [1883.0, 442.0], [1884.0, 499.0], [461.0, 522.0]], 識別文字: 'roztropnosc Sobolewskiego. Zamiast siedziec ci-', 置信度: 1.00
# 文字框座標: [[463.0, 534.0], [1880.0, 516.0], [1881.0, 573.0], [463.0, 591.0]], 識別文字: 'cho, postanowil dzialac, przekonany o swojej mi-', 置信度: 0.99
# 文字框座標: [[465.0, 610.0], [1890.0, 583.0], [1891.0, 642.0], [466.0, 669.0]], 識別文字: 'sji gloszenia prawdy o komunizmie. Wyglaszal', 置信度: 0.99
# 文字框座標: [[465.0, 679.0], [1890.0, 654.0], [1891.0, 713.0], [466.0, 738.0]], 識別文字: 'odczyty dla miejscowej polskiej kolonii 1 8strzegal', 置信度: 0.98
# 文字框座標: [[463.0, 819.0], [1880.0, 802.0], [1881.0, 861.0], [463.0, 878.0]], 識別文字: 'lance, jednej ze stolic miedzynarodowego szpiego', 置信度: 1.00
# 文字框座標: [[467.0, 893.0], [1883.0, 870.0], [1884.0, 930.0], [468.0, 952.0]], 識別文字: 'stwa, gdzie Warszawa rowniez miala swoja siatke', 置信度: 0.98
# 文字框座標: [[472.0, 964.0], [1898.0, 947.0], [1898.0, 1003.0], [473.0, 1021.0]], 識別文字: 'Podpadl, co sie okazalo, kiedy czujac, ze grunt mu', 置信度: 0.99
# 文字框座標: [[470.0, 1038.0], [1895.0, 1016.0], [1896.0, 1072.0], [471.0, 1095.0]], 識別文字: 'sie pali pod nogami. wybral sie do Rzyml znow po', 置信度: 0.99
# 文字框座標: [[470.0, 1107.0], [1900.0, 1077.0], [1901.0, 1143.0], [471.0, 1174.0]], 識別文字: 'paszporty i wizy. Szemplinska, kiedy nam to.', 置信度: 0.97
# 文字框座標: [[475.0, 1181.0], [1897.0, 1156.0], [1898.0, 1215.0], [476.0, 1240.0]], 識別文字: 'opowiadala, byla przekonana, ze kuter, z ktorym', 置信度: 1.00
# 文字框座標: [[475.0, 1247.0], [1900.0, 1225.0], [1901.0, 1284.0], [476.0, 1306.0]], 識別文字: 'Sobolewski ugodzil sie co do ceny za rejs do', 置信度: 0.98
# 文字框座標: [[475.0, 1319.0], [1897.0, 1296.0], [1898.0, 1355.0], [476.0, 1378.0]], 識別文字: 'Rzymu, byl podstawiony. Zostala sama z dziec-', 置信度: 1.00
# 文字框座標: [[475.0, 1390.0], [1905.0, 1365.0], [1906.0, 1424.0], [476.0, 1449.0]], 識別文字: 'kiem, wyjechal i zaginal bez wiesciJPotem cialo', 置信度: 0.98
# OCR 識別結果已保存到文本文件：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_14.txt
# 識別結果已保存到可視化圖片：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_14_ocr.jpg
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\train_image_15.png'...
# [2025/05/11 22:13:58] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.4242584705352783
# [2025/05/11 22:13:58] ppocr DEBUG: cls num  : 11, elapsed : 0.2121753692626953
# [2025/05/11 22:14:00] ppocr DEBUG: rec_res num  : 11, elapsed : 1.3238873481750488
# OCR 識別結果：
# 文字框座標: [[754.0, 478.0], [1730.0, 442.0], [1732.0, 492.0], [756.0, 527.0]], 識別文字: 'Zajmijcie sie wlasnymi problemami, zamiast pouczac.', 置信度: 0.98
# 文字框座標: [[1251.0, 512.0], [1699.0, 496.0], [1700.0, 546.0], [1253.0, 561.0]], 識別文字: ' glinianych nogach - ma', 置信度: 0.92
# 文字框座標: [[764.0, 532.0], [1275.0, 514.0], [1277.0, 556.0], [766.0, 574.0]], 識別文字: 'innych.Francic to kolos na', 置信度: 0.94
# 文字框座標: [[703.0, 584.0], [1762.0, 546.0], [1764.0, 595.0], [705.0, 633.0]], 識別文字: 'olbrzymia biurokracje. a proby zreformowania gospodarki', 置信度: 0.98
# 文字框座標: [[703.0, 638.0], [1769.0, 600.0], [1771.0, 649.0], [705.0, 687.0]], 識別文字: 'ponosza kleske za kleska. Nic dziwnego. ze przedsiebiorcy', 置信度: 0.98
# 文字框座標: [[706.0, 696.0], [954.0, 691.0], [955.0, 735.0], [707.0, 741.0]], 識別文字: 'stamtad wieja', 置信度: 0.92
# 文字框座標: [[774.0, 773.0], [1755.0, 740.0], [1756.0, 785.0], [775.0, 817.0]], 識別文字: 'Na sojuszach z Francja Polska zawsze wychodzila zle', 置信度: 0.96
# 文字框座標: [[752.0, 825.0], [1789.0, 789.0], [1791.0, 838.0], [754.0, 874.0]], 識別文字: 'Gdyby we wrzesniu 1939 r oderwali sie od zabich udek', 置信度: 0.99
# 文字框座標: [[1312.0, 861.0], [1690.0, 853.0], [1690.0, 890.0], [1313.0, 898.0]], 識別文字: 'iewoinaswiatowa', 置信度: 0.91
# 文字框座標: [[1339.0, 915.0], [1665.0, 900.0], [1667.0, 942.0], [1341.0, 958.0]], 識別文字: 'A tak trwala 6 lat.', 置信度: 0.97
# 文字框座標: [[557.0, 1317.0], [1672.0, 1291.0], [1674.0, 1372.0], [559.0, 1398.0]], 識別文字: 'Fnkt z0of1 n 23f1 s.5', 置信度: 0.74
# OCR 識別結果已保存到文本文件：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_15.txt
# 識別結果已保存到可視化圖片：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_15_ocr.jpg
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\train_image_16.png'...
# [2025/05/11 22:14:00] ppocr DEBUG: dt_boxes num : 36, elapsed : 0.1593036651611328
# [2025/05/11 22:14:00] ppocr DEBUG: cls num  : 36, elapsed : 0.11209535598754883
# [2025/05/11 22:14:04] ppocr DEBUG: rec_res num  : 36, elapsed : 4.11674952507019
# OCR 識別結果：
# 文字框座標: [[716.0, 157.0], [821.0, 157.0], [821.0, 214.0], [716.0, 214.0]], 識別文字: 'Z1', 置信度: 0.70
# 文字框座標: [[1546.0, 162.0], [2311.0, 155.0], [2311.0, 194.0], [1547.0, 202.0]], 識別文字: 'o wymaganych parametrach.eNa', 置信度: 0.93
# 文字框座標: [[1549.0, 207.0], [2311.0, 202.0], [2311.0, 243.0], [1549.0, 249.0]], 識別文字: 'pracowniach koledzy rozprawia-', 置信度: 0.97
# 文字框座標: [[1554.0, 256.0], [2311.0, 256.0], [2311.0, 290.0], [1554.0, 290.0]], 識別文字: 'li o.banialukach. nocami teore-', 置信度: 0.92
# 文字框座標: [[723.0, 280.0], [1471.0, 280.0], [1471.0, 315.0], [723.0, 315.0]], 識別文字: 'nika.Zdal egzamini takrozpo', 置信度: 0.90
# 文字框座標: [[1546.0, 300.0], [2316.0, 295.0], [2316.0, 337.0], [1547.0, 342.0]], 識別文字: 'tyzowal opracowujac.potrzebne', 置信度: 0.96
# 文字框座標: [[718.0, 325.0], [1476.0, 320.0], [1476.0, 362.0], [719.0, 367.0]], 識別文字: 'czal sie okres jak z tysiaca zy', 置信度: 0.90
# 文字框座標: [[1549.0, 347.0], [2313.0, 342.0], [2314.0, 384.0], [1549.0, 389.0]], 識別文字: 'do sprawozdan wyniki badan, W', 置信度: 0.92
# 文字框座標: [[716.0, 369.0], [1483.0, 364.0], [1483.0, 413.0], [716.0, 418.0]], 識別文字: 'ciorysow:szkola,praca.Tak jak', 置信度: 0.94
# 文字框座標: [[1556.0, 391.0], [2306.0, 391.0], [2306.0, 433.0], [1556.0, 433.0]], 識別文字: 'dzien chodzil trupio/blady,cza-', 置信度: 0.94
# 文字框座標: [[716.0, 418.0], [1481.0, 413.0], [1481.0, 455.0], [716.0, 460.0]], 識別文字: 'wsztubackim zyciu-xzadania', 置信度: 0.93
# 文字框座標: [[1549.0, 443.0], [2145.0, 438.0], [2146.0, 477.0], [1549.0, 482.0]], 識別文字: 'sem zasypialna lekcji', 置信度: 0.94
# 文字框座標: [[2216.0, 440.0], [2314.0, 440.0], [2314.0, 477.0], [2216.0, 477.0]], 識別文字: 'zyl', 置信度: 0.70
# 文字框座標: [[716.0, 460.0], [1485.0, 455.0], [1486.0, 504.0], [716.0, 509.0]], 識別文字: 'wypracowania,klasowki. Dni, w', 置信度: 0.94
# 文字框座標: [[1554.0, 487.0], [2311.0, 487.0], [2311.0, 529.0], [1554.0, 529.0]], 識別文字: 'swoim swiatem.Zlapal tego mo-', 置信度: 0.93
# 文字框座標: [[718.0, 509.0], [1486.0, 507.0], [1486.0, 548.0], [719.0, 551.0]], 識別文字: 'ktorychwykonujesie mnostwo', 置信度: 0.98
# 文字框座標: [[1551.0, 536.0], [2240.0, 529.0], [2241.0, 573.0], [1552.0, 581.0]], 識別文字: 'la, dreczylo pytanie: dlaczego?', 置信度: 0.92
# 文字框座標: [[721.0, 556.0], [1483.0, 551.0], [1483.0, 593.0], [721.0, 598.0]], 識別文字: 'tychsamych czynnosci,wkto-', 置信度: 0.96
# 文字框座標: [[721.0, 603.0], [1488.0, 598.0], [1488.0, 640.0], [721.0, 645.0]], 識別文字: 'rych/nie zawsze da'sie wykrzesae', 置信度: 0.92
# 文字框座標: [[1590.0, 637.0], [2311.0, 632.0], [2311.0, 676.0], [1591.0, 681.0]], 識別文字: 'Tym rozmachem poszedl dalej.', 置信度: 0.94
# 文字框座標: [[721.0, 649.0], [1485.0, 644.0], [1486.0, 686.0], [721.0, 691.0]], 識別文字: 'iskry satysfakcji.Mozna przesia-', 置信度: 0.95
# 文字框座標: [[1556.0, 686.0], [2316.0, 681.0], [2316.0, 723.0], [1556.0, 728.0]], 識別文字: 'Ukonczyl fizyke na Uniwersytecie', 置信度: 0.96
# 文字框座標: [[723.0, 696.0], [1485.0, 691.0], [1486.0, 730.0], [723.0, 736.0]], 識別文字: 'dywacnocaminadprojektami', 置信度: 0.98
# 文字框座標: [[1554.0, 731.0], [2316.0, 728.0], [2316.0, 770.0], [1554.0, 772.0]], 識別文字: 'Gdanskim i zdalo mu sie juz,ze', 置信度: 0.92
# 文字框座標: [[726.0, 745.0], [1488.0, 738.0], [1488.0, 777.0], [726.0, 785.0]], 識別文字: 'wspanialych wzmacniaczy 1 Tar-', 置信度: 0.93
# 文字框座標: [[1551.0, 777.0], [2318.0, 772.0], [2319.0, 821.0], [1552.0, 827.0]], 識別文字: 'chwycil Pana Boga za nogi, ze', 置信度: 0.90
# 文字框座標: [[723.0, 792.0], [1488.0, 782.0], [1488.0, 824.0], [724.0, 834.0]], 識別文字: 'gonski mowi,zeto wlasniebyio', 置信度: 0.93
# 文字框座標: [[726.0, 836.0], [1171.0, 831.0], [1172.0, 873.0], [726.0, 878.0]], 識別文字: 'fajne..Fantazjowal', 置信度: 0.94
# 文字框座標: [[1240.0, 834.0], [1486.0, 834.0], [1486.0, 868.0], [1240.0, 868.0]], 識別文字: 'ezakladal', 置信度: 0.85
# 文字框座標: [[1554.0, 829.0], [2316.0, 824.0], [2316.0, 863.0], [1554.0, 868.0]], 識別文字: 'zisci mrzonki,rozgryzie teorie re-', 置信度: 0.98
# 文字框座標: [[721.0, 883.0], [1373.0, 876.0], [1374.0, 917.0], [721.0, 925.0]], 識別文字: 'niezwyklajakosc.swoich', 置信度: 0.94
# 文字框座標: [[1359.0, 883.0], [1483.0, 883.0], [1483.0, 918.0], [1359.0, 918.0]], 識別文字: 'urza-', 置信度: 0.96
# 文字框座標: [[1554.0, 876.0], [2318.0, 868.0], [2319.0, 910.0], [1554.0, 918.0]], 識別文字: 'normalizacji,ze bedzie na swoim', 置信度: 0.94
# 文字框座標: [[726.0, 930.0], [1495.0, 922.0], [1495.0, 964.0], [726.0, 972.0]], 識別文字: 'dzen,choc brakowalo.tranzystorow', 置信度: 0.94
# 文字框座標: [[1559.0, 922.0], [1756.0, 922.0], [1756.0, 964.0], [1559.0, 964.0]], 識別文字: 'miejscu.!', 置信度: 0.93
# 文字框座標: [[809.0, 1240.0], [1997.0, 1240.0], [1997.0, 1355.0], [809.0, 1355.0]], 識別文字: 'Plitchril'10+8 rr 12, s.8.', 置信度: 0.78
# OCR 識別結果已保存到文本文件：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_16.txt
# 識別結果已保存到可視化圖片：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_16_ocr.jpg
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\train_image_17.png'...
# [2025/05/11 22:14:05] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.454911470413208
# [2025/05/11 22:14:06] ppocr DEBUG: cls num  : 12, elapsed : 0.13223576545715332
# [2025/05/11 22:14:07] ppocr DEBUG: rec_res num  : 12, elapsed : 1.3609552383422852
# OCR 識別結果：
# 文字框座標: [[904.0, 280.0], [1309.0, 286.0], [1308.0, 327.0], [904.0, 322.0]], 識別文字: 'Poset SLD Alfred Owoc', 置信度: 0.97
# 文字框座標: [[794.0, 339.0], [1447.0, 344.0], [1447.0, 386.0], [794.0, 381.0]], 識別文字: 'spowodowat wypadek samochodowy,', 置信度: 1.00
# 文字框座標: [[797.0, 393.0], [1460.0, 401.0], [1459.0, 443.0], [797.0, 435.0]], 識別文字: 'zjezdzajac gwaltownie z prawego pasa', 置信度: 0.98
# 文字框座標: [[797.0, 455.0], [1377.0, 455.0], [1377.0, 497.0], [797.0, 497.0]], 識別文字: 'na lewy. ,Byt tak pijany, ze ledwo', 置信度: 1.00
# 文字框座標: [[792.0, 509.0], [1418.0, 507.0], [1418.0, 549.0], [792.0, 551.0]], 識別文字: 'trzymat sie na nogach" -- powiedzial', 置信度: 1.00
# 文字框座標: [[809.0, 568.0], [1318.0, 568.0], [1318.0, 603.0], [809.0, 603.0]], 識別文字: ',Super Expressowi" wtasciciel', 置信度: 0.95
# 文字框座標: [[797.0, 617.0], [1452.0, 622.0], [1452.0, 664.0], [797.0, 659.0]], 識別文字: 'poszkodowanego auta. Parlamentarzy-', 置信度: 0.99
# 文字框座標: [[797.0, 674.0], [1386.0, 679.0], [1386.0, 718.0], [797.0, 713.0]], 識別文字: 'sta Owoc zaprzecza: ,Zupeinie nie', 置信度: 0.96
# 文字框座標: [[797.0, 731.0], [1384.0, 731.0], [1384.0, 772.0], [797.0, 772.0]], 識別文字: 'wiem, jak to sie stato, ze czuli ode', 置信度: 0.99
# 文字框座標: [[792.0, 780.0], [1296.0, 785.0], [1296.0, 834.0], [792.0, 829.0]], 識別文字: 'mnie wodke. Moze to zwykty', 置信度: 1.00
# 文字框座標: [[794.0, 839.0], [1296.0, 836.0], [1296.0, 885.0], [794.0, 888.0]], 識別文字: 'spryskiwacz samochodowy?'', 置信度: 1.00
# 文字框座標: [[611.0, 1346.0], [1629.0, 1328.0], [1631.0, 1434.0], [613.0, 1452.0]], 識別文字: 'Pdctgkn 1O001 rr h) s- 90s', 置信度: 0.79
# OCR 識別結果已保存到文本文件：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_17.txt
# 識別結果已保存到可視化圖片：C:\Users\User\Desktop\PaddleOCR\ocr\train_image_17_ocr.jpg
#
# OCR 測試完成。

# %% [markdown]
# 一張CER

# %%
from paddleocr_backup import PaddleOCR
import os
import datetime
from PIL import Image
import Levenshtein

def calculate_cer_with_details(ground_truth, prediction):
    """計算字元錯誤率 (CER) 並返回詳細的錯誤信息"""
    if not ground_truth:
        return 1.0 if prediction else 0.0, []
    if not prediction:
        return 1.0, []

    ground_truth = ground_truth.upper()
    prediction = prediction.upper()

    distance = Levenshtein.distance(ground_truth, prediction)
    cer = distance / len(ground_truth)
    details = []

    # 使用 Levenshtein 的操作來追蹤差異
    operations = Levenshtein.editops(ground_truth, prediction)
    gt_index = 0
    pred_index = 0
    for op, gt_pos, pred_pos in operations:
        if op == 'insert':
            details.append(f"預測行: 1, 位置: {pred_pos + 1}, 插入: '{prediction[pred_pos]}'")
        elif op == 'delete':
            details.append(f"實際行: 1, 位置: {gt_pos + 1}, 刪除: '{ground_truth[gt_pos]}'")
        elif op == 'replace':
            details.append(f"實際行: 1, 位置: {gt_pos + 1}, 替換為: '{prediction[pred_pos]}', 原字元: '{ground_truth[gt_pos]}'")

    return cer, details

# 指定要測試的單張圖片路徑
image_path = r'C:\Users\User\Desktop\PaddleOCR\4.png'

# 提供 ground_truth 文字
ground_truth_text = """Can Human Survive After 100 Years?
Earth is now in a very bad situation, it is sick and fragile. Lots of reasons
that cause the Earth sick is made from human. How can we help to make
Earth healthier?
Every day after we go to school or work, some of us forgot to turn of air
conditioner or faucet, it is not only a waste of energy, but also a reason that
lets Earth become sicker. On the way to school, our parents drive the car to
take us to school, the car will release Carbon Dioxide (CO2), it will cause green
house effect and broke the Ozone layer. Human keep destroy natural
resources on Earth, and if these kinds of things continue to happen, our next
generation will have no chance of having a good living environment or living
on Earth!
It won't take long for you to turn off the electrical appliances, or having
bus and train instead of car and motorcycle. I believe, if we can have less
pollution human and the other organism expect cockroach and mosquito can
survive on a healthy Earth after 100 year."""

# 指定 OCR 輸出文本資料夾路徑
ocr_output_folder = r'C:\Users\User\Desktop\PaddleOCR\ocr_cer_detailed'

# 確保輸出資料夾存在，如果不存在則創建
if not os.path.exists(ocr_output_folder):
    os.makedirs(ocr_output_folder)
    print(f"已創建 OCR 輸出資料夾：{ocr_output_folder}")

# 檢查圖片是否存在
if not os.path.exists(image_path):
    print(f"錯誤：圖片文件 '{image_path}' 不存在。請檢查路徑是否正確。")
else:
    # 初始化 OCR 模型
    ocr = PaddleOCR(use_angle_cls=True, lang="ch", use_gpu=False)
    print(f"正在對圖片 '{image_path}' 執行 OCR 並計算 CER (含詳細錯誤)...")

    ocr_output_text = ""
    current_cer = 0.0
    error_details = []

    # 執行 OCR 識別
    result = ocr.ocr(image_path, cls=True)

    if result and result[0]:
        for i, line in enumerate(result[0]):
            text = line[1][0]
            ocr_output_text += text + "\n"
        ocr_output_text = ocr_output_text.strip()

        # 計算 CER 並獲取詳細錯誤
        if ground_truth_text:
            current_cer, error_details = calculate_cer_with_details(ground_truth_text, ocr_output_text)
            print(f"圖片 '{os.path.basename(image_path)}' 的 CER: {current_cer:.4f}")

            if error_details:
                print("詳細錯誤：")
                for detail in error_details:
                    print(detail)
            else:
                print("沒有發現字元錯誤。")

            # 保存 OCR 輸出到 .txt 文件
            timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
            image_name_without_ext = os.path.splitext(os.path.basename(image_path))[0]
            ocr_output_filename = f"{image_name_without_ext}_ocr_detailed_{timestamp}.txt"
            ocr_output_path = os.path.join(ocr_output_folder, ocr_output_filename)
            try:
                with open(ocr_output_path, 'w', encoding='utf-8') as f:
                    f.write(ocr_output_text)
                print(f"OCR 輸出已保存到：{ocr_output_path}")
            except IOError as e:
                print(f"保存 OCR 輸出文件時發生錯誤: {e}")
        else:
            print("沒有提供 ground_truth 文字，無法計算 CER。")

    else:
        print("未在圖片中識別到任何文字。")

print("\nOCR 和 CER 計算完成 (含詳細錯誤)。")
# Out:
# [2025/05/12 10:37:58] ppocr DEBUG: Namespace(alpha=1.0, alphacolor=(255, 255, 255), benchmark=False, beta=1.0, binarize=False, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='C:\\Users\\User/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='C:\\Users\\User/.paddleocr/whl\\det\\ch\\ch_PP-OCRv4_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, formula=False, formula_algorithm='LaTeXOCR', formula_batch_num=1, formula_char_dict_path=None, formula_model_dir=None, fourier_degree=5, gpu_id=0, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, invert=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='ch', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv4', onnx_providers=False, onnx_sess_options=False, output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='c:\\Users\\User\\anaconda3\\envs\\pytorch_env\\lib\\site-packages\\paddleocr\\ppocr\\utils\\ppocr_keys_v1.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='C:\\Users\\User/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv4_rec_infer', recovery=False, recovery_to_markdown=False, return_word_box=False, save_crop_res=False, save_log_path='./log_output/', savefile=False, scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=True, use_dilation=False, use_gcu=False, use_gpu=False, use_mlu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# 正在對圖片 'C:\Users\User\Desktop\PaddleOCR\4.png' 執行 OCR 並計算 CER (含詳細錯誤)...
# [2025/05/12 10:38:00] ppocr DEBUG: dt_boxes num : 16, elapsed : 0.09481143951416016
# [2025/05/12 10:38:00] ppocr DEBUG: cls num  : 16, elapsed : 0.07304883003234863
# [2025/05/12 10:38:02] ppocr DEBUG: rec_res num  : 16, elapsed : 1.7580554485321045
# 圖片 '4.png' 的 CER: 0.2362
# 詳細錯誤：
# 實際行: 1, 位置: 4, 刪除: ' '
# 實際行: 1, 位置: 10, 刪除: ' '
# 實際行: 1, 位置: 18, 刪除: ' '
# 實際行: 1, 位置: 24, 刪除: ' '
# 實際行: 1, 位置: 26, 替換為: 'O', 原字元: '0'
# 實際行: 1, 位置: 27, 替換為: 'O', 原字元: '0'
# 實際行: 1, 位置: 28, 刪除: ' '
# 實際行: 1, 位置: 41, 刪除: ' '
# 實際行: 1, 位置: 44, 刪除: ' '
# 實際行: 1, 位置: 48, 刪除: ' '
# 實際行: 1, 位置: 53, 刪除: ' '
# 實際行: 1, 位置: 58, 刪除: ' '
# 實際行: 1, 位置: 62, 刪除: ' '
# 實際行: 1, 位置: 73, 刪除: ' '
# 實際行: 1, 位置: 76, 刪除: ' '
# 實際行: 1, 位置: 79, 刪除: ' '
# 實際行: 1, 位置: 84, 刪除: ' '
# 實際行: 1, 位置: 88, 刪除: ' '
# 實際行: 1, 位置: 97, 刪除: ' '
# 實際行: 1, 位置: 102, 刪除: ' '
# 實際行: 1, 位置: 105, 刪除: ' '
# 實際行: 1, 位置: 118, 刪除: ' '
# 實際行: 1, 位置: 124, 刪除: ' '
# 實際行: 1, 位置: 128, 刪除: ' '
# 實際行: 1, 位置: 134, 刪除: ' '
# 實際行: 1, 位置: 139, 刪除: ' '
# 實際行: 1, 位置: 142, 刪除: ' '
# 實際行: 1, 位置: 147, 刪除: ' '
# 實際行: 1, 位置: 152, 刪除: ' '
# 實際行: 1, 位置: 159, 刪除: ' '
# 實際行: 1, 位置: 163, 刪除: ' '
# 實際行: 1, 位置: 167, 刪除: ' '
# 實際行: 1, 位置: 170, 刪除: ' '
# 實際行: 1, 位置: 175, 刪除: ' '
# 實際行: 1, 位置: 178, 刪除: ' '
# 實際行: 1, 位置: 189, 刪除: ' '
# 實際行: 1, 位置: 206, 刪除: ' '
# 實際行: 1, 位置: 210, 刪除: ' '
# 實際行: 1, 位置: 216, 刪除: ' '
# 實際行: 1, 位置: 219, 刪除: ' '
# 實際行: 1, 位置: 222, 刪除: ' '
# 實際行: 1, 位置: 225, 刪除: ' '
# 實際行: 1, 位置: 232, 刪除: ' '
# 實際行: 1, 位置: 235, 刪除: ' '
# 實際行: 1, 位置: 241, 刪除: ' '
# 實際行: 1, 位置: 246, 刪除: ' '
# 實際行: 1, 位置: 249, 刪除: ' '
# 實際行: 1, 位置: 252, 刪除: ' '
# 實際行: 1, 位置: 259, 刪除: ' '
# 實際行: 1, 位置: 262, 刪除: ' '
# 實際行: 1, 位置: 267, 刪除: ' '
# 實際行: 1, 位置: 270, 刪除: ' '
# 實際行: 1, 位置: 275, 刪除: 'C'
# 實際行: 1, 位置: 276, 刪除: 'O'
# 實際行: 1, 位置: 277, 刪除: 'N'
# 實際行: 1, 位置: 278, 刪除: 'D'
# 實際行: 1, 位置: 279, 刪除: 'I'
# 實際行: 1, 位置: 280, 刪除: 'T'
# 實際行: 1, 位置: 281, 刪除: 'I'
# 實際行: 1, 位置: 282, 刪除: 'O'
# 實際行: 1, 位置: 283, 刪除: 'N'
# 實際行: 1, 位置: 284, 刪除: 'E'
# 實際行: 1, 位置: 285, 刪除: 'R'
# 實際行: 1, 位置: 286, 刪除: ' '
# 實際行: 1, 位置: 287, 刪除: 'O'
# 實際行: 1, 位置: 288, 刪除: 'R'
# 實際行: 1, 位置: 289, 刪除: ' '
# 實際行: 1, 位置: 290, 刪除: 'F'
# 實際行: 1, 位置: 291, 刪除: 'A'
# 實際行: 1, 位置: 292, 刪除: 'U'
# 實際行: 1, 位置: 293, 刪除: 'C'
# 實際行: 1, 位置: 294, 刪除: 'E'
# 實際行: 1, 位置: 295, 刪除: 'T'
# 實際行: 1, 位置: 296, 刪除: ','
# 實際行: 1, 位置: 297, 刪除: ' '
# 實際行: 1, 位置: 298, 刪除: 'I'
# 實際行: 1, 位置: 299, 刪除: 'T'
# 實際行: 1, 位置: 300, 刪除: ' '
# 實際行: 1, 位置: 301, 刪除: 'I'
# 實際行: 1, 位置: 302, 刪除: 'S'
# 實際行: 1, 位置: 303, 刪除: ' '
# 實際行: 1, 位置: 304, 刪除: 'N'
# 實際行: 1, 位置: 305, 刪除: 'O'
# 實際行: 1, 位置: 306, 刪除: 'T'
# 實際行: 1, 位置: 307, 刪除: ' '
# 實際行: 1, 位置: 308, 刪除: 'O'
# 實際行: 1, 位置: 309, 刪除: 'N'
# 實際行: 1, 位置: 311, 刪除: 'Y'
# 實際行: 1, 位置: 312, 刪除: ' '
# 實際行: 1, 位置: 313, 刪除: 'A'
# 實際行: 1, 位置: 314, 刪除: ' '
# 實際行: 1, 位置: 315, 刪除: 'W'
# 實際行: 1, 位置: 316, 刪除: 'A'
# 實際行: 1, 位置: 317, 刪除: 'S'
# 實際行: 1, 位置: 318, 刪除: 'T'
# 實際行: 1, 位置: 320, 刪除: ' '
# 實際行: 1, 位置: 321, 刪除: 'O'
# 實際行: 1, 位置: 322, 刪除: 'F'
# 實際行: 1, 位置: 323, 刪除: ' '
# 實際行: 1, 位置: 324, 刪除: 'E'
# 實際行: 1, 位置: 325, 刪除: 'N'
# 實際行: 1, 位置: 326, 刪除: 'E'
# 實際行: 1, 位置: 327, 刪除: 'R'
# 實際行: 1, 位置: 328, 刪除: 'G'
# 實際行: 1, 位置: 329, 刪除: 'Y'
# 實際行: 1, 位置: 330, 刪除: ','
# 實際行: 1, 位置: 331, 刪除: ' '
# 實際行: 1, 位置: 332, 刪除: 'B'
# 實際行: 1, 位置: 333, 刪除: 'U'
# 實際行: 1, 位置: 335, 刪除: ' '
# 實際行: 1, 位置: 336, 刪除: 'A'
# 實際行: 1, 位置: 337, 刪除: 'L'
# 實際行: 1, 位置: 339, 刪除: 'O'
# 實際行: 1, 位置: 340, 刪除: ' '
# 實際行: 1, 位置: 341, 刪除: 'A'
# 實際行: 1, 位置: 342, 刪除: ' '
# 實際行: 1, 位置: 343, 刪除: 'R'
# 實際行: 1, 位置: 346, 刪除: 'S'
# 實際行: 1, 位置: 347, 刪除: 'O'
# 實際行: 1, 位置: 348, 刪除: 'N'
# 實際行: 1, 位置: 349, 刪除: ' '
# 實際行: 1, 位置: 350, 刪除: 'T'
# 實際行: 1, 位置: 351, 刪除: 'H'
# 實際行: 1, 位置: 352, 刪除: 'A'
# 實際行: 1, 位置: 353, 刪除: 'T'
# 實際行: 1, 位置: 354, 刪除: '
# '
# 實際行: 1, 位置: 355, 刪除: 'L'
# 實際行: 1, 位置: 356, 刪除: 'E'
# 實際行: 1, 位置: 357, 刪除: 'T'
# 實際行: 1, 位置: 358, 刪除: 'S'
# 實際行: 1, 位置: 359, 刪除: ' '
# 實際行: 1, 位置: 360, 刪除: 'E'
# 實際行: 1, 位置: 361, 刪除: 'A'
# 實際行: 1, 位置: 365, 刪除: ' '
# 實際行: 1, 位置: 380, 刪除: ' '
# 實際行: 1, 位置: 383, 刪除: ' '
# 實際行: 1, 位置: 387, 刪除: ' '
# 實際行: 1, 位置: 391, 刪除: ' '
# 實際行: 1, 位置: 394, 刪除: ' '
# 實際行: 1, 位置: 402, 刪除: ' '
# 實際行: 1, 位置: 406, 刪除: ' '
# 實際行: 1, 位置: 414, 刪除: ' '
# 實際行: 1, 位置: 420, 刪除: ' '
# 實際行: 1, 位置: 424, 刪除: ' '
# 實際行: 1, 位置: 428, 刪除: ' '
# 實際行: 1, 位置: 436, 刪除: ' '
# 實際行: 1, 位置: 439, 刪除: ' '
# 實際行: 1, 位置: 442, 刪除: ' '
# 實際行: 1, 位置: 450, 刪除: ' '
# 實際行: 1, 位置: 454, 刪除: ' '
# 實際行: 1, 位置: 458, 刪除: ' '
# 實際行: 1, 位置: 463, 刪除: ' '
# 實際行: 1, 位置: 471, 刪除: ' '
# 實際行: 1, 位置: 478, 刪除: ' '
# 實際行: 1, 位置: 486, 替換為: '（', 原字元: ' '
# 實際行: 1, 位置: 487, 刪除: '('
# 實際行: 1, 位置: 493, 刪除: ' '
# 實際行: 1, 位置: 496, 刪除: ' '
# 實際行: 1, 位置: 501, 刪除: ' '
# 實際行: 1, 位置: 507, 刪除: ' '
# 實際行: 1, 位置: 519, 刪除: ' '
# 實際行: 1, 位置: 526, 刪除: ' '
# 實際行: 1, 位置: 530, 刪除: ' '
# 實際行: 1, 位置: 536, 刪除: ' '
# 實際行: 1, 位置: 540, 刪除: ' '
# 實際行: 1, 位置: 546, 刪除: ' '
# 實際行: 1, 位置: 553, 刪除: ' '
# 實際行: 1, 位置: 559, 刪除: ' '
# 實際行: 1, 位置: 564, 刪除: ' '
# 實際行: 1, 位置: 572, 刪除: ' '
# 實際行: 1, 位置: 590, 刪除: ' '
# 實際行: 1, 位置: 593, 刪除: ' '
# 實際行: 1, 位置: 600, 刪除: ' '
# 實際行: 1, 位置: 604, 刪除: ' '
# 實際行: 1, 位置: 607, 刪除: ' '
# 實際行: 1, 位置: 613, 刪除: ' '
# 實際行: 1, 位置: 619, 刪除: ' '
# 實際行: 1, 位置: 622, 刪除: ' '
# 實際行: 1, 位置: 629, 刪除: ' '
# 實際行: 1, 位置: 638, 刪除: ' '
# 實際行: 1, 位置: 641, 刪除: ' '
# 實際行: 1, 位置: 649, 刪除: ' '
# 實際行: 1, 位置: 653, 刪除: ' '
# 實際行: 1, 位置: 669, 刪除: ' '
# 實際行: 1, 位置: 679, 刪除: ' '
# 實際行: 1, 位置: 682, 刪除: ' '
# 實際行: 1, 位置: 689, 刪除: ' '
# 實際行: 1, 位置: 699, 刪除: ' '
# 實際行: 1, 位置: 701, 刪除: ' '
# 實際行: 1, 位置: 706, 刪除: ' '
# 實際行: 1, 位置: 713, 刪除: ' '
# 實際行: 1, 位置: 725, 刪除: ' '
# 實際行: 1, 位置: 728, 刪除: ' '
# 實際行: 1, 位置: 738, 刪除: ' '
# 實際行: 1, 位置: 748, 刪除: ' '
# 實際行: 1, 位置: 754, 刪除: ' '
# 實際行: 1, 位置: 759, 刪除: ' '
# 實際行: 1, 位置: 764, 刪除: ' '
# 實際行: 1, 位置: 768, 刪除: ' '
# 實際行: 1, 位置: 772, 刪除: ' '
# 實際行: 1, 位置: 775, 刪除: ' '
# 實際行: 1, 位置: 780, 刪除: ' '
# 實際行: 1, 位置: 784, 刪除: ' '
# 實際行: 1, 位置: 788, 刪除: ' '
# 實際行: 1, 位置: 799, 刪除: ' '
# 實際行: 1, 位置: 811, 刪除: ' '
# 實際行: 1, 位置: 814, 刪除: ' '
# 實際行: 1, 位置: 829, 刪除: ' '
# 實際行: 1, 位置: 835, 刪除: ' '
# 實際行: 1, 位置: 843, 刪除: ' '
# 實際行: 1, 位置: 846, 刪除: ' '
# 實際行: 1, 位置: 850, 刪除: ' '
# 實際行: 1, 位置: 854, 刪除: ' '
# 實際行: 1, 位置: 866, 刪除: ' '
# 實際行: 1, 位置: 868, 刪除: ' '
# 實際行: 1, 位置: 877, 刪除: ' '
# 實際行: 1, 位置: 880, 刪除: ' '
# 實際行: 1, 位置: 883, 刪除: ' '
# 實際行: 1, 位置: 887, 刪除: ' '
# 實際行: 1, 位置: 892, 刪除: ' '
# 實際行: 1, 位置: 907, 刪除: ' '
# 實際行: 1, 位置: 913, 刪除: ' '
# 實際行: 1, 位置: 917, 刪除: ' '
# 實際行: 1, 位置: 921, 刪除: ' '
# 實際行: 1, 位置: 927, 刪除: ' '
# 實際行: 1, 位置: 936, 刪除: ' '
# 實際行: 1, 位置: 943, 刪除: ' '
# 實際行: 1, 位置: 953, 刪除: ' '
# 實際行: 1, 位置: 957, 刪除: ' '
# 實際行: 1, 位置: 966, 刪除: ' '
# 實際行: 1, 位置: 978, 刪除: ' '
# 實際行: 1, 位置: 981, 刪除: ' '
# 實際行: 1, 位置: 983, 刪除: ' '
# 實際行: 1, 位置: 991, 刪除: ' '
# 實際行: 1, 位置: 997, 刪除: ' '
# 實際行: 1, 位置: 1003, 刪除: ' '
# 實際行: 1, 位置: 1005, 替換為: 'O', 原字元: '0'
# 實際行: 1, 位置: 1006, 替換為: 'O', 原字元: '0'
# 實際行: 1, 位置: 1007, 刪除: ' '
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_detailed\4_ocr_detailed_20250512_103802.txt
#
# OCR 和 CER 計算完成 (含詳細錯誤)。

# %% [markdown]
# 前十張OCR

# %%
from paddleocr_backup import PaddleOCR
import os
import datetime
from PIL import Image
import Levenshtein

def calculate_cer_with_details(ground_truth, prediction):
    """計算字元錯誤率 (CER) 並返回詳細的錯誤信息"""
    if not ground_truth:
        return 1.0 if prediction else 0.0, []
    if not prediction:
        return 1.0, []

    ground_truth = ground_truth.upper()
    prediction = prediction.upper()

    distance = Levenshtein.distance(ground_truth, prediction)
    cer = distance / len(ground_truth)
    details = []

    operations = Levenshtein.editops(ground_truth, prediction)
    gt_index = 0
    pred_index = 0
    gt_lines = ground_truth.splitlines()
    pred_lines = prediction.splitlines()
    gt_line_index = 0
    pred_line_index = 0
    gt_char_index = 0
    pred_char_index = 0

    for op, gt_pos, pred_pos in operations:
        # 找到對應的行號和字元位置 (這部分可能不完全精確，因為 OCR 結果可能是多行)
        temp_gt_index = 0
        for i, line in enumerate(gt_lines):
            if temp_gt_index <= gt_pos < temp_gt_index + len(line) + 1:
                gt_line_index = i + 1
                gt_char_index = gt_pos - temp_gt_index + 1
                break
            temp_gt_index += len(line) + 1

        temp_pred_index = 0
        for i, line in enumerate(pred_lines):
            if temp_pred_index <= pred_pos < temp_pred_index + len(line) + 1:
                pred_line_index = i + 1
                pred_char_index = pred_pos - temp_pred_index + 1
                break
            temp_pred_index += len(line) + 1

        if op == 'insert':
            details.append(f"預測行: {pred_line_index}, 位置: {pred_char_index}, 插入: '{prediction[pred_pos]}'")
        elif op == 'delete':
            details.append(f"實際行: {gt_line_index}, 位置: {gt_char_index}, 刪除: '{ground_truth[gt_pos]}'")
        elif op == 'replace':
            details.append(f"實際行: {gt_line_index}, 位置: {gt_char_index}, 替換為: '{prediction[pred_pos]}', 原字元: '{ground_truth[gt_pos]}'")

    return cer, details

# 指定圖片資料夾路徑
images_folder = r'C:\Users\User\Desktop\PaddleOCR\images'
# 指定 ground_truth 文本資料夾路徑
ground_truth_folder = r'C:\Users\User\Desktop\PaddleOCR\txt'
# 指定 OCR 輸出文本資料夾路徑
ocr_output_folder = r'C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed'

# 指定要處理的圖片數量
num_images_to_process = 10

# 確保輸出資料夾存在，如果不存在則創建
if not os.path.exists(ocr_output_folder):
    os.makedirs(ocr_output_folder)
    print(f"已創建 OCR 輸出資料夾：{ocr_output_folder}")

# 確保圖片和 ground_truth 資料夾存在
if not os.path.exists(images_folder):
    print(f"錯誤：圖片資料夾 '{images_folder}' 不存在。請檢查路徑是否正確。")
elif not os.path.exists(ground_truth_folder):
    print(f"錯誤：ground_truth 文本資料夾 '{ground_truth_folder}' 不存在。請檢查路徑是否正確。")
else:
    # 獲取圖片文件列表
    all_files = os.listdir(images_folder)
    image_files = sorted([f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))])

    if not image_files:
        print(f"錯誤：圖片資料夾 '{images_folder}' 中沒有找到任何圖片文件。")
    else:
        # 初始化 OCR 模型
        ocr = PaddleOCR(use_angle_cls=True, lang="en", use_gpu=False)
        print(f"即將對資料夾 '{images_folder}' 中的前 {min(num_images_to_process, len(image_files))} 張圖片執行 OCR 並計算 CER (含詳細錯誤)...")

        total_cer = 0.0
        cer_values = {}
        processed_count = 0

        for i, image_file in enumerate(image_files[:num_images_to_process]):
            image_path = os.path.join(images_folder, image_file)
            image_name_without_ext = os.path.splitext(image_file)[0]
            ground_truth_file_path = os.path.join(ground_truth_folder, f"{image_name_without_ext}.txt")
            ocr_output_text = ""
            ground_truth_text = ""
            current_cer = 0.0
            error_details = []

            print(f"\n正在處理圖片 '{image_path}'...")

            # 執行 OCR 識別
            result = ocr.ocr(image_path, cls=True)

            if result and result[0]:
                for line in result[0]:
                    text = line[1][0]
                    ocr_output_text += text + "\n"
                ocr_output_text = ocr_output_text.strip()

                # 讀取 ground_truth 文本
                if os.path.exists(ground_truth_file_path):
                    try:
                        with open(ground_truth_file_path, 'r', encoding='utf-8') as f:
                            ground_truth_text = f.read().strip()
                    except IOError as e:
                        print(f"讀取 ground_truth 文件 '{ground_truth_file_path}' 時發生錯誤: {e}")
                else:
                    print(f"警告：找不到對應的 ground_truth 文件 '{ground_truth_file_path}'。")

                # 計算 CER 並獲取詳細錯誤
                if ground_truth_text:
                    current_cer, error_details = calculate_cer_with_details(ground_truth_text, ocr_output_text)
                    cer_values[image_file] = current_cer
                    total_cer += current_cer
                    processed_count += 1
                    print(f"圖片 '{image_file}' 的 CER: {current_cer:.4f}")
                    if error_details:
                        print("詳細錯誤：")
                        for detail in error_details:
                            print(detail)
                    else:
                        print("沒有發現字元錯誤。")

                # 保存 OCR 輸出到 .txt 文件
                timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
                ocr_output_filename = f"{image_name_without_ext}_ocr_detailed_{timestamp}.txt"
                ocr_output_path = os.path.join(ocr_output_folder, ocr_output_filename)
                try:
                    with open(ocr_output_path, 'w', encoding='utf-8') as f:
                        f.write(ocr_output_text)
                    print(f"OCR 輸出已保存到：{ocr_output_path}")
                except IOError as e:
                    print(f"保存 OCR 輸出文件時發生錯誤: {e}")

            else:
                print("未在圖片中識別到任何文字。")

            if i + 1 == num_images_to_process:
                break

        if processed_count > 0:
            average_cer = total_cer / processed_count
            print(f"\n前 {processed_count} 張圖片的總 CER (平均): {average_cer:.4f}")
        else:
            print("\n沒有成功處理任何圖片並計算 CER。")

print("\nOCR 和 CER 計算完成 (含詳細錯誤)。")
# Out:
# 已創建 OCR 輸出資料夾：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed
# [2025/05/11 23:26:51] ppocr DEBUG: Namespace(alpha=1.0, alphacolor=(255, 255, 255), benchmark=False, beta=1.0, binarize=False, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='C:\\Users\\User/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='C:\\Users\\User/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, formula=False, formula_algorithm='LaTeXOCR', formula_batch_num=1, formula_char_dict_path=None, formula_model_dir=None, fourier_degree=5, gpu_id=0, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, invert=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='en', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv4', onnx_providers=False, onnx_sess_options=False, output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='c:\\Users\\User\\anaconda3\\envs\\pytorch_env\\lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='C:\\Users\\User/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', recovery=False, recovery_to_markdown=False, return_word_box=False, save_crop_res=False, save_log_path='./log_output/', savefile=False, scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=True, use_dilation=False, use_gcu=False, use_gpu=False, use_mlu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# 即將對資料夾 'C:\Users\User\Desktop\PaddleOCR\images' 中的前 10 張圖片執行 OCR 並計算 CER (含詳細錯誤)...
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00000.jpg'...
# [2025/05/11 23:27:01] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.6673891544342041
# [2025/05/11 23:27:01] ppocr DEBUG: cls num  : 12, elapsed : 0.12439274787902832
# [2025/05/11 23:27:02] ppocr DEBUG: rec_res num  : 12, elapsed : 1.018799066543579
# 警告：找不到對應的 ground_truth 文件 'C:\Users\User\Desktop\PaddleOCR\txt\image_00000.txt'。
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00000_ocr_detailed_20250511_232702.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00001.jpg'...
# [2025/05/11 23:27:02] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.08367919921875
# [2025/05/11 23:27:03] ppocr DEBUG: cls num  : 11, elapsed : 0.18998289108276367
# [2025/05/11 23:27:04] ppocr DEBUG: rec_res num  : 11, elapsed : 0.9187870025634766
# 警告：找不到對應的 ground_truth 文件 'C:\Users\User\Desktop\PaddleOCR\txt\image_00001.txt'。
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00001_ocr_detailed_20250511_232704.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00002.jpg'...
# [2025/05/11 23:27:04] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.09909534454345703
# [2025/05/11 23:27:04] ppocr DEBUG: cls num  : 12, elapsed : 0.061409711837768555
# [2025/05/11 23:27:05] ppocr DEBUG: rec_res num  : 12, elapsed : 1.1342239379882812
# 警告：找不到對應的 ground_truth 文件 'C:\Users\User\Desktop\PaddleOCR\txt\image_00002.txt'。
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00002_ocr_detailed_20250511_232705.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00003.jpg'...
# [2025/05/11 23:27:05] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.09020423889160156
# [2025/05/11 23:27:05] ppocr DEBUG: cls num  : 10, elapsed : 0.19057583808898926
# [2025/05/11 23:27:06] ppocr DEBUG: rec_res num  : 10, elapsed : 0.9394834041595459
# 警告：找不到對應的 ground_truth 文件 'C:\Users\User\Desktop\PaddleOCR\txt\image_00003.txt'。
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00003_ocr_detailed_20250511_232706.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00004.jpg'...
# [2025/05/11 23:27:06] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.0901784896850586
# [2025/05/11 23:27:06] ppocr DEBUG: cls num  : 8, elapsed : 0.16709089279174805
# [2025/05/11 23:27:07] ppocr DEBUG: rec_res num  : 8, elapsed : 0.745887041091919
# 警告：找不到對應的 ground_truth 文件 'C:\Users\User\Desktop\PaddleOCR\txt\image_00004.txt'。
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00004_ocr_detailed_20250511_232707.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00005.jpg'...
# [2025/05/11 23:27:07] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.28757810592651367
# [2025/05/11 23:27:08] ppocr DEBUG: cls num  : 11, elapsed : 0.12936115264892578
# [2025/05/11 23:27:08] ppocr DEBUG: rec_res num  : 11, elapsed : 0.7721946239471436
# 警告：找不到對應的 ground_truth 文件 'C:\Users\User\Desktop\PaddleOCR\txt\image_00005.txt'。
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00005_ocr_detailed_20250511_232708.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00006.jpg'...
# [2025/05/11 23:27:08] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.08968234062194824
# [2025/05/11 23:27:09] ppocr DEBUG: cls num  : 11, elapsed : 0.0362546443939209
# [2025/05/11 23:27:09] ppocr DEBUG: rec_res num  : 11, elapsed : 0.6573703289031982
# 警告：找不到對應的 ground_truth 文件 'C:\Users\User\Desktop\PaddleOCR\txt\image_00006.txt'。
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00006_ocr_detailed_20250511_232709.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00007.jpg'...
# [2025/05/11 23:27:09] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.09892916679382324
# [2025/05/11 23:27:09] ppocr DEBUG: cls num  : 12, elapsed : 0.058249711990356445
# [2025/05/11 23:27:10] ppocr DEBUG: rec_res num  : 12, elapsed : 0.7375442981719971
# 警告：找不到對應的 ground_truth 文件 'C:\Users\User\Desktop\PaddleOCR\txt\image_00007.txt'。
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00007_ocr_detailed_20250511_232710.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00008.jpg'...
# [2025/05/11 23:27:10] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.09874749183654785
# [2025/05/11 23:27:10] ppocr DEBUG: cls num  : 10, elapsed : 0.14682841300964355
# [2025/05/11 23:27:11] ppocr DEBUG: rec_res num  : 10, elapsed : 0.6504604816436768
# 警告：找不到對應的 ground_truth 文件 'C:\Users\User\Desktop\PaddleOCR\txt\image_00008.txt'。
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00008_ocr_detailed_20250511_232711.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00009.jpg'...
# [2025/05/11 23:27:11] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.0738980770111084
# [2025/05/11 23:27:11] ppocr DEBUG: cls num  : 6, elapsed : 0.016352176666259766
# [2025/05/11 23:27:11] ppocr DEBUG: rec_res num  : 6, elapsed : 0.23260498046875
# 警告：找不到對應的 ground_truth 文件 'C:\Users\User\Desktop\PaddleOCR\txt\image_00009.txt'。
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00009_ocr_detailed_20250511_232711.txt
#
# 沒有成功處理任何圖片並計算 CER。
#
# OCR 和 CER 計算完成 (含詳細錯誤)。

# %% [markdown]
# _-------

# %%
from paddleocr_backup import PaddleOCR
import os
import datetime
from PIL import Image
import Levenshtein

def calculate_cer_with_details(ground_truth, prediction):
    """計算字元錯誤率 (CER) 並返回詳細的錯誤信息"""
    if not ground_truth:
        return 1.0 if prediction else 0.0, []
    if not prediction:
        return 1.0, []

    ground_truth = ground_truth.upper()
    prediction = prediction.upper()

    distance = Levenshtein.distance(ground_truth, prediction)
    cer = distance / len(ground_truth)
    details = []

    operations = Levenshtein.editops(ground_truth, prediction)
    gt_index = 0
    pred_index = 0
    gt_lines = ground_truth.splitlines()
    pred_lines = prediction.splitlines()
    gt_line_index = 0
    pred_line_index = 0
    gt_char_index = 0
    pred_char_index = 0

    for op, gt_pos, pred_pos in operations:
        # 找到對應的行號和字元位置 (這部分可能不完全精確，因為 OCR 結果可能是多行)
        temp_gt_index = 0
        for i, line in enumerate(gt_lines):
            if temp_gt_index <= gt_pos < temp_gt_index + len(line) + 1:
                gt_line_index = i + 1
                gt_char_index = gt_pos - temp_gt_index + 1
                break
            temp_gt_index += len(line) + 1

        temp_pred_index = 0
        for i, line in enumerate(pred_lines):
            if temp_pred_index <= pred_pos < temp_pred_index + len(line) + 1:
                pred_line_index = i + 1
                pred_char_index = pred_pos - temp_pred_index + 1
                break
            temp_pred_index += len(line) + 1

        if op == 'insert':
            details.append(f"預測行: {pred_line_index}, 位置: {pred_char_index}, 插入: '{prediction[pred_pos]}'")
        elif op == 'delete':
            details.append(f"實際行: {gt_line_index}, 位置: {gt_char_index}, 刪除: '{ground_truth[gt_pos]}'")
        elif op == 'replace':
            details.append(f"實際行: {gt_line_index}, 位置: {gt_char_index}, 替換為: '{prediction[pred_pos]}', 原字元: '{ground_truth[gt_pos]}'")

    return cer, details

# 指定圖片資料夾路徑
images_folder = r'C:\Users\User\Desktop\PaddleOCR\images'
# 指定 ground_truth 文本資料夾路徑
ground_truth_folder = r'C:\Users\User\Desktop\PaddleOCR\txt'
# 指定 OCR 輸出文本資料夾路徑
ocr_output_folder = r'C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed'

# 指定要處理的圖片數量
num_images_to_process = 50

# 確保輸出資料夾存在，如果不存在則創建
if not os.path.exists(ocr_output_folder):
    os.makedirs(ocr_output_folder)
    print(f"已創建 OCR 輸出資料夾：{ocr_output_folder}")

# 確保圖片和 ground_truth 資料夾存在
if not os.path.exists(images_folder):
    print(f"錯誤：圖片資料夾 '{images_folder}' 不存在。請檢查路徑是否正確。")
elif not os.path.exists(ground_truth_folder):
    print(f"錯誤：ground_truth 文本資料夾 '{ground_truth_folder}' 不存在。請檢查路徑是否正確。")
else:
    # 獲取圖片文件列表
    all_files = os.listdir(images_folder)
    image_files = sorted([f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))])

    if not image_files:
        print(f"錯誤：圖片資料夾 '{images_folder}' 中沒有找到任何圖片文件。")
    else:
        # 初始化 OCR 模型
        # lang="ch" 是中文模型，如果您要識別中文，請使用這個
        # lang="en" 是英文模型
        ocr = PaddleOCR(use_angle_cls=True, lang="ch", use_gpu=False) # 將語言改為中文

        print(f"即將對資料夾 '{images_folder}' 中的前 {min(num_images_to_process, len(image_files))} 張圖片執行 OCR 並計算 CER (含詳細錯誤)...")

        total_cer = 0.0
        cer_values = {}
        processed_count = 0

        for i, image_file in enumerate(image_files[:num_images_to_process]):
            image_path = os.path.join(images_folder, image_file)
            image_name_without_ext = os.path.splitext(image_file)[0] # 例如: "image_00000"

            # *** 關鍵修改部分 ***
            # 從 "image_00000" 提取數字部分 "00000"
            file_index = image_name_without_ext.split('_')[1]
            ground_truth_file_path = os.path.join(ground_truth_folder, f"label_{file_index}.txt")
            # *********************

            ocr_output_text = ""
            ground_truth_text = ""
            current_cer = 0.0
            error_details = []

            print(f"\n正在處理圖片 '{image_path}'...")

            # 執行 OCR 識別
            result = ocr.ocr(image_path, cls=True)

            if result and result[0]:
                for line in result[0]:
                    text = line[1][0]
                    ocr_output_text += text + "\n"
                ocr_output_text = ocr_output_text.strip()

                # 讀取 ground_truth 文本
                if os.path.exists(ground_truth_file_path):
                    try:
                        with open(ground_truth_file_path, 'r', encoding='utf-8') as f:
                            ground_truth_text = f.read().strip()
                    except IOError as e:
                        print(f"讀取 ground_truth 文件 '{ground_truth_file_path}' 時發生錯誤: {e}")
                else:
                    print(f"警告：找不到對應的 ground_truth 文件 '{ground_truth_file_path}'。")

                # 計算 CER 並獲取詳細錯誤
                if ground_truth_text:
                    current_cer, error_details = calculate_cer_with_details(ground_truth_text, ocr_output_text)
                    cer_values[image_file] = current_cer
                    total_cer += current_cer
                    processed_count += 1
                    print(f"圖片 '{image_file}' 的 CER: {current_cer:.4f}")
                    if error_details:
                        print("詳細錯誤：")
                        for detail in error_details:
                            print(detail)
                    else:
                        print("沒有發現字元錯誤。")

                # 保存 OCR 輸出到 .txt 文件
                timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
                ocr_output_filename = f"{image_name_without_ext}_ocr_detailed_{timestamp}.txt"
                ocr_output_path = os.path.join(ocr_output_folder, ocr_output_filename)
                try:
                    with open(ocr_output_path, 'w', encoding='utf-8') as f:
                        f.write(ocr_output_text)
                    print(f"OCR 輸出已保存到：{ocr_output_path}")
                except IOError as e:
                    print(f"保存 OCR 輸出文件時發生錯誤: {e}")

            else:
                print("未在圖片中識別到任何文字。")

            if i + 1 == num_images_to_process:
                break

        if processed_count > 0:
            average_cer = total_cer / processed_count
            print(f"\n前 {processed_count} 張圖片的總 CER (平均): {average_cer:.4f}")
        else:
            print("\n沒有成功處理任何圖片並計算 CER。")

print("\nOCR 和 CER 計算完成 (含詳細錯誤)。")
# Out:
# [2025/05/11 23:36:09] ppocr DEBUG: Namespace(alpha=1.0, alphacolor=(255, 255, 255), benchmark=False, beta=1.0, binarize=False, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='C:\\Users\\User/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='C:\\Users\\User/.paddleocr/whl\\det\\ch\\ch_PP-OCRv4_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, formula=False, formula_algorithm='LaTeXOCR', formula_batch_num=1, formula_char_dict_path=None, formula_model_dir=None, fourier_degree=5, gpu_id=0, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, invert=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='ch', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv4', onnx_providers=False, onnx_sess_options=False, output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='c:\\Users\\User\\anaconda3\\envs\\pytorch_env\\lib\\site-packages\\paddleocr\\ppocr\\utils\\ppocr_keys_v1.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='C:\\Users\\User/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv4_rec_infer', recovery=False, recovery_to_markdown=False, return_word_box=False, save_crop_res=False, save_log_path='./log_output/', savefile=False, scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=True, use_dilation=False, use_gcu=False, use_gpu=False, use_mlu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# 即將對資料夾 'C:\Users\User\Desktop\PaddleOCR\images' 中的前 50 張圖片執行 OCR 並計算 CER (含詳細錯誤)...
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00000.jpg'...
# [2025/05/11 23:36:11] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.1367053985595703
# [2025/05/11 23:36:11] ppocr DEBUG: cls num  : 10, elapsed : 0.1317894458770752
# [2025/05/11 23:36:12] ppocr DEBUG: rec_res num  : 10, elapsed : 0.6391603946685791
# 圖片 'image_00000.jpg' 的 CER: 0.5106
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '刷'
# 預測行: 3, 位置: 3, 插入: '
# '
# 預測行: 4, 位置: 2, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 5, 位置: 1, 插入: '出'
# 預測行: 5, 位置: 2, 插入: '生'
# 預測行: 5, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 6, 位置: 11, 插入: '日'
# 預測行: 7, 位置: 1, 插入: '住'
# 預測行: 7, 位置: 2, 插入: '址'
# 預測行: 7, 位置: 3, 插入: '
# '
# 預測行: 8, 位置: 9, 插入: '
# '
# 預測行: 10, 位置: 1, 插入: '公'
# 預測行: 10, 位置: 2, 插入: '民'
# 預測行: 10, 位置: 3, 插入: '身'
# 預測行: 10, 位置: 4, 插入: '份'
# 預測行: 10, 位置: 5, 插入: '号'
# 預測行: 10, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00000_ocr_detailed_20250511_233612.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00001.jpg'...
# [2025/05/11 23:36:12] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.10071039199829102
# [2025/05/11 23:36:12] ppocr DEBUG: cls num  : 12, elapsed : 0.03540182113647461
# [2025/05/11 23:36:13] ppocr DEBUG: rec_res num  : 12, elapsed : 0.6519348621368408
# 圖片 'image_00001.jpg' 的 CER: 0.4800
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 3, 插入: '
# '
# 預測行: 5, 位置: 1, 插入: '民'
# 預測行: 5, 位置: 2, 插入: '旗'
# 預測行: 6, 位置: 1, 插入: '出'
# 預測行: 6, 位置: 2, 插入: '生'
# 預測行: 6, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 7, 位置: 10, 插入: '日'
# 預測行: 8, 位置: 1, 插入: '住'
# 預測行: 8, 位置: 2, 插入: '址'
# 預測行: 8, 位置: 3, 插入: '
# '
# 預測行: 9, 位置: 9, 插入: '
# '
# 預測行: 10, 位置: 6, 插入: '
# '
# 預測行: 11, 位置: 1, 插入: '民'
# 預測行: 11, 位置: 2, 插入: '身'
# 預測行: 11, 位置: 3, 插入: '份'
# 預測行: 11, 位置: 4, 插入: '号'
# 預測行: 11, 位置: 5, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00001_ocr_detailed_20250511_233613.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00002.jpg'...
# [2025/05/11 23:36:13] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.11866235733032227
# [2025/05/11 23:36:13] ppocr DEBUG: cls num  : 12, elapsed : 0.03757643699645996
# [2025/05/11 23:36:14] ppocr DEBUG: rec_res num  : 12, elapsed : 0.7095756530761719
# 圖片 'image_00002.jpg' 的 CER: 0.5000
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 4, 位置: 1, 插入: '民'
# 預測行: 4, 位置: 2, 插入: '族'
# 預測行: 5, 位置: 1, 插入: '性'
# 預測行: 5, 位置: 2, 插入: '别'
# 預測行: 5, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 6, 位置: 10, 插入: '日'
# 預測行: 7, 位置: 1, 插入: '出'
# 預測行: 7, 位置: 2, 插入: '生'
# 預測行: 7, 位置: 3, 插入: '
# '
# 預測行: 8, 位置: 9, 插入: '
# '
# 預測行: 9, 位置: 1, 插入: '住'
# 預測行: 9, 位置: 2, 插入: '址'
# 預測行: 9, 位置: 3, 插入: '
# '
# 預測行: 11, 位置: 19, 插入: '
# '
# 預測行: 12, 位置: 1, 插入: '公'
# 預測行: 12, 位置: 2, 插入: '民'
# 預測行: 12, 位置: 3, 插入: '身'
# 預測行: 12, 位置: 4, 插入: '份'
# 預測行: 12, 位置: 5, 插入: '号'
# 預測行: 12, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00002_ocr_detailed_20250511_233614.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00003.jpg'...
# [2025/05/11 23:36:14] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.11111235618591309
# [2025/05/11 23:36:14] ppocr DEBUG: cls num  : 9, elapsed : 0.12369132041931152
# [2025/05/11 23:36:14] ppocr DEBUG: rec_res num  : 9, elapsed : 0.40670132637023926
# 圖片 'image_00003.jpg' 的 CER: 0.5000
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 實際行: 1, 位置: 3, 替換為: '照', 原字元: '熙'
# 預測行: 2, 位置: 1, 插入: '性'
# 預測行: 2, 位置: 2, 插入: '别'
# 預測行: 2, 位置: 4, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 3, 位置: 1, 插入: '出'
# 預測行: 3, 位置: 2, 插入: '生'
# 預測行: 3, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 5, 位置: 1, 插入: '住'
# 預測行: 5, 位置: 2, 插入: '址'
# 預測行: 5, 位置: 3, 插入: '
# '
# 預測行: 7, 位置: 19, 插入: '
# '
# 預測行: 8, 位置: 1, 插入: '公'
# 預測行: 8, 位置: 2, 插入: '民'
# 預測行: 8, 位置: 3, 插入: '身'
# 預測行: 8, 位置: 4, 插入: '份'
# 預測行: 8, 位置: 5, 插入: '导'
# 預測行: 8, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00003_ocr_detailed_20250511_233614.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00004.jpg'...
# [2025/05/11 23:36:14] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.1171407699584961
# [2025/05/11 23:36:15] ppocr DEBUG: cls num  : 8, elapsed : 0.1459805965423584
# [2025/05/11 23:36:15] ppocr DEBUG: rec_res num  : 8, elapsed : 0.5516090393066406
# 圖片 'image_00004.jpg' 的 CER: 0.2222
# 詳細錯誤：
# 預測行: 3, 位置: 1, 插入: '民'
# 預測行: 3, 位置: 2, 插入: '族'
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 4, 位置: 9, 插入: '日'
# 預測行: 5, 位置: 9, 插入: '
# '
# 預測行: 6, 位置: 2, 插入: '
# '
# 預測行: 7, 位置: 1, 插入: '份'
# 預測行: 7, 位置: 2, 插入: '号'
# 預測行: 7, 位置: 3, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00004_ocr_detailed_20250511_233615.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00005.jpg'...
# [2025/05/11 23:36:15] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.23383235931396484
# [2025/05/11 23:36:15] ppocr DEBUG: cls num  : 10, elapsed : 0.054143428802490234
# [2025/05/11 23:36:16] ppocr DEBUG: rec_res num  : 10, elapsed : 0.5370101928710938
# 圖片 'image_00005.jpg' 的 CER: 0.5106
# 詳細錯誤：
# 預測行: 2, 位置: 1, 插入: '姓'
# 預測行: 2, 位置: 2, 插入: '名'
# 預測行: 2, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 2, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '旅', 原字元: '
# '
# 預測行: 4, 位置: 1, 插入: '性'
# 預測行: 4, 位置: 2, 插入: '财'
# 預測行: 4, 位置: 3, 插入: '
# '
# 預測行: 5, 位置: 1, 插入: '出'
# 預測行: 5, 位置: 2, 插入: '生'
# 預測行: 5, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 6, 位置: 11, 插入: '日'
# 預測行: 7, 位置: 9, 插入: '
# '
# 預測行: 8, 位置: 1, 插入: '佳'
# 預測行: 8, 位置: 2, 插入: '址'
# 預測行: 8, 位置: 3, 插入: '
# '
# 預測行: 10, 位置: 1, 插入: '公'
# 預測行: 10, 位置: 2, 插入: '民'
# 預測行: 10, 位置: 3, 插入: '身'
# 預測行: 10, 位置: 4, 插入: '份'
# 預測行: 10, 位置: 5, 插入: '号'
# 預測行: 10, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00005_ocr_detailed_20250511_233616.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00006.jpg'...
# [2025/05/11 23:36:16] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.11548590660095215
# [2025/05/11 23:36:16] ppocr DEBUG: cls num  : 11, elapsed : 0.1720893383026123
# [2025/05/11 23:36:17] ppocr DEBUG: rec_res num  : 11, elapsed : 0.49085164070129395
# 圖片 'image_00006.jpg' 的 CER: 0.5814
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 實際行: 1, 位置: 3, 替換為: '棋', 原字元: '祺'
# 預測行: 4, 位置: 1, 插入: '民'
# 預測行: 4, 位置: 2, 插入: '族'
# 預測行: 5, 位置: 1, 插入: '性'
# 預測行: 5, 位置: 2, 插入: '别'
# 預測行: 5, 位置: 3, 插入: '
# '
# 預測行: 6, 位置: 1, 插入: '出'
# 預測行: 6, 位置: 2, 插入: '生'
# 預測行: 6, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 7, 位置: 10, 插入: '日'
# 預測行: 8, 位置: 1, 插入: '住'
# 預測行: 8, 位置: 2, 插入: '址'
# 預測行: 8, 位置: 3, 插入: '
# '
# 預測行: 9, 位置: 7, 插入: '
# '
# 預測行: 10, 位置: 1, 插入: '公'
# 預測行: 10, 位置: 2, 插入: '民'
# 預測行: 10, 位置: 3, 插入: '身'
# 預測行: 10, 位置: 4, 插入: '份'
# 預測行: 10, 位置: 5, 插入: '号'
# 預測行: 10, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00006_ocr_detailed_20250511_233617.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00007.jpg'...
# [2025/05/11 23:36:17] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.09399867057800293
# [2025/05/11 23:36:17] ppocr DEBUG: cls num  : 9, elapsed : 0.10484719276428223
# [2025/05/11 23:36:17] ppocr DEBUG: rec_res num  : 9, elapsed : 0.41719985008239746
# 圖片 'image_00007.jpg' 的 CER: 0.5435
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 實際行: 1, 位置: 3, 替換為: '暖', 原字元: '瑗'
# 預測行: 2, 位置: 1, 插入: '性'
# 預測行: 2, 位置: 2, 插入: '别'
# 預測行: 2, 位置: 4, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 3, 位置: 1, 插入: '出'
# 預測行: 3, 位置: 2, 插入: '生'
# 預測行: 3, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 4, 位置: 10, 插入: '日'
# 預測行: 5, 位置: 1, 插入: '住'
# 預測行: 5, 位置: 2, 插入: '址'
# 預測行: 5, 位置: 3, 插入: '
# '
# 預測行: 6, 位置: 9, 插入: '
# '
# 預測行: 7, 位置: 1, 插入: '音'
# 預測行: 7, 位置: 2, 插入: '
# '
# 預測行: 8, 位置: 1, 插入: '公'
# 預測行: 8, 位置: 2, 插入: '民'
# 預測行: 8, 位置: 3, 插入: '身'
# 預測行: 8, 位置: 4, 插入: '份'
# 預測行: 8, 位置: 5, 插入: '号'
# 實際行: 7, 位置: 9, 替換為: '码', 原字元: '县'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00007_ocr_detailed_20250511_233617.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00008.jpg'...
# [2025/05/11 23:36:17] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.12431621551513672
# [2025/05/11 23:36:18] ppocr DEBUG: cls num  : 11, elapsed : 0.04236459732055664
# [2025/05/11 23:36:18] ppocr DEBUG: rec_res num  : 11, elapsed : 0.4416983127593994
# 圖片 'image_00008.jpg' 的 CER: 0.5581
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 3, 插入: '
# '
# 預測行: 5, 位置: 1, 插入: '民'
# 預測行: 5, 位置: 2, 插入: '族'
# 預測行: 6, 位置: 1, 插入: '出'
# 預測行: 6, 位置: 2, 插入: '生'
# 預測行: 6, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 7, 位置: 10, 插入: '日'
# 預測行: 8, 位置: 1, 插入: '住'
# 預測行: 8, 位置: 2, 插入: '址'
# 預測行: 8, 位置: 3, 插入: '
# '
# 預測行: 9, 位置: 7, 插入: '
# '
# 預測行: 10, 位置: 1, 插入: '公'
# 預測行: 10, 位置: 2, 插入: '民'
# 預測行: 10, 位置: 3, 插入: '身'
# 預測行: 10, 位置: 4, 插入: '份'
# 預測行: 10, 位置: 5, 插入: '号'
# 預測行: 10, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00008_ocr_detailed_20250511_233618.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00009.jpg'...
# [2025/05/11 23:36:18] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.10601973533630371
# [2025/05/11 23:36:18] ppocr DEBUG: cls num  : 8, elapsed : 0.04143118858337402
# [2025/05/11 23:36:18] ppocr DEBUG: rec_res num  : 8, elapsed : 0.36041808128356934
# 圖片 'image_00009.jpg' 的 CER: 0.3400
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 2, 位置: 1, 插入: '性'
# 預測行: 2, 位置: 2, 插入: '制'
# 預測行: 2, 位置: 4, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 3, 位置: 1, 插入: '出'
# 預測行: 3, 位置: 2, 插入: '生'
# 預測行: 3, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 5, 位置: 9, 插入: '
# '
# 預測行: 7, 位置: 1, 插入: '公'
# 預測行: 7, 位置: 2, 插入: '民'
# 預測行: 7, 位置: 3, 插入: '身'
# 預測行: 7, 位置: 4, 插入: '号'
# 預測行: 7, 位置: 5, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00009_ocr_detailed_20250511_233618.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00010.jpg'...
# [2025/05/11 23:36:19] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.10305094718933105
# [2025/05/11 23:36:19] ppocr DEBUG: cls num  : 8, elapsed : 0.11282014846801758
# [2025/05/11 23:36:19] ppocr DEBUG: rec_res num  : 8, elapsed : 0.4147651195526123
# 圖片 'image_00010.jpg' 的 CER: 0.2500
# 詳細錯誤：
# 實際行: 2, 位置: 1, 替換為: '民', 原字元: '女'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 3, 位置: 1, 插入: '女'
# 預測行: 3, 位置: 2, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 4, 位置: 11, 插入: '日'
# 預測行: 5, 位置: 9, 插入: '
# '
# 預測行: 7, 位置: 19, 插入: '
# '
# 預測行: 8, 位置: 1, 插入: '身'
# 預測行: 8, 位置: 2, 插入: '份'
# 預測行: 8, 位置: 3, 插入: '号'
# 預測行: 8, 位置: 4, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00010_ocr_detailed_20250511_233619.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00011.jpg'...
# [2025/05/11 23:36:19] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.19795799255371094
# [2025/05/11 23:36:19] ppocr DEBUG: cls num  : 12, elapsed : 0.037802696228027344
# [2025/05/11 23:36:20] ppocr DEBUG: rec_res num  : 12, elapsed : 0.652625560760498
# 圖片 'image_00011.jpg' 的 CER: 0.4808
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 3, 插入: '
# '
# 預測行: 5, 位置: 1, 插入: '民'
# 預測行: 5, 位置: 2, 插入: '族'
# 預測行: 6, 位置: 1, 插入: '出'
# 預測行: 6, 位置: 2, 插入: '生'
# 預測行: 6, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 7, 位置: 9, 插入: '日'
# 預測行: 8, 位置: 1, 插入: '住'
# 預測行: 8, 位置: 2, 插入: '址'
# 預測行: 8, 位置: 3, 插入: '
# '
# 預測行: 9, 位置: 9, 插入: '
# '
# 預測行: 10, 位置: 9, 插入: '
# '
# 預測行: 11, 位置: 1, 插入: '公'
# 預測行: 11, 位置: 2, 插入: '民'
# 預測行: 11, 位置: 3, 插入: '身'
# 預測行: 11, 位置: 4, 插入: '份'
# 預測行: 11, 位置: 5, 插入: '号'
# 預測行: 11, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00011_ocr_detailed_20250511_233620.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00012.jpg'...
# [2025/05/11 23:36:20] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.22745466232299805
# [2025/05/11 23:36:20] ppocr DEBUG: cls num  : 10, elapsed : 0.18103933334350586
# [2025/05/11 23:36:21] ppocr DEBUG: rec_res num  : 10, elapsed : 0.4446549415588379
# 圖片 'image_00012.jpg' 的 CER: 0.5217
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 4, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 4, 位置: 1, 插入: '出'
# 預測行: 4, 位置: 2, 插入: '生'
# 預測行: 4, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 5, 位置: 10, 插入: '日'
# 預測行: 6, 位置: 1, 插入: '住'
# 預測行: 6, 位置: 2, 插入: '址'
# 預測行: 6, 位置: 3, 插入: '
# '
# 預測行: 7, 位置: 9, 插入: '
# '
# 預測行: 8, 位置: 2, 插入: '
# '
# 預測行: 9, 位置: 1, 插入: '公'
# 預測行: 9, 位置: 2, 插入: '民'
# 預測行: 9, 位置: 3, 插入: '身'
# 預測行: 9, 位置: 4, 插入: '份'
# 預測行: 9, 位置: 5, 插入: '号'
# 預測行: 9, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00012_ocr_detailed_20250511_233621.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00013.jpg'...
# [2025/05/11 23:36:21] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.10483050346374512
# [2025/05/11 23:36:21] ppocr DEBUG: cls num  : 12, elapsed : 0.030432701110839844
# [2025/05/11 23:36:22] ppocr DEBUG: rec_res num  : 12, elapsed : 0.5950589179992676
# 圖片 'image_00013.jpg' 的 CER: 0.5319
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 3, 插入: '
# '
# 預測行: 5, 位置: 1, 插入: '民'
# 預測行: 5, 位置: 2, 插入: '族'
# 預測行: 6, 位置: 1, 插入: '出'
# 預測行: 6, 位置: 2, 插入: '生'
# 預測行: 6, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 7, 位置: 10, 插入: '日'
# 預測行: 8, 位置: 1, 插入: '住'
# 預測行: 8, 位置: 2, 插入: '址'
# 預測行: 8, 位置: 3, 插入: '
# '
# 預測行: 9, 位置: 9, 插入: '
# '
# 預測行: 10, 位置: 4, 插入: '
# '
# 預測行: 11, 位置: 1, 插入: '公'
# 預測行: 11, 位置: 2, 插入: '民'
# 預測行: 11, 位置: 3, 插入: '身'
# 預測行: 11, 位置: 4, 插入: '份'
# 預測行: 11, 位置: 5, 插入: '号'
# 預測行: 11, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00013_ocr_detailed_20250511_233622.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00014.jpg'...
# [2025/05/11 23:36:22] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.1016542911529541
# [2025/05/11 23:36:22] ppocr DEBUG: cls num  : 10, elapsed : 0.030185222625732422
# [2025/05/11 23:36:22] ppocr DEBUG: rec_res num  : 10, elapsed : 0.38320422172546387
# 圖片 'image_00014.jpg' 的 CER: 0.2917
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '务'
# 預測行: 1, 位置: 3, 插入: '
# '
# 實際行: 1, 位置: 1, 替換為: '前', 原字元: '蒯'
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 實際行: 2, 位置: 2, 替換為: '民', 原字元: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 4, 位置: 11, 插入: '日'
# 預測行: 5, 位置: 1, 插入: '住'
# 預測行: 5, 位置: 2, 插入: '址'
# 預測行: 5, 位置: 3, 插入: '
# '
# 預測行: 6, 位置: 9, 插入: '
# '
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00014_ocr_detailed_20250511_233622.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00015.jpg'...
# [2025/05/11 23:36:22] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.11098003387451172
# [2025/05/11 23:36:22] ppocr DEBUG: cls num  : 7, elapsed : 0.12646770477294922
# [2025/05/11 23:36:23] ppocr DEBUG: rec_res num  : 7, elapsed : 0.3288726806640625
# 圖片 'image_00015.jpg' 的 CER: 0.2174
# 詳細錯誤：
# 預測行: 2, 位置: 2, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 3, 位置: 10, 插入: '日'
# 預測行: 4, 位置: 9, 插入: '
# '
# 預測行: 5, 位置: 2, 插入: '
# '
# 預測行: 6, 位置: 1, 插入: '份'
# 預測行: 6, 位置: 2, 插入: '号'
# 預測行: 6, 位置: 3, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00015_ocr_detailed_20250511_233623.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00016.jpg'...
# [2025/05/11 23:36:23] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.10267519950866699
# [2025/05/11 23:36:23] ppocr DEBUG: cls num  : 10, elapsed : 0.033910512924194336
# [2025/05/11 23:36:23] ppocr DEBUG: rec_res num  : 10, elapsed : 0.42415666580200195
# 圖片 'image_00016.jpg' 的 CER: 0.5435
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 2, 位置: 1, 插入: '性'
# 預測行: 2, 位置: 2, 插入: '别'
# 預測行: 2, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 2, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 4, 位置: 1, 插入: '出'
# 預測行: 4, 位置: 2, 插入: '生'
# 預測行: 4, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 5, 位置: 10, 插入: '日'
# 預測行: 6, 位置: 1, 插入: '住'
# 預測行: 6, 位置: 2, 插入: '址'
# 預測行: 6, 位置: 3, 插入: '
# '
# 預測行: 7, 位置: 9, 插入: '
# '
# 實際行: 7, 位置: 9, 替換為: '音', 原字元: '县'
# 預測行: 9, 位置: 19, 插入: '
# '
# 預測行: 10, 位置: 1, 插入: '公'
# 預測行: 10, 位置: 2, 插入: '民'
# 預測行: 10, 位置: 3, 插入: '身'
# 預測行: 10, 位置: 4, 插入: '份'
# 預測行: 10, 位置: 5, 插入: '号'
# 預測行: 10, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00016_ocr_detailed_20250511_233623.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00017.jpg'...
# [2025/05/11 23:36:23] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.12407898902893066
# [2025/05/11 23:36:24] ppocr DEBUG: cls num  : 8, elapsed : 0.11005282402038574
# [2025/05/11 23:36:24] ppocr DEBUG: rec_res num  : 8, elapsed : 0.3766303062438965
# 圖片 'image_00017.jpg' 的 CER: 0.1111
# 詳細錯誤：
# 實際行: 2, 位置: 2, 刪除: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 3, 位置: 9, 插入: '日'
# 預測行: 4, 位置: 9, 插入: '
# '
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00017_ocr_detailed_20250511_233624.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00018.jpg'...
# [2025/05/11 23:36:24] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.2566688060760498
# [2025/05/11 23:36:24] ppocr DEBUG: cls num  : 11, elapsed : 0.1722733974456787
# [2025/05/11 23:36:25] ppocr DEBUG: rec_res num  : 11, elapsed : 0.5080091953277588
# 圖片 'image_00018.jpg' 的 CER: 0.4894
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 2, 位置: 1, 插入: '性'
# 實際行: 2, 位置: 1, 替換為: '别', 原字元: '男'
# 預測行: 3, 位置: 1, 插入: '民'
# 預測行: 3, 位置: 2, 插入: '族'
# 預測行: 4, 位置: 1, 插入: '出'
# 預測行: 4, 位置: 2, 插入: '生'
# 預測行: 4, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 5, 位置: 9, 插入: '日'
# 預測行: 6, 位置: 1, 插入: '住'
# 預測行: 6, 位置: 2, 插入: '址'
# 預測行: 6, 位置: 3, 插入: '
# '
# 預測行: 7, 位置: 9, 插入: '
# '
# 預測行: 8, 位置: 4, 插入: '
# '
# 預測行: 9, 位置: 1, 插入: '公'
# 預測行: 9, 位置: 2, 插入: '民'
# 預測行: 9, 位置: 3, 插入: '身'
# 預測行: 9, 位置: 4, 插入: '份'
# 預測行: 9, 位置: 5, 插入: '号'
# 預測行: 9, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00018_ocr_detailed_20250511_233625.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00019.jpg'...
# [2025/05/11 23:36:25] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.11892390251159668
# [2025/05/11 23:36:25] ppocr DEBUG: cls num  : 11, elapsed : 0.03872799873352051
# [2025/05/11 23:36:25] ppocr DEBUG: rec_res num  : 11, elapsed : 0.39313364028930664
# 圖片 'image_00019.jpg' 的 CER: 0.1020
# 詳細錯誤：
# 實際行: 2, 位置: 2, 刪除: '
# '
# 實際行: 4, 位置: 5, 刪除: '
# '
# 實際行: 5, 位置: 2, 刪除: '
# '
# 實際行: 7, 位置: 3, 替換為: '社', 原字元: '壮'
# 預測行: 4, 位置: 9, 插入: '
# '
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00019_ocr_detailed_20250511_233625.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00020.jpg'...
# [2025/05/11 23:36:26] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.12958908081054688
# [2025/05/11 23:36:26] ppocr DEBUG: cls num  : 9, elapsed : 0.11890888214111328
# [2025/05/11 23:36:26] ppocr DEBUG: rec_res num  : 9, elapsed : 0.3510575294494629
# 圖片 'image_00020.jpg' 的 CER: 0.4118
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 2, 位置: 1, 插入: '性'
# 預測行: 2, 位置: 2, 插入: '别'
# 預測行: 2, 位置: 4, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 3, 位置: 1, 插入: '出'
# 預測行: 3, 位置: 2, 插入: '饼'
# 預測行: 3, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 4, 位置: 9, 插入: '日'
# 預測行: 5, 位置: 9, 插入: '
# '
# 預測行: 6, 位置: 8, 插入: '
# '
# 預測行: 7, 位置: 1, 插入: '公'
# 預測行: 7, 位置: 2, 插入: '民'
# 預測行: 7, 位置: 3, 插入: '身'
# 預測行: 7, 位置: 4, 插入: '份'
# 預測行: 7, 位置: 5, 插入: '号'
# 預測行: 7, 位置: 6, 插入: '码'
# 預測行: 7, 位置: 7, 插入: '4'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00020_ocr_detailed_20250511_233626.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00021.jpg'...
# [2025/05/11 23:36:26] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.09262561798095703
# [2025/05/11 23:36:26] ppocr DEBUG: cls num  : 10, elapsed : 0.12037110328674316
# [2025/05/11 23:36:27] ppocr DEBUG: rec_res num  : 10, elapsed : 0.40970826148986816
# 圖片 'image_00021.jpg' 的 CER: 0.4222
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 2, 位置: 1, 插入: '性'
# 實際行: 2, 位置: 2, 替換為: '民', 原字元: '
# '
# 預測行: 3, 位置: 1, 插入: '出'
# 預測行: 3, 位置: 2, 插入: '生'
# 預測行: 3, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 4, 位置: 9, 插入: '日'
# 實際行: 7, 位置: 7, 替換為: '颖', 原字元: '颍'
# 預測行: 5, 位置: 9, 插入: '
# '
# 預測行: 6, 位置: 2, 插入: '
# '
# 預測行: 7, 位置: 1, 插入: '公'
# 預測行: 7, 位置: 2, 插入: '民'
# 預測行: 7, 位置: 3, 插入: '身'
# 預測行: 7, 位置: 4, 插入: '外'
# 預測行: 7, 位置: 5, 插入: '导'
# 預測行: 7, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00021_ocr_detailed_20250511_233627.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00022.jpg'...
# [2025/05/11 23:36:27] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.12102341651916504
# [2025/05/11 23:36:27] ppocr DEBUG: cls num  : 12, elapsed : 0.03695511817932129
# [2025/05/11 23:36:28] ppocr DEBUG: rec_res num  : 12, elapsed : 0.6221802234649658
# 圖片 'image_00022.jpg' 的 CER: 0.5652
# 詳細錯誤：
# 預測行: 2, 位置: 1, 插入: '姓'
# 實際行: 2, 位置: 1, 替換為: '名', 原字元: '女'
# 預測行: 3, 位置: 1, 插入: '民'
# 預測行: 3, 位置: 2, 插入: '族'
# 預測行: 4, 位置: 1, 插入: '性'
# 預測行: 4, 位置: 2, 插入: '别'
# 預測行: 4, 位置: 3, 插入: '
# '
# 預測行: 5, 位置: 1, 插入: '女'
# 預測行: 5, 位置: 2, 插入: '
# '
# 預測行: 6, 位置: 1, 插入: '出'
# 預測行: 6, 位置: 2, 插入: '生'
# 預測行: 6, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 7, 位置: 10, 插入: '日'
# 預測行: 8, 位置: 1, 插入: '住'
# 預測行: 8, 位置: 2, 插入: '址'
# 預測行: 8, 位置: 3, 插入: '
# '
# 預測行: 9, 位置: 9, 插入: '
# '
# 預測行: 11, 位置: 19, 插入: '
# '
# 預測行: 12, 位置: 1, 插入: '公'
# 預測行: 12, 位置: 2, 插入: '民'
# 預測行: 12, 位置: 3, 插入: '身'
# 預測行: 12, 位置: 4, 插入: '份'
# 預測行: 12, 位置: 5, 插入: '号'
# 預測行: 12, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00022_ocr_detailed_20250511_233628.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00023.jpg'...
# [2025/05/11 23:36:28] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.10922741889953613
# [2025/05/11 23:36:28] ppocr DEBUG: cls num  : 11, elapsed : 0.03986930847167969
# [2025/05/11 23:36:28] ppocr DEBUG: rec_res num  : 11, elapsed : 0.4464542865753174
# 圖片 'image_00023.jpg' 的 CER: 0.5714
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 3, 插入: '
# '
# 預測行: 4, 位置: 2, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 5, 位置: 1, 插入: '出'
# 預測行: 5, 位置: 2, 插入: '生'
# 預測行: 5, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 6, 位置: 9, 插入: '日'
# 預測行: 7, 位置: 1, 插入: '住'
# 預測行: 7, 位置: 2, 插入: '址'
# 預測行: 7, 位置: 3, 插入: '
# '
# 預測行: 8, 位置: 7, 插入: '
# '
# 預測行: 9, 位置: 1, 插入: '公'
# 預測行: 9, 位置: 2, 插入: '民'
# 預測行: 9, 位置: 3, 插入: '身'
# 預測行: 9, 位置: 4, 插入: '份'
# 預測行: 9, 位置: 5, 插入: '号'
# 預測行: 9, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00023_ocr_detailed_20250511_233628.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00024.jpg'...
# [2025/05/11 23:36:28] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.12446475028991699
# [2025/05/11 23:36:28] ppocr DEBUG: cls num  : 12, elapsed : 0.03390836715698242
# [2025/05/11 23:36:29] ppocr DEBUG: rec_res num  : 12, elapsed : 0.45661330223083496
# 圖片 'image_00024.jpg' 的 CER: 0.5435
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 3, 插入: '
# '
# 預測行: 4, 位置: 2, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 5, 位置: 1, 插入: '出'
# 預測行: 5, 位置: 2, 插入: '生'
# 預測行: 5, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 7, 位置: 1, 插入: '住'
# 預測行: 7, 位置: 2, 插入: '域'
# 預測行: 7, 位置: 3, 插入: '
# '
# 預測行: 8, 位置: 9, 插入: '
# '
# 預測行: 9, 位置: 1, 插入: '音'
# 預測行: 9, 位置: 2, 插入: '
# '
# 預測行: 10, 位置: 1, 插入: '公'
# 預測行: 10, 位置: 2, 插入: '民'
# 預測行: 10, 位置: 3, 插入: '身'
# 預測行: 10, 位置: 4, 插入: '份'
# 預測行: 10, 位置: 5, 插入: '号'
# 實際行: 7, 位置: 9, 替換為: '码', 原字元: '县'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00024_ocr_detailed_20250511_233629.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00025.jpg'...
# [2025/05/11 23:36:29] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.25727367401123047
# [2025/05/11 23:36:29] ppocr DEBUG: cls num  : 11, elapsed : 0.03143596649169922
# [2025/05/11 23:36:29] ppocr DEBUG: rec_res num  : 11, elapsed : 0.31656646728515625
# 圖片 'image_00025.jpg' 的 CER: 0.3261
# 詳細錯誤：
# 實際行: 2, 位置: 2, 替換為: '民', 原字元: '
# '
# 預測行: 3, 位置: 1, 插入: '出'
# 預測行: 3, 位置: 2, 插入: '生'
# 預測行: 3, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 4, 位置: 9, 插入: '日'
# 預測行: 5, 位置: 9, 插入: '
# '
# 預測行: 7, 位置: 19, 插入: '
# '
# 預測行: 8, 位置: 1, 插入: '公'
# 預測行: 8, 位置: 2, 插入: '民'
# 預測行: 8, 位置: 3, 插入: '身'
# 預測行: 8, 位置: 4, 插入: '份'
# 預測行: 8, 位置: 5, 插入: '专'
# 預測行: 8, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00025_ocr_detailed_20250511_233629.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00026.jpg'...
# [2025/05/11 23:36:30] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.13116097450256348
# [2025/05/11 23:36:30] ppocr DEBUG: cls num  : 11, elapsed : 0.18787288665771484
# [2025/05/11 23:36:30] ppocr DEBUG: rec_res num  : 11, elapsed : 0.5904204845428467
# 圖片 'image_00026.jpg' 的 CER: 0.4898
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 4, 位置: 1, 插入: '民'
# 預測行: 4, 位置: 2, 插入: '族'
# 預測行: 5, 位置: 1, 插入: '出'
# 預測行: 5, 位置: 2, 插入: '生'
# 預測行: 5, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 6, 位置: 9, 插入: '日'
# 預測行: 7, 位置: 1, 插入: '住'
# 預測行: 7, 位置: 2, 插入: '址'
# 預測行: 7, 位置: 3, 插入: '
# '
# 預測行: 8, 位置: 9, 插入: '
# '
# 預測行: 9, 位置: 6, 插入: '
# '
# 預測行: 10, 位置: 1, 插入: '公'
# 預測行: 10, 位置: 2, 插入: '民'
# 預測行: 10, 位置: 3, 插入: '身'
# 預測行: 10, 位置: 4, 插入: '份'
# 預測行: 10, 位置: 5, 插入: '号'
# 預測行: 10, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00026_ocr_detailed_20250511_233630.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00027.jpg'...
# [2025/05/11 23:36:30] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.10040450096130371
# [2025/05/11 23:36:30] ppocr DEBUG: cls num  : 11, elapsed : 0.03290414810180664
# [2025/05/11 23:36:31] ppocr DEBUG: rec_res num  : 11, elapsed : 0.33426356315612793
# 圖片 'image_00027.jpg' 的 CER: 0.5102
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 3, 插入: '
# '
# 預測行: 4, 位置: 2, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 5, 位置: 1, 插入: '出'
# 預測行: 5, 位置: 2, 插入: '生'
# 預測行: 5, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 6, 位置: 9, 插入: '日'
# 預測行: 7, 位置: 1, 插入: '住'
# 預測行: 7, 位置: 2, 插入: '址'
# 預測行: 7, 位置: 3, 插入: '
# '
# 預測行: 8, 位置: 9, 插入: '
# '
# 預測行: 9, 位置: 6, 插入: '
# '
# 預測行: 10, 位置: 1, 插入: '公'
# 預測行: 10, 位置: 2, 插入: '民'
# 預測行: 10, 位置: 3, 插入: '身'
# 預測行: 10, 位置: 4, 插入: '份'
# 預測行: 10, 位置: 5, 插入: '号'
# 預測行: 10, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00027_ocr_detailed_20250511_233631.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00028.jpg'...
# [2025/05/11 23:36:31] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.10689282417297363
# [2025/05/11 23:36:31] ppocr DEBUG: cls num  : 11, elapsed : 0.04145550727844238
# [2025/05/11 23:36:32] ppocr DEBUG: rec_res num  : 11, elapsed : 0.5415084362030029
# 圖片 'image_00028.jpg' 的 CER: 0.5333
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 3, 插入: '
# '
# 預測行: 5, 位置: 1, 插入: '民'
# 預測行: 5, 位置: 2, 插入: '族'
# 預測行: 6, 位置: 1, 插入: '出'
# 預測行: 6, 位置: 2, 插入: '生'
# 預測行: 6, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 7, 位置: 10, 插入: '日'
# 預測行: 8, 位置: 1, 插入: '住'
# 預測行: 8, 位置: 2, 插入: '址'
# 預測行: 8, 位置: 3, 插入: '
# '
# 預測行: 9, 位置: 9, 插入: '
# '
# 預測行: 10, 位置: 1, 插入: '公'
# 預測行: 10, 位置: 2, 插入: '民'
# 預測行: 10, 位置: 3, 插入: '身'
# 預測行: 10, 位置: 4, 插入: '份'
# 預測行: 10, 位置: 5, 插入: '号'
# 預測行: 10, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00028_ocr_detailed_20250511_233632.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00029.jpg'...
# [2025/05/11 23:36:32] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.11326217651367188
# [2025/05/11 23:36:32] ppocr DEBUG: cls num  : 8, elapsed : 0.11221480369567871
# [2025/05/11 23:36:32] ppocr DEBUG: rec_res num  : 8, elapsed : 0.34760189056396484
# 圖片 'image_00029.jpg' 的 CER: 0.5000
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 2, 位置: 1, 插入: '性'
# 預測行: 2, 位置: 2, 插入: '别'
# 預測行: 2, 位置: 4, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 3, 位置: 11, 插入: '日'
# 預測行: 4, 位置: 1, 插入: '出'
# 預測行: 4, 位置: 2, 插入: '生'
# 預測行: 4, 位置: 3, 插入: '
# '
# 預測行: 6, 位置: 1, 插入: '住'
# 預測行: 6, 位置: 2, 插入: '址'
# 預測行: 6, 位置: 3, 插入: '
# '
# 預測行: 7, 位置: 19, 插入: '
# '
# 預測行: 8, 位置: 1, 插入: '公'
# 預測行: 8, 位置: 2, 插入: '民'
# 預測行: 8, 位置: 3, 插入: '身'
# 預測行: 8, 位置: 4, 插入: '份'
# 預測行: 8, 位置: 5, 插入: '号'
# 預測行: 8, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00029_ocr_detailed_20250511_233632.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00030.jpg'...
# [2025/05/11 23:36:32] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.11839866638183594
# [2025/05/11 23:36:32] ppocr DEBUG: cls num  : 9, elapsed : 0.12256002426147461
# [2025/05/11 23:36:33] ppocr DEBUG: rec_res num  : 9, elapsed : 0.43279457092285156
# 圖片 'image_00030.jpg' 的 CER: 0.5000
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 2, 位置: 1, 插入: '性'
# 預測行: 2, 位置: 2, 插入: '别'
# 預測行: 2, 位置: 4, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 3, 位置: 1, 插入: '出'
# 預測行: 3, 位置: 2, 插入: '生'
# 預測行: 3, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 4, 位置: 9, 插入: '日'
# 預測行: 5, 位置: 1, 插入: '住'
# 預測行: 5, 位置: 2, 插入: '址'
# 預測行: 5, 位置: 3, 插入: '
# '
# 預測行: 6, 位置: 9, 插入: '
# '
# 預測行: 7, 位置: 3, 插入: '
# '
# 預測行: 8, 位置: 1, 插入: '公'
# 預測行: 8, 位置: 2, 插入: '民'
# 預測行: 8, 位置: 3, 插入: '身'
# 預測行: 8, 位置: 4, 插入: '份'
# 預測行: 8, 位置: 5, 插入: '号'
# 預測行: 8, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00030_ocr_detailed_20250511_233633.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00031.jpg'...
# [2025/05/11 23:36:33] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.10567402839660645
# [2025/05/11 23:36:33] ppocr DEBUG: cls num  : 7, elapsed : 0.13070964813232422
# [2025/05/11 23:36:34] ppocr DEBUG: rec_res num  : 7, elapsed : 0.5503339767456055
# 圖片 'image_00031.jpg' 的 CER: 0.1698
# 詳細錯誤：
# 實際行: 2, 位置: 2, 替換為: '民', 原字元: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 3, 位置: 10, 插入: '日'
# 預測行: 4, 位置: 9, 插入: '
# '
# 預測行: 5, 位置: 9, 插入: '
# '
# 預測行: 6, 位置: 1, 插入: '份'
# 預測行: 6, 位置: 2, 插入: '号'
# 預測行: 6, 位置: 3, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00031_ocr_detailed_20250511_233634.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00032.jpg'...
# [2025/05/11 23:36:34] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.2390737533569336
# [2025/05/11 23:36:34] ppocr DEBUG: cls num  : 11, elapsed : 0.20927929878234863
# [2025/05/11 23:36:35] ppocr DEBUG: rec_res num  : 11, elapsed : 0.5611422061920166
# 圖片 'image_00032.jpg' 的 CER: 0.2745
# 詳細錯誤：
# 預測行: 2, 位置: 2, 插入: '汉'
# 實際行: 3, 位置: 1, 替換為: '出', 原字元: '汉'
# 實際行: 4, 位置: 5, 刪除: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 5, 位置: 1, 插入: '住'
# 預測行: 5, 位置: 2, 插入: '
# '
# 預測行: 6, 位置: 9, 插入: '
# '
# 預測行: 7, 位置: 7, 插入: '
# '
# 預測行: 8, 位置: 1, 插入: '公'
# 預測行: 8, 位置: 2, 插入: '民'
# 預測行: 8, 位置: 3, 插入: '身'
# 預測行: 8, 位置: 4, 插入: '价'
# 預測行: 8, 位置: 5, 插入: '号'
# 預測行: 8, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00032_ocr_detailed_20250511_233635.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00033.jpg'...
# [2025/05/11 23:36:35] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.1150202751159668
# [2025/05/11 23:36:35] ppocr DEBUG: cls num  : 12, elapsed : 0.09014105796813965
# [2025/05/11 23:36:36] ppocr DEBUG: rec_res num  : 12, elapsed : 0.6795885562896729
# 圖片 'image_00033.jpg' 的 CER: 0.4200
# 詳細錯誤：
# 預測行: 2, 位置: 1, 插入: '姓'
# 預測行: 2, 位置: 2, 插入: '名'
# 預測行: 2, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 2, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 4, 位置: 1, 插入: '性'
# 預測行: 4, 位置: 2, 插入: '照'
# 預測行: 4, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 6, 位置: 1, 插入: '出'
# 預測行: 6, 位置: 2, 插入: '生'
# 預測行: 6, 位置: 3, 插入: '
# '
# 預測行: 7, 位置: 9, 插入: '
# '
# 預測行: 9, 位置: 19, 插入: '
# '
# 預測行: 10, 位置: 1, 插入: '公'
# 預測行: 10, 位置: 2, 插入: '民'
# 預測行: 10, 位置: 3, 插入: '身'
# 預測行: 10, 位置: 4, 插入: '设'
# 預測行: 10, 位置: 5, 插入: '号'
# 預測行: 10, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00033_ocr_detailed_20250511_233636.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00034.jpg'...
# [2025/05/11 23:36:36] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.11807870864868164
# [2025/05/11 23:36:36] ppocr DEBUG: cls num  : 8, elapsed : 0.133040189743042
# [2025/05/11 23:36:36] ppocr DEBUG: rec_res num  : 8, elapsed : 0.47509050369262695
# 圖片 'image_00034.jpg' 的 CER: 0.4889
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 2, 位置: 1, 插入: '性'
# 預測行: 2, 位置: 2, 插入: '别'
# 預測行: 2, 位置: 4, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 3, 位置: 1, 插入: '出'
# 預測行: 3, 位置: 2, 插入: '生'
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 3, 位置: 11, 插入: '日'
# 預測行: 4, 位置: 9, 插入: '
# '
# 預測行: 5, 位置: 1, 插入: '住'
# 預測行: 5, 位置: 2, 插入: '址'
# 預測行: 5, 位置: 3, 插入: '
# '
# 預測行: 7, 位置: 19, 插入: '
# '
# 預測行: 8, 位置: 1, 插入: '公'
# 預測行: 8, 位置: 2, 插入: '民'
# 預測行: 8, 位置: 3, 插入: '身'
# 預測行: 8, 位置: 4, 插入: '份'
# 預測行: 8, 位置: 5, 插入: '号'
# 預測行: 8, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00034_ocr_detailed_20250511_233636.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00035.jpg'...
# [2025/05/11 23:36:36] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.10639071464538574
# [2025/05/11 23:36:36] ppocr DEBUG: cls num  : 10, elapsed : 0.11277031898498535
# [2025/05/11 23:36:37] ppocr DEBUG: rec_res num  : 10, elapsed : 0.5186436176300049
# 圖片 'image_00035.jpg' 的 CER: 0.5455
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 3, 插入: '
# '
# 預測行: 4, 位置: 2, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 5, 位置: 1, 插入: '出'
# 預測行: 5, 位置: 2, 插入: '生'
# 預測行: 5, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 6, 位置: 11, 插入: '日'
# 預測行: 7, 位置: 1, 插入: '住'
# 預測行: 7, 位置: 2, 插入: '址'
# 預測行: 7, 位置: 3, 插入: '
# '
# 預測行: 8, 位置: 7, 插入: '
# '
# 預測行: 9, 位置: 1, 插入: '公'
# 預測行: 9, 位置: 2, 插入: '民'
# 預測行: 9, 位置: 3, 插入: '身'
# 預測行: 9, 位置: 4, 插入: '份'
# 預測行: 9, 位置: 5, 插入: '号'
# 預測行: 9, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00035_ocr_detailed_20250511_233637.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00036.jpg'...
# [2025/05/11 23:36:37] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.13353657722473145
# [2025/05/11 23:36:37] ppocr DEBUG: cls num  : 11, elapsed : 0.04282641410827637
# [2025/05/11 23:36:38] ppocr DEBUG: rec_res num  : 11, elapsed : 0.5241403579711914
# 圖片 'image_00036.jpg' 的 CER: 0.5319
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 3, 插入: '
# '
# 預測行: 4, 位置: 2, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 5, 位置: 1, 插入: '出'
# 預測行: 5, 位置: 2, 插入: '生'
# 預測行: 5, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 6, 位置: 11, 插入: '日'
# 預測行: 7, 位置: 1, 插入: '住'
# 預測行: 7, 位置: 2, 插入: '址'
# 預測行: 7, 位置: 3, 插入: '
# '
# 預測行: 8, 位置: 9, 插入: '
# '
# 預測行: 9, 位置: 2, 插入: '
# '
# 預測行: 10, 位置: 1, 插入: '公'
# 預測行: 10, 位置: 2, 插入: '民'
# 預測行: 10, 位置: 3, 插入: '身'
# 預測行: 10, 位置: 4, 插入: '份'
# 預測行: 10, 位置: 5, 插入: '号'
# 預測行: 10, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00036_ocr_detailed_20250511_233638.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00037.jpg'...
# [2025/05/11 23:36:38] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.27872538566589355
# [2025/05/11 23:36:38] ppocr DEBUG: cls num  : 9, elapsed : 0.2248995304107666
# [2025/05/11 23:36:39] ppocr DEBUG: rec_res num  : 9, elapsed : 0.5937206745147705
# 圖片 'image_00037.jpg' 的 CER: 0.4615
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 實際行: 1, 位置: 3, 替換為: '斑', 原字元: '玟'
# 預測行: 2, 位置: 1, 插入: '性'
# 預測行: 2, 位置: 2, 插入: '别'
# 預測行: 2, 位置: 4, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 3, 位置: 1, 插入: '出'
# 預測行: 3, 位置: 2, 插入: '生'
# 預測行: 3, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 4, 位置: 11, 插入: '日'
# 預測行: 5, 位置: 1, 插入: '住'
# 預測行: 5, 位置: 2, 插入: '址'
# 預測行: 5, 位置: 3, 插入: '
# '
# 預測行: 6, 位置: 9, 插入: '
# '
# 預測行: 7, 位置: 7, 插入: '
# '
# 預測行: 8, 位置: 1, 插入: '公'
# 預測行: 8, 位置: 2, 插入: '民'
# 預測行: 8, 位置: 3, 插入: '身'
# 預測行: 8, 位置: 4, 插入: '份'
# 預測行: 8, 位置: 5, 插入: '号'
# 預測行: 8, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00037_ocr_detailed_20250511_233639.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00038.jpg'...
# [2025/05/11 23:36:39] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.11182618141174316
# [2025/05/11 23:36:39] ppocr DEBUG: cls num  : 10, elapsed : 0.047649383544921875
# [2025/05/11 23:36:39] ppocr DEBUG: rec_res num  : 10, elapsed : 0.4488363265991211
# 圖片 'image_00038.jpg' 的 CER: 0.4348
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '名'
# 預測行: 2, 位置: 2, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 3, 位置: 1, 插入: '出'
# 預測行: 3, 位置: 2, 插入: '生'
# 預測行: 3, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 4, 位置: 10, 插入: '日'
# 預測行: 5, 位置: 1, 插入: '住'
# 預測行: 5, 位置: 2, 插入: '址'
# 預測行: 5, 位置: 3, 插入: '
# '
# 預測行: 6, 位置: 9, 插入: '
# '
# 預測行: 8, 位置: 19, 插入: '
# '
# 預測行: 9, 位置: 1, 插入: '公'
# 預測行: 9, 位置: 2, 插入: '民'
# 預測行: 9, 位置: 3, 插入: '身'
# 預測行: 9, 位置: 4, 插入: '份'
# 預測行: 9, 位置: 5, 插入: '号'
# 預測行: 9, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00038_ocr_detailed_20250511_233639.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00039.jpg'...
# [2025/05/11 23:36:40] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.21413254737854004
# [2025/05/11 23:36:40] ppocr DEBUG: cls num  : 8, elapsed : 0.1284182071685791
# [2025/05/11 23:36:40] ppocr DEBUG: rec_res num  : 8, elapsed : 0.6180408000946045
# 圖片 'image_00039.jpg' 的 CER: 0.2340
# 詳細錯誤：
# 預測行: 3, 位置: 1, 插入: '民'
# 預測行: 3, 位置: 2, 插入: '族'
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 4, 位置: 11, 插入: '日'
# 預測行: 5, 位置: 9, 插入: '
# '
# 預測行: 6, 位置: 1, 插入: '音'
# 預測行: 6, 位置: 2, 插入: '
# '
# 預測行: 7, 位置: 1, 插入: '份'
# 預測行: 7, 位置: 2, 插入: '号'
# 實際行: 7, 位置: 9, 替換為: '码', 原字元: '县'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00039_ocr_detailed_20250511_233640.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00040.jpg'...
# [2025/05/11 23:36:41] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.11899709701538086
# [2025/05/11 23:36:41] ppocr DEBUG: cls num  : 12, elapsed : 0.04013228416442871
# [2025/05/11 23:36:41] ppocr DEBUG: rec_res num  : 12, elapsed : 0.7415752410888672
# 圖片 'image_00040.jpg' 的 CER: 0.5319
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 3, 插入: '
# '
# 預測行: 5, 位置: 1, 插入: '民'
# 預測行: 5, 位置: 2, 插入: '族'
# 預測行: 6, 位置: 1, 插入: '出'
# 預測行: 6, 位置: 2, 插入: '生'
# 預測行: 6, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 7, 位置: 10, 插入: '日'
# 預測行: 8, 位置: 1, 插入: '住'
# 預測行: 8, 位置: 2, 插入: '址'
# 預測行: 8, 位置: 3, 插入: '
# '
# 預測行: 9, 位置: 9, 插入: '
# '
# 預測行: 10, 位置: 3, 插入: '
# '
# 預測行: 11, 位置: 1, 插入: '公'
# 預測行: 11, 位置: 2, 插入: '民'
# 預測行: 11, 位置: 3, 插入: '身'
# 預測行: 11, 位置: 4, 插入: '份'
# 預測行: 11, 位置: 5, 插入: '导'
# 預測行: 11, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00040_ocr_detailed_20250511_233641.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00041.jpg'...
# [2025/05/11 23:36:41] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.1283426284790039
# [2025/05/11 23:36:42] ppocr DEBUG: cls num  : 8, elapsed : 0.03896045684814453
# [2025/05/11 23:36:42] ppocr DEBUG: rec_res num  : 8, elapsed : 0.48673462867736816
# 圖片 'image_00041.jpg' 的 CER: 0.4783
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 2, 位置: 1, 插入: '性'
# 預測行: 2, 位置: 2, 插入: '别'
# 預測行: 2, 位置: 4, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 3, 位置: 10, 插入: '日'
# 預測行: 4, 位置: 1, 插入: '出'
# 預測行: 4, 位置: 2, 插入: '生'
# 預測行: 4, 位置: 3, 插入: '
# '
# 預測行: 5, 位置: 1, 插入: '佳'
# 預測行: 5, 位置: 2, 插入: '址'
# 預測行: 5, 位置: 3, 插入: '
# '
# 預測行: 6, 位置: 9, 插入: '
# '
# 預測行: 7, 位置: 1, 插入: '公'
# 預測行: 7, 位置: 2, 插入: '民'
# 預測行: 7, 位置: 3, 插入: '身'
# 預測行: 7, 位置: 4, 插入: '份'
# 實際行: 7, 位置: 9, 替換為: '号', 原字元: '县'
# 實際行: 7, 位置: 10, 替換為: '码', 原字元: '
# '
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00041_ocr_detailed_20250511_233642.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00042.jpg'...
# [2025/05/11 23:36:42] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.12764549255371094
# [2025/05/11 23:36:42] ppocr DEBUG: cls num  : 12, elapsed : 0.03627300262451172
# [2025/05/11 23:36:43] ppocr DEBUG: rec_res num  : 12, elapsed : 0.5858585834503174
# 圖片 'image_00042.jpg' 的 CER: 0.4902
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 3, 插入: '
# '
# 預測行: 5, 位置: 1, 插入: '民'
# 預測行: 5, 位置: 2, 插入: '族'
# 預測行: 6, 位置: 1, 插入: '出'
# 預測行: 6, 位置: 2, 插入: '生'
# 預測行: 6, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 7, 位置: 10, 插入: '日'
# 預測行: 8, 位置: 1, 插入: '住'
# 預測行: 8, 位置: 2, 插入: '址'
# 預測行: 8, 位置: 3, 插入: '
# '
# 預測行: 9, 位置: 9, 插入: '
# '
# 預測行: 10, 位置: 7, 插入: '
# '
# 預測行: 11, 位置: 1, 插入: '公'
# 預測行: 11, 位置: 2, 插入: '民'
# 預測行: 11, 位置: 3, 插入: '身'
# 預測行: 11, 位置: 4, 插入: '价'
# 預測行: 11, 位置: 5, 插入: '号'
# 預測行: 11, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00042_ocr_detailed_20250511_233643.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00043.jpg'...
# [2025/05/11 23:36:43] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.28922414779663086
# [2025/05/11 23:36:43] ppocr DEBUG: cls num  : 12, elapsed : 0.11849570274353027
# [2025/05/11 23:36:44] ppocr DEBUG: rec_res num  : 12, elapsed : 0.687136173248291
# 圖片 'image_00043.jpg' 的 CER: 0.4000
# 詳細錯誤：
# 預測行: 3, 位置: 1, 插入: '民'
# 預測行: 3, 位置: 2, 插入: '族'
# 預測行: 4, 位置: 1, 插入: '别'
# 預測行: 4, 位置: 2, 插入: '
# '
# 預測行: 6, 位置: 1, 插入: '8'
# 預測行: 6, 位置: 2, 插入: '年'
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 6, 位置: 6, 插入: '日'
# 預測行: 7, 位置: 1, 插入: '生'
# 預測行: 7, 位置: 2, 插入: '
# '
# 預測行: 8, 位置: 9, 插入: '
# '
# 預測行: 10, 位置: 19, 插入: '
# '
# 預測行: 11, 位置: 1, 插入: '公'
# 預測行: 11, 位置: 2, 插入: '民'
# 預測行: 11, 位置: 3, 插入: '身'
# 預測行: 11, 位置: 4, 插入: '份'
# 預測行: 11, 位置: 5, 插入: '号'
# 預測行: 11, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00043_ocr_detailed_20250511_233644.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00044.jpg'...
# [2025/05/11 23:36:44] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.10729193687438965
# [2025/05/11 23:36:44] ppocr DEBUG: cls num  : 11, elapsed : 0.14220523834228516
# [2025/05/11 23:36:45] ppocr DEBUG: rec_res num  : 11, elapsed : 0.5699236392974854
# 圖片 'image_00044.jpg' 的 CER: 0.4091
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '主'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 3, 插入: '
# '
# 預測行: 5, 位置: 1, 插入: '民'
# 預測行: 5, 位置: 2, 插入: '族'
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 6, 位置: 9, 插入: '日'
# 預測行: 7, 位置: 9, 插入: '
# '
# 預測行: 8, 位置: 1, 插入: '音'
# 預測行: 8, 位置: 2, 插入: '
# '
# 預測行: 9, 位置: 1, 插入: '身'
# 預測行: 9, 位置: 2, 插入: '份'
# 預測行: 9, 位置: 3, 插入: '号'
# 實際行: 7, 位置: 9, 替換為: '码', 原字元: '县'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00044_ocr_detailed_20250511_233645.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00045.jpg'...
# [2025/05/11 23:36:45] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.10379147529602051
# [2025/05/11 23:36:45] ppocr DEBUG: cls num  : 7, elapsed : 0.13480019569396973
# [2025/05/11 23:36:45] ppocr DEBUG: rec_res num  : 7, elapsed : 0.35798168182373047
# 圖片 'image_00045.jpg' 的 CER: 0.3191
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 實際行: 1, 位置: 1, 替換為: '伊', 原字元: '毋'
# 預測行: 2, 位置: 1, 插入: '刷'
# 預測行: 2, 位置: 3, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 3, 位置: 10, 插入: '日'
# 預測行: 4, 位置: 9, 插入: '
# '
# 預測行: 5, 位置: 3, 插入: '
# '
# 預測行: 6, 位置: 1, 插入: '身'
# 預測行: 6, 位置: 2, 插入: '份'
# 預測行: 6, 位置: 3, 插入: '号'
# 預測行: 6, 位置: 4, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00045_ocr_detailed_20250511_233645.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00046.jpg'...
# [2025/05/11 23:36:45] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.13572144508361816
# [2025/05/11 23:36:46] ppocr DEBUG: cls num  : 10, elapsed : 0.13223886489868164
# [2025/05/11 23:36:46] ppocr DEBUG: rec_res num  : 10, elapsed : 0.4630270004272461
# 圖片 'image_00046.jpg' 的 CER: 0.5217
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 4, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 4, 位置: 1, 插入: '出'
# 預測行: 4, 位置: 2, 插入: '生'
# 預測行: 4, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 5, 位置: 10, 插入: '日'
# 預測行: 6, 位置: 1, 插入: '住'
# 預測行: 6, 位置: 2, 插入: '址'
# 預測行: 6, 位置: 3, 插入: '
# '
# 預測行: 7, 位置: 9, 插入: '
# '
# 預測行: 8, 位置: 2, 插入: '
# '
# 預測行: 9, 位置: 1, 插入: '公'
# 預測行: 9, 位置: 2, 插入: '民'
# 預測行: 9, 位置: 3, 插入: '身'
# 預測行: 9, 位置: 4, 插入: '份'
# 預測行: 9, 位置: 5, 插入: '号'
# 預測行: 9, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00046_ocr_detailed_20250511_233646.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00047.jpg'...
# [2025/05/11 23:36:46] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.11779618263244629
# [2025/05/11 23:36:46] ppocr DEBUG: cls num  : 9, elapsed : 0.1275317668914795
# [2025/05/11 23:36:47] ppocr DEBUG: rec_res num  : 9, elapsed : 0.7117016315460205
# 圖片 'image_00047.jpg' 的 CER: 0.3019
# 詳細錯誤：
# 實際行: 1, 位置: 1, 替換為: '逢', 原字元: '逄'
# 實際行: 2, 位置: 1, 替換為: '民', 原字元: '男'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 3, 位置: 1, 插入: '男'
# 預測行: 3, 位置: 2, 插入: '
# '
# 預測行: 5, 位置: 1, 插入: '年'
# 實際行: 5, 位置: 3, 替換為: '月', 原字元: '
# '
# 預測行: 5, 位置: 6, 插入: '日'
# 預測行: 6, 位置: 9, 插入: '
# '
# 實際行: 7, 位置: 15, 替換為: '文', 原字元: '丈'
# 預測行: 8, 位置: 19, 插入: '
# '
# 預測行: 9, 位置: 1, 插入: '民'
# 預測行: 9, 位置: 2, 插入: '身'
# 預測行: 9, 位置: 3, 插入: '份'
# 預測行: 9, 位置: 4, 插入: '号'
# 預測行: 9, 位置: 5, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00047_ocr_detailed_20250511_233647.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00048.jpg'...
# [2025/05/11 23:36:47] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.35486769676208496
# [2025/05/11 23:36:48] ppocr DEBUG: cls num  : 12, elapsed : 0.1358809471130371
# [2025/05/11 23:36:48] ppocr DEBUG: rec_res num  : 12, elapsed : 0.6796956062316895
# 圖片 'image_00048.jpg' 的 CER: 0.5319
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 1, 位置: 3, 插入: '
# '
# 預測行: 3, 位置: 1, 插入: '性'
# 預測行: 3, 位置: 2, 插入: '别'
# 預測行: 3, 位置: 3, 插入: '
# '
# 預測行: 5, 位置: 1, 插入: '民'
# 預測行: 5, 位置: 2, 插入: '族'
# 預測行: 6, 位置: 1, 插入: '出'
# 預測行: 6, 位置: 2, 插入: '生'
# 預測行: 6, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 7, 位置: 10, 插入: '日'
# 預測行: 8, 位置: 1, 插入: '住'
# 預測行: 8, 位置: 2, 插入: '址'
# 預測行: 8, 位置: 3, 插入: '
# '
# 預測行: 9, 位置: 9, 插入: '
# '
# 預測行: 10, 位置: 3, 插入: '
# '
# 預測行: 11, 位置: 1, 插入: '公'
# 預測行: 11, 位置: 2, 插入: '民'
# 預測行: 11, 位置: 3, 插入: '身'
# 預測行: 11, 位置: 4, 插入: '份'
# 預測行: 11, 位置: 5, 插入: '号'
# 預測行: 11, 位置: 6, 插入: '码'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00048_ocr_detailed_20250511_233648.txt
#
# 正在處理圖片 'C:\Users\User\Desktop\PaddleOCR\images\image_00049.jpg'...
# [2025/05/11 23:36:48] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.13337397575378418
# [2025/05/11 23:36:48] ppocr DEBUG: cls num  : 9, elapsed : 0.04787635803222656
# [2025/05/11 23:36:49] ppocr DEBUG: rec_res num  : 9, elapsed : 0.4439058303833008
# 圖片 'image_00049.jpg' 的 CER: 0.5682
# 詳細錯誤：
# 預測行: 1, 位置: 1, 插入: '姓'
# 預測行: 1, 位置: 2, 插入: '名'
# 預測行: 2, 位置: 1, 插入: '性'
# 預測行: 2, 位置: 2, 插入: '别'
# 預測行: 2, 位置: 4, 插入: '民'
# 實際行: 2, 位置: 2, 替換為: '族', 原字元: '
# '
# 預測行: 3, 位置: 1, 插入: '出'
# 預測行: 3, 位置: 2, 插入: '生'
# 預測行: 3, 位置: 3, 插入: '
# '
# 實際行: 4, 位置: 5, 替換為: '年', 原字元: '
# '
# 實際行: 5, 位置: 2, 替換為: '月', 原字元: '
# '
# 預測行: 4, 位置: 9, 插入: '日'
# 預測行: 5, 位置: 1, 插入: '住'
# 預測行: 5, 位置: 2, 插入: '址'
# 預測行: 5, 位置: 3, 插入: '
# '
# 實際行: 7, 位置: 4, 替換為: '街', 原字元: '衢'
# 預測行: 6, 位置: 9, 插入: '
# '
# 預測行: 7, 位置: 1, 插入: '音'
# 預測行: 7, 位置: 2, 插入: '
# '
# 預測行: 8, 位置: 1, 插入: '公'
# 預測行: 8, 位置: 2, 插入: '民'
# 預測行: 8, 位置: 3, 插入: '身'
# 預測行: 8, 位置: 4, 插入: '份'
# 預測行: 8, 位置: 5, 插入: '号'
# 實際行: 7, 位置: 9, 替換為: '码', 原字元: '县'
# OCR 輸出已保存到：C:\Users\User\Desktop\PaddleOCR\ocr_cer_batch_detailed\image_00049_ocr_detailed_20250511_233649.txt
#
# 前 50 張圖片的總 CER (平均): 0.4355
#
# OCR 和 CER 計算完成 (含詳細錯誤)。

# %% [markdown]
# 轉HSV和灰度

# %%
import cv2
import matplotlib.pyplot as plt
import os

# 圖片路徑 (請確保反斜線是正確的，或者使用 raw string)
image_path = r"C:\Users\User\Desktop\PaddleOCR\images\image_00010.jpg" # 使用 raw string r"..."

# --- 1. 檢查檔案是否存在 ---
if not os.path.exists(image_path):
    print(f"錯誤：找不到圖片檔案 '{image_path}'")
    print("請檢查路徑是否正確，以及檔案是否存在。")
    exit()

# --- 2. 讀取圖片 ---
# cv2.imread() 預設以 BGR 格式讀取圖片
original_bgr = cv2.imread(image_path)

# 檢查圖片是否成功讀取
if original_bgr is None:
    print(f"錯誤：無法讀取圖片 '{image_path}'.")
    print("請檢查檔案是否為有效的圖片格式 (如 .jpg, .png 等) 或檔案是否損毀。")
    exit()

# --- 3. 色彩空間轉換 ---

# 將 BGR 轉換為 RGB (方便 Matplotlib 顯示原始圖片的正確顏色)
original_rgb = cv2.cvtColor(original_bgr, cv2.COLOR_BGR2RGB)

# 將 BGR 轉換為 HSV
# HSV (Hue, Saturation, Value) 色彩空間
# H: 色調 (0-179 在 OpenCV 中)
# S: 飽和度 (0-255)
# V: 明度 (0-255)
hsv_image = cv2.cvtColor(original_bgr, cv2.COLOR_BGR2HSV)

# 將 BGR 轉換為灰度
# 灰度圖只有一個通道，表示亮度信息
gray_image = cv2.cvtColor(original_bgr, cv2.COLOR_BGR2GRAY)

# --- 4. 使用 Matplotlib 可視化 ---
# 創建一個畫布 (figure) 和一組子圖 (axes)
# 這裡我們創建 1 行 3 列的子圖，figsize 用來設定畫布大小
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# 顯示原始圖片 (RGB)
axes[0].imshow(original_rgb)
axes[0].set_title('原始圖片 (RGB)')
axes[0].axis('off') # 不顯示座標軸

# 顯示 HSV 圖片
# 注意：直接顯示 HSV 圖片可能看起來與預期不同，因為 Matplotlib 的 imshow
# 會嘗試將其解釋為 RGB (如果通道數為3)。
# HSV 的三個通道分別代表色調、飽和度和明度，其視覺呈現方式與RGB不同。
axes[1].imshow(hsv_image)
axes[1].set_title('HSV 色彩空間')
axes[1].axis('off')

# 顯示灰度圖片
# 灰度圖需要指定色彩映射 (colormap) 為 'gray'
axes[2].imshow(gray_image, cmap='gray')
axes[2].set_title('灰度色彩空間')
axes[2].axis('off')

# 自動調整子圖參數，使之填充整個圖像區域
plt.tight_layout()

# 顯示圖片
plt.show()

print("圖片處理與顯示完成。")

# --- 5. (可選) 如果你只想用 OpenCV 的視窗顯示 ---
# cv2.imshow('Original BGR', original_bgr)
# cv2.imshow('HSV Image', hsv_image)
# cv2.imshow('Grayscale Image', gray_image)

# cv2.waitKey(0) # 等待用戶按下任意鍵
# cv2.destroyAllWindows() # 關閉所有 OpenCV 創建的視窗

# %% [markdown]
# 排除字

# %%
from paddleocr_backup import PaddleOCR, draw_ocr
import os
import datetime # 導入 datetime 模組，用於生成時間戳
from PIL import Image # 確保 Image 被正確導入
import difflib

# 指定圖片路徑
image_path = r'C:\Users\User\Desktop\PaddleOCR\images\image_00010.jpg'

# 要過濾掉的關鍵字列表
filter_keywords = ['姓名', '性刷','性别', '民族','民旗' ,'出生','住址', '公民身份号码','民身份号码']

# 檢查圖片是否存在
if not os.path.exists(image_path):
    print(f"錯誤：圖片文件 '{image_path}' 不存在。請檢查路徑是否正確。")
else:
    # 初始化 OCR 模型
    # lang='ch' 表示使用中文模型，'en' 表示英文，你也可以指定其他語言
    # use_gpu=True 表示使用 GPU，如果你的電腦沒有 GPU 或者沒有配置 CUDA，請設置為 False
    # use_angle_cls=True 表示使用方向分類器，可以識別圖片中文字的旋轉角度
    ocr = PaddleOCR(use_angle_cls=True, lang="ch", use_gpu=False) # 假設圖片是中文，如果不是請修改 lang

    print(f"正在對圖片 '{image_path}' 執行 OCR 識別...")

    # 執行 OCR 識別
    result = ocr.ocr(image_path, cls=True)

    # 初始化列表來保存處理後的文本結果
    texts_for_file_output = [] # 用於保存到文本文件 (過濾後)
    
    # 用於繪圖的數據，需要保持座標、過濾後的文本和置信度對齊
    # 只有在過濾後文本不為空時才添加到這些列表
    drawable_boxes = []
    drawable_texts = []
    drawable_scores = []

    # 打印並處理識別結果
    if result and result[0]: # result[0] 包含識別結果的列表
        print("\nOCR 識別結果 (過濾前與過濾後)：")
        for line_data in result[0]: # 更清晰的變量名
            box_coordinates = line_data[0]    # 文字框的座標
            original_text = line_data[1][0]   # 識別出的原始文字
            confidence = line_data[1][1]      # 置信度

            print(f"  原始文字: '{original_text}', 置信度: {confidence:.2f}")

            # ---- 文字過濾 ----
            text_after_filtering = original_text
            for keyword in filter_keywords:
                text_after_filtering = text_after_filtering.replace(keyword, '')
            text_after_filtering = text_after_filtering.strip() # 去除替換後可能產生的前後空格
            # ------------------

            # 將過濾後的文本（即使是空字符串）添加到用於文件輸出的列表
            texts_for_file_output.append(text_after_filtering)

            if text_after_filtering: # 如果過濾後文本不為空
                print(f"  -> 過濾後文字: '{text_after_filtering}' (將用於繪圖和文本文件)")
                drawable_boxes.append(box_coordinates)
                drawable_texts.append(text_after_filtering)
                drawable_scores.append(confidence)
            else:
                print(f"  -> 過濾後文字為空或僅含空格，將不在繪圖中使用，文本文件中將為空行或僅含過濾殘餘。")
        
        # ----- 將過濾後的識別結果保存到 .txt 文件 -----
        output_dir = os.path.dirname(image_path)
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        image_name_without_ext = os.path.splitext(os.path.basename(image_path))[0]
        # 修改文件名以表示已過濾
        output_text_filename = f"{image_name_without_ext}_ocr_result_filtered_{timestamp}.txt"
        output_text_path = os.path.join(output_dir, output_text_filename)

        try:
            with open(output_text_path, 'w', encoding='utf-8') as f:
                for text_line in texts_for_file_output: # 使用包含所有過濾後文本的列表
                    f.write(text_line + '\n') # 每個識別到的文字後換行
            print(f"\n過濾後的 OCR 識別結果已保存到文本文件：{output_text_path}")
        except IOError as e:
            print(f"\n保存文本文件時發生錯誤: {e}")
        # ----------------------------------------------------

        # ----- 可選：繪製過濾後的識別結果並保存到圖片 -----
        if drawable_texts: # 僅當有可繪製的文本時才進行
            try:
                img_for_drawing = Image.open(image_path).convert('RGB')
                
                # 使用過濾和對齊後的 drawable_boxes, drawable_texts, drawable_scores
                font_path_for_drawing = r'C:\Windows\Fonts\msyh.ttc' # 微軟雅黑
                if not os.path.exists(font_path_for_drawing):
                    print(f"警告：字體 '{font_path_for_drawing}' 不存在，將嘗試使用預設字體。")
                    font_path_for_drawing = None # PaddleOCR 會使用其內建字體


                im_show_array = draw_ocr(img_for_drawing, drawable_boxes, drawable_texts, drawable_scores, font_path=font_path_for_drawing)
                
                # 定義輸出圖片路徑
                output_image_filename = f"{image_name_without_ext}_ocr_visual_filtered_{timestamp}.jpg"
                output_image_path = os.path.join(output_dir, output_image_filename)
                
                # draw_ocr 返回的是 NumPy 數組，需要轉回 PIL Image 對象進行保存
                im_show_pil = Image.fromarray(im_show_array)
                im_show_pil.save(output_image_path)
                print(f"\n過濾後的識別結果已保存到可視化圖片：{output_image_path}")

            except ImportError:
                print("\n警告：無法繪製識別結果。請安裝 'Pillow' 庫 (pip install Pillow)。OpenCV 也建議安裝。")
            except FileNotFoundError:
                # 此處主要指font_path_for_drawing指定的字體文件未找到
                print(f"\n錯誤：繪製圖片時找不到字體文件。請檢查 font_path: '{font_path_for_drawing}' 是否正確。")
            except Exception as e:
                print(f"\n繪製結果時發生未知錯誤: {e}")
        else:
            print("\n沒有可繪製的過濾後文字，跳過生成可視化圖片。")
            
    else:
        print("未在圖片中識別到任何文字。")

print("\nOCR 測試完成。")

# %%
# -*- coding: utf-8 -*-
"""
OCR 文字偵測 + 彈性關鍵字遮蔽（模糊比對 + 正則空格處理）
作者：ChatGPT         日期：2025‑05‑17
-----------------------------------------------------------------
需求：
1. 讀取指定圖片進行 PaddleOCR
2. 依關鍵字過濾個資（支援錯字、空格、類似詞）
3. 產生：
   ‑ 過濾後文字 txt
   ‑ 過濾後標註圖片
-----------------------------------------------------------------
"""

import os, datetime, difflib, re
from paddleocr_backup import PaddleOCR, draw_ocr
from PIL import Image

# ========= 使用者僅需修改以下區塊 ========= #
IMAGE_PATH  = r'C:\Users\User\Desktop\PaddleOCR\images\image_00006.jpg'
USE_GPU     = False          # 如裝好 CUDA 可改 True
OCR_LANG    = 'ch'           # zh(簡體) / ch(繁體) / en / 日韓… 詳見官方
SIM_THR     = 0.80           # 模糊比對相似度門檻 (0~1)
FILTER_WORDS = [
    '姓名', '性别', '民族', '出生', '住址', '公民身份号码',
    # 常見錯字／簡繁／拆字也可先列入
    '性別', '民旗', '性 别', '民 族'
]
# ========================================== #

# ---------- 函式區 ----------
def similar_to_keyword(text: str, keywords: list, thr: float) -> bool:
    """利用 difflib 判斷 text 是否與任一 keyword 相似到 thr 以上"""
    for kw in keywords:
        if difflib.SequenceMatcher(None, kw, text).ratio() >= thr:
            return True
    return False


def flex_regex_filter(text: str, keywords: list) -> str:
    """
    讓 keyword 中每個字後面可夾雜空白，再用正則替換
    例如 '出生' -> '出\s*生\s*'
    """
    filtered = text
    for kw in keywords:
        pattern = ''.join(fr'{re.escape(c)}\s*' for c in kw)
        filtered = re.sub(pattern, '', filtered, flags=re.IGNORECASE)
    return filtered.strip()


def apply_privacy_filter(orig_text: str) -> str:
    """
    先以模糊比對「整段文字」判斷是否完全屬於個資，
    是→整段清空；否→再用正則把片段關鍵字拿掉
    """
    if similar_to_keyword(orig_text, FILTER_WORDS, SIM_THR):
        return ''                      # 整段屬於敏感詞，直接清空
    return flex_regex_filter(orig_text, FILTER_WORDS)

# ----------------------------

# 1. 檢查圖片
if not os.path.isfile(IMAGE_PATH):
    raise FileNotFoundError(f'找不到圖片：{IMAGE_PATH}')

# 2. 初始化 OCR
ocr = PaddleOCR(use_angle_cls=True, lang=OCR_LANG, use_gpu=USE_GPU)
print(f'正在處理：{IMAGE_PATH}')

# 3. 執行 OCR
ocr_res = ocr.ocr(IMAGE_PATH, cls=True)

# 4. 準備輸出容器
txt_lines        = []    # 所有（含空行）文字
draw_boxes, draw_txts, draw_scores = [], [], []

# 5. 逐行處理
if ocr_res and ocr_res[0]:
    print('\n--- 識別結果 ---')
    for box, (text, score) in ocr_res[0]:
        print(f"原始: '{text}'  conf={score:.2f}")

        clean_text = apply_privacy_filter(text)
        txt_lines.append(clean_text)  # 即使空行也寫入

        if clean_text:                # 要畫的才存
            draw_boxes.append(box)
            draw_txts.append(clean_text)
            draw_scores.append(score)
            print(f"  → 保留: '{clean_text}'")
        else:
            print("  → 已遮蔽 / 空行")

else:
    print('⚠️ 未識別到任何文字')
    txt_lines.append('')  # 仍寫入空行避免後續報錯

# 6. 存 txt
out_dir   = os.path.dirname(IMAGE_PATH)
stamp     = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
base_name = os.path.splitext(os.path.basename(IMAGE_PATH))[0]
txt_path  = os.path.join(out_dir, f'{base_name}_filtered_{stamp}.txt')

with open(txt_path, 'w', encoding='utf-8') as f:
    f.write('\n'.join(txt_lines))
print(f'\n✅ 已輸出文字檔：{txt_path}')

# 7. 產生標註圖（若有文字）
if draw_txts:
    font_path = r'C:\Windows\Fonts\msyh.ttc'
    if not os.path.exists(font_path):
        font_path = None  # 讓 paddle 走內建字體
    img = Image.open(IMAGE_PATH).convert('RGB')
    vis = draw_ocr(img, draw_boxes, draw_txts, draw_scores, font_path=font_path)
    vis_img = Image.fromarray(vis)
    vis_path = os.path.join(out_dir, f'{base_name}_vis_{stamp}.jpg')
    vis_img.save(vis_path)
    print(f'✅ 已輸出標註圖：{vis_path}')
else:
    print('⚠️ 沒有可視化文字需要繪製，跳過輸出標註圖')

print('\n🎉 OCR 隱私過濾完成')
